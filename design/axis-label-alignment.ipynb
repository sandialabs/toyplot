# %% [markdown]
# ## Label Alignment
#
# **Default behavior:**
#
# * location: "above" or "below".  If None, default to "below".
# * offset: If None, use -8px for location "above", or 8px for location "below".
# * alignment-baseline: Default to "alphabetic" for location "above", "hanging" for location "below".
# * text-anchor: "middle"
#
# **Then, if the angle is nonzero:**
#
# * alignment-baseline: "central"
# * text-anchor: "start" or "end", determined by the sign of the angle and whether the location is "above" or "below".

# %%
import toyplot.pdf

# %%
canvas = toyplot.Canvas(width=600, height=200)
numberline = canvas.numberline(min=-100, max=100)
numberline.axis.ticks.show = True
numberline.axis.scale = "log"
# Out:
# <div align="center" class="toyplot" id="t53976d509ef140f0802d16b407b6f13f"><svg height="200.0px" id="t47c17579600c44b5add87788c2aecb64" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 200.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-NumberLine" id="tc9653f92d0ac45ad8d1fc919af3ba0f3"><g class="toyplot-coordinate-events"></g><g class="toyplot-axes-Axis" id="t825c3af6e79a46d795d4272f4e408003" transform="translate(50.0,100.0) rotate(0.0) translate(0,20.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-3" y2="3"></line><line style="" x1="100.0" x2="100.0" y1="-3" y2="3"></line><line style="" x1="200.0" x2="200.0" y1="-3" y2="3"></line><line style="" x1="250.0" x2="250.0" y1="-3" y2="3"></line><line style="" x1="300.0" x2="300.0" y1="-3" y2="3"></line><line style="" x1="400.0" x2="400.0" y1="-3" y2="3"></line><line style="" x1="500.0" x2="500.0" y1="-3" y2="3"></line></g><g><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,6)"><tspan style="dominant-baseline:inherit">-10</tspan><tspan dy="-3.0" style="dominant-baseline:inherit;font-size:7.0px"> 2</tspan></text><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(100.0,6)"><tspan style="dominant-baseline:inherit">-10</tspan><tspan dy="-3.0" style="dominant-baseline:inherit;font-size:7.0px"> 1</tspan></text><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(200.0,6)"><tspan style="dominant-baseline:inherit">-10</tspan><tspan dy="-3.0" style="dominant-baseline:inherit;font-size:7.0px"> 0</tspan></text><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(250.0,6)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(300.0,6)"><tspan style="dominant-baseline:inherit">10</tspan><tspan dy="-3.0" style="dominant-baseline:inherit;font-size:7.0px"> 0</tspan></text><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(400.0,6)"><tspan style="dominant-baseline:inherit">10</tspan><tspan dy="-3.0" style="dominant-baseline:inherit;font-size:7.0px"> 1</tspan></text><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(500.0,6)"><tspan style="dominant-baseline:inherit">10</tspan><tspan dy="-3.0" style="dominant-baseline:inherit;font-size:7.0px"> 2</tspan></text></g></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul></div></div>

# %%
canvas = toyplot.Canvas(width=600, height=200)
numberline = canvas.numberline()
numberline.axis.ticks.show = True
numberline.axis.ticks.labels.angle = 30
numberline.axis.ticks.labels.offset = 12
numberline.axis.ticks.labels.location = "below"
numberline.axis.ticks.labels.style = {"font-size":"16px"}
# Out:
# <div align="center" class="toyplot" id="tc7815f82f99e418397e087de4a1954cc"><svg height="200.0px" id="t3d64c1ee97594c99b7047e521e159a83" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 200.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-NumberLine" id="t1d87d699243142618e017fa91abed41e"><g class="toyplot-coordinate-events"></g><g class="toyplot-axes-Axis" id="t6d94e147a155413199b1c9559a8aea76" transform="translate(50.0,100.0) rotate(0.0) translate(0,20.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-3" y2="3"></line><line style="" x1="250.0" x2="250.0" y1="-3" y2="3"></line><line style="" x1="500.0" x2="500.0" y1="-3" y2="3"></line></g><g><text style="dominant-baseline:central;font-size:16px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,12.0)rotate(-30)"><tspan style="dominant-baseline:inherit">-0.5</tspan></text><text style="dominant-baseline:central;font-size:16px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(250.0,12.0)rotate(-30)"><tspan style="dominant-baseline:inherit">0.0</tspan></text><text style="dominant-baseline:central;font-size:16px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(500.0,12.0)rotate(-30)"><tspan style="dominant-baseline:inherit">0.5</tspan></text></g></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul></div></div>

# %%
canvas = toyplot.Canvas(width=300, height=500)
colormap = toyplot.color.LinearMap(domain_min=0, domain_max=1)
scale = canvas.color_scale(x1="50%", x2="50%", y1="-10%", y2="10%", colormap=colormap)
scale.axis.ticks.labels.angle=-90
scale.axis.ticks.labels.style={"font-size":"16px", "baseline-shift":"10px", "text-anchor":"middle"}
scale.axis.ticks.labels.offset="50px"
scale.axis.ticks.show = True
scale.axis.ticks.locator = toyplot.locator.Explicit(
    [0, 0.5, 1.0],
    [
        "0<br><small>(0.1, 0.03, 0.4)</small>",
        "0.5<br><small>(0.4, 0.5, 0.9)</small>",
        "1.0<br><small>(0.8, 0.9, 1.0)</small>",
    ],
)
# Out:
# <div align="center" class="toyplot" id="t46223d95d123400485855eefb8440b6a"><svg height="500.0px" id="t748d46969db04b959ea5982be59e40a7" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 300.0 500.0" width="300.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-NumberLine" id="t634e01ab6a2740bcaaf9e3028338eb57"><g class="toyplot-coordinate-events"><g class="toyplot-color-Map" id="t72213d73e9ad4e58804eb25607cbd763" transform="translate(150.0,450.0) rotate(-90.0) translate(0,-0.0)"><defs><linearGradient gradientUnits="userSpaceOnUse" id="t48559e18fa984f3c9cfb38954756f19e" x1="0.0" x2="400.0" y1="0" y2="0"><stop offset="0.0" stop-color="rgb(3.14%,18.8%,42%)" stop-opacity="1.0"></stop><stop offset="0.015873015873" stop-color="rgb(3.14%,20.5%,44.4%)" stop-opacity="1.0"></stop><stop offset="0.031746031746" stop-color="rgb(3.14%,22.1%,46.8%)" stop-opacity="1.0"></stop><stop offset="0.047619047619" stop-color="rgb(3.14%,23.8%,49.3%)" stop-opacity="1.0"></stop><stop offset="0.0634920634921" stop-color="rgb(3.14%,25.4%,51.7%)" stop-opacity="1.0"></stop><stop offset="0.0793650793651" stop-color="rgb(3.14%,27%,54.2%)" stop-opacity="1.0"></stop><stop offset="0.0952380952381" stop-color="rgb(3.14%,28.7%,56.6%)" stop-opacity="1.0"></stop><stop offset="0.111111111111" stop-color="rgb(3.14%,30.3%,59%)" stop-opacity="1.0"></stop><stop offset="0.126984126984" stop-color="rgb(3.29%,32%,61.3%)" stop-opacity="1.0"></stop><stop offset="0.142857142857" stop-color="rgb(4.54%,33.6%,62.6%)" stop-opacity="1.0"></stop><stop offset="0.15873015873" stop-color="rgb(5.78%,35.2%,63.8%)" stop-opacity="1.0"></stop><stop offset="0.174603174603" stop-color="rgb(7.03%,36.7%,65.1%)" stop-opacity="1.0"></stop><stop offset="0.190476190476" stop-color="rgb(8.27%,38.3%,66.3%)" stop-opacity="1.0"></stop><stop offset="0.206349206349" stop-color="rgb(9.52%,39.9%,67.6%)" stop-opacity="1.0"></stop><stop offset="0.222222222222" stop-color="rgb(10.8%,41.5%,68.8%)" stop-opacity="1.0"></stop><stop offset="0.238095238095" stop-color="rgb(12%,43.1%,70%)" stop-opacity="1.0"></stop><stop offset="0.253968253968" stop-color="rgb(13.4%,44.7%,71.2%)" stop-opacity="1.0"></stop><stop offset="0.269841269841" stop-color="rgb(15%,46.4%,72%)" stop-opacity="1.0"></stop><stop offset="0.285714285714" stop-color="rgb(16.6%,48%,72.9%)" stop-opacity="1.0"></stop><stop offset="0.301587301587" stop-color="rgb(18.3%,49.7%,73.7%)" stop-opacity="1.0"></stop><stop offset="0.31746031746" stop-color="rgb(19.9%,51.3%,74.6%)" stop-opacity="1.0"></stop><stop offset="0.333333333333" stop-color="rgb(21.6%,52.9%,75.4%)" stop-opacity="1.0"></stop><stop offset="0.349206349206" stop-color="rgb(23.2%,54.6%,76.3%)" stop-opacity="1.0"></stop><stop offset="0.365079365079" stop-color="rgb(24.9%,56.2%,77.1%)" stop-opacity="1.0"></stop><stop offset="0.380952380952" stop-color="rgb(26.6%,57.8%,77.9%)" stop-opacity="1.0"></stop><stop offset="0.396825396825" stop-color="rgb(28.7%,59.2%,78.7%)" stop-opacity="1.0"></stop><stop offset="0.412698412698" stop-color="rgb(30.7%,60.6%,79.5%)" stop-opacity="1.0"></stop><stop offset="0.428571428571" stop-color="rgb(32.8%,62%,80.3%)" stop-opacity="1.0"></stop><stop offset="0.444444444444" stop-color="rgb(34.8%,63.4%,81.1%)" stop-opacity="1.0"></stop><stop offset="0.460317460317" stop-color="rgb(36.9%,64.7%,81.9%)" stop-opacity="1.0"></stop><stop offset="0.47619047619" stop-color="rgb(38.9%,66.1%,82.7%)" stop-opacity="1.0"></stop><stop offset="0.492063492063" stop-color="rgb(40.9%,67.5%,83.5%)" stop-opacity="1.0"></stop><stop offset="0.507936507937" stop-color="rgb(43.2%,68.9%,84.2%)" stop-opacity="1.0"></stop><stop offset="0.52380952381" stop-color="rgb(45.8%,70.3%,84.7%)" stop-opacity="1.0"></stop><stop offset="0.539682539683" stop-color ...

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, padding=20)
axes.x.ticks.show = True
axes.y.ticks.show = True
# Out:
# <div align="center" class="toyplot" id="tc5241af2e35141d3b771a215a8ea6bb5"><svg height="600px" id="t39123a238ffb427a9650fc456e403182" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t40ad57211bcf48d9988d584a7e9aa0b2"><clipPath id="tc5410368d6034e7ebeb275f9c49d2ee2"><rect height="540.0" width="540.0" x="30.0" y="30.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tc5410368d6034e7ebeb275f9c49d2ee2)" style="cursor:crosshair"><rect height="540.0" style="pointer-events:all;visibility:hidden" width="540.0" x="30.0" y="30.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="450.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="495.0" y="67.0"></text></g><g class="toyplot-axes-Axis" id="td741d5ab181a4c45a1aedd1ed1d3bb71" transform="translate(50.0,550.0) rotate(0.0) translate(0,20.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="125.0" x2="125.0" y1="-5" y2="0"></line><line style="" x1="250.0" x2="250.0" y1="-5" y2="0"></line><line style="" x1="375.0" x2="375.0" y1="-5" y2="0"></line><line style="" x1="500.0" x2="500.0" y1="-5" y2="0"></line></g><g><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,6)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(125.0,6)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(250.0,6)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(375.0,6)"><tspan style="dominant-baseline:inherit">500</tspan></text><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(500.0,6)"><tspan style="dominant-baseline:inherit">1000</tspan></text></g></g><g class="toyplot-axes-Axis" id="t726acf7f0bf64db793e8210ad7da4a86" transform="translate(50.0,550.0) rotate(-90.0) translate(0,-20.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="125.0" x2="125.0" y1="0" y2="5"></line><line style="" x1="250.0" x2="250.0" y1="0" y2="5"></line><line style="" x1="375.0" x2="375.0" y1="0" y2="5"></line><line style="" x1="500.0" x2="500.0" y1="0" y2="5"></line></g><g><text style="dominant-baseline:alphabetic;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,-6)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:alphabetic;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(125.0,-6)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:alphabetic;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(250.0,-6)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:alphabetic;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(375.0,-6)"><tspan style="dominant-baseline:inherit">500</tspan></text><text style="dominant-ba ...
# (function()
# {
#   var axes = {"t40ad57211bcf48d9988d584a7e9aa0b2": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 550.0, "min": 50.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 50.0, "min": 550.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coordinates[i].style.visibility = "hidden";
#   }
#
#   for(var axes_id in

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, padding=20)
axes.x.ticks.show = True
axes.y.ticks.show = True
axes.x.ticks.labels.style = {"font-size":"18px"}
axes.y.ticks.labels.style = {"font-size":"18px"}
# Out:
# <div align="center" class="toyplot" id="td379910bb804415e9239ba307f4a5e8d"><svg height="600px" id="t854f823b727f45d9a512c385f62ccaea" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t5e8167bb3fd74524b580614fcf8f675c"><clipPath id="t9b750898e4b34c6eae0f6c68ae4d660f"><rect height="540.0" width="540.0" x="30.0" y="30.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t9b750898e4b34c6eae0f6c68ae4d660f)" style="cursor:crosshair"><rect height="540.0" style="pointer-events:all;visibility:hidden" width="540.0" x="30.0" y="30.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="450.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="495.0" y="67.0"></text></g><g class="toyplot-axes-Axis" id="tb61234ebaa6945738dd80c8189ad5a8a" transform="translate(50.0,550.0) rotate(0.0) translate(0,20.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="125.0" x2="125.0" y1="-5" y2="0"></line><line style="" x1="250.0" x2="250.0" y1="-5" y2="0"></line><line style="" x1="375.0" x2="375.0" y1="-5" y2="0"></line><line style="" x1="500.0" x2="500.0" y1="-5" y2="0"></line></g><g><text style="dominant-baseline:hanging;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,6)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:hanging;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(125.0,6)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:hanging;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(250.0,6)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:hanging;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(375.0,6)"><tspan style="dominant-baseline:inherit">500</tspan></text><text style="dominant-baseline:hanging;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(500.0,6)"><tspan style="dominant-baseline:inherit">1000</tspan></text></g></g><g class="toyplot-axes-Axis" id="t35784704995b458ebd2846200bdee815" transform="translate(50.0,550.0) rotate(-90.0) translate(0,-20.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="125.0" x2="125.0" y1="0" y2="5"></line><line style="" x1="250.0" x2="250.0" y1="0" y2="5"></line><line style="" x1="375.0" x2="375.0" y1="0" y2="5"></line><line style="" x1="500.0" x2="500.0" y1="0" y2="5"></line></g><g><text style="dominant-baseline:alphabetic;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,-6)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:alphabetic;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(125.0,-6)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:alphabetic;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(250.0,-6)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:alphabetic;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(375.0,-6)"><tspan style="dominant-baseline:inherit">500</tspan></text><text style="dominant-ba ...
# (function()
# {
#   var axes = {"t5e8167bb3fd74524b580614fcf8f675c": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 550.0, "min": 50.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 50.0, "min": 550.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coordinates[i].style.visibility = "hidden";
#   }
#
#   for(var axes_id in

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, gutter=100, padding=20)
axes.x.ticks.show = True
axes.y.ticks.show = True
axes.x.ticks.labels.angle = 90
axes.y.ticks.labels.angle = -90
axes.x.ticks.labels.style = {"font-size":"18px"}
axes.y.ticks.labels.style = {"font-size":"18px"}
# Out:
# <div align="center" class="toyplot" id="tdbe63d2f99c84c4793aff8cae4dec583"><svg height="600px" id="t2ffadb4b42cb4ee983e25ccf5e1f22c6" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t44da3ef60a87447b830e0d01348e08f7"><clipPath id="taf3102dc81f64b4296c8d0c33211ade4"><rect height="440.0" width="440.0" x="80.0" y="80.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#taf3102dc81f64b4296c8d0c33211ade4)" style="cursor:crosshair"><rect height="440.0" style="pointer-events:all;visibility:hidden" width="440.0" x="80.0" y="80.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="400.0" y="110.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="445.0" y="117.0"></text></g><g class="toyplot-axes-Axis" id="t1ea0fc832618417bbaef7cfd1cef71ab" transform="translate(100.0,500.0) rotate(0.0) translate(0,20.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="100.0" x2="100.0" y1="-5" y2="0"></line><line style="" x1="200.0" x2="200.0" y1="-5" y2="0"></line><line style="" x1="300.0" x2="300.0" y1="-5" y2="0"></line><line style="" x1="400.0" x2="400.0" y1="-5" y2="0"></line></g><g><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,6)rotate(-90)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,6)rotate(-90)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,6)rotate(-90)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,6)rotate(-90)"><tspan style="dominant-baseline:inherit">500</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(400.0,6)rotate(-90)"><tspan style="dominant-baseline:inherit">1000</tspan></text></g></g><g class="toyplot-axes-Axis" id="t4a2ef0d521d74bd0821d88a9431bd793" transform="translate(100.0,500.0) rotate(-90.0) translate(0,-20.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="100.0" x2="100.0" y1="0" y2="5"></line><line style="" x1="200.0" x2="200.0" y1="0" y2="5"></line><line style="" x1="300.0" x2="300.0" y1="0" y2="5"></line><line style="" x1="400.0" x2="400.0" y1="0" y2="5"></line></g><g><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,-6)rotate(90)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,-6)rotate(90)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,-6)rotate(90)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,-6)rotate(90)"><tspan style="dominant- ...
# (function()
# {
#   var axes = {"t44da3ef60a87447b830e0d01348e08f7": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 500.0, "min": 100.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 100.0, "min": 500.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coor

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, gutter=100, padding=20)
axes.x.ticks.show = True
axes.y.ticks.show = True
axes.x.ticks.labels.angle = 90
axes.y.ticks.labels.angle = -90
axes.x.ticks.labels.offset = "0.5cm"
axes.y.ticks.labels.offset = "0.5cm"
axes.x.ticks.labels.style = {"font-size":"18px"}
axes.y.ticks.labels.style = {"font-size":"18px"}
# Out:
# <div align="center" class="toyplot" id="t781190c93d6447e58294c20fb6143a14"><svg height="600px" id="t47e0ce7a25cc4404a1269a600e0c2ade" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="td02b98f7bad945a58025fa57ac8db535"><clipPath id="t350b31dfad494f09b1544a0c418c081d"><rect height="440.0" width="440.0" x="80.0" y="80.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t350b31dfad494f09b1544a0c418c081d)" style="cursor:crosshair"><rect height="440.0" style="pointer-events:all;visibility:hidden" width="440.0" x="80.0" y="80.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="400.0" y="110.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="445.0" y="117.0"></text></g><g class="toyplot-axes-Axis" id="t48c3b518d74547f08b5973a16ebb497e" transform="translate(100.0,500.0) rotate(0.0) translate(0,20.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="100.0" x2="100.0" y1="-5" y2="0"></line><line style="" x1="200.0" x2="200.0" y1="-5" y2="0"></line><line style="" x1="300.0" x2="300.0" y1="-5" y2="0"></line><line style="" x1="400.0" x2="400.0" y1="-5" y2="0"></line></g><g><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,18.897637800000002)rotate(-90)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,18.897637800000002)rotate(-90)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,18.897637800000002)rotate(-90)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,18.897637800000002)rotate(-90)"><tspan style="dominant-baseline:inherit">500</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(400.0,18.897637800000002)rotate(-90)"><tspan style="dominant-baseline:inherit">1000</tspan></text></g></g><g class="toyplot-axes-Axis" id="t5003e55aea3c4af9a32eee0b05982590" transform="translate(100.0,500.0) rotate(-90.0) translate(0,-20.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="100.0" x2="100.0" y1="0" y2="5"></line><line style="" x1="200.0" x2="200.0" y1="0" y2="5"></line><line style="" x1="300.0" x2="300.0" y1="0" y2="5"></line><line style="" x1="400.0" x2="400.0" y1="0" y2="5"></line></g><g><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,-18.897637800000002)rotate(90)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,-18.897637800000002)rotate(90)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,-18.897637800000002)rotate(90)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline: ...
# (function()
# {
#   var axes = {"td02b98f7bad945a58025fa57ac8db535": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 500.0, "min": 100.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 100.0, "min": 500.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, gutter=100, padding=20)
axes.x.ticks.show = True
axes.y.ticks.show = True
axes.x.ticks.labels.angle = 45
axes.y.ticks.labels.angle = -45
axes.x.ticks.labels.style = {"font-size":"18px"}
axes.y.ticks.labels.style = {"font-size":"18px"}
# Out:
# <div align="center" class="toyplot" id="t74e5be061db64294a988da1e560886ff"><svg height="600px" id="t13380861632d4970a71560b4f9c5aa35" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t0c310485555d4f318cbdd33d4e1072b4"><clipPath id="t6f44cef335534d449368989c39595081"><rect height="440.0" width="440.0" x="80.0" y="80.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t6f44cef335534d449368989c39595081)" style="cursor:crosshair"><rect height="440.0" style="pointer-events:all;visibility:hidden" width="440.0" x="80.0" y="80.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="400.0" y="110.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="445.0" y="117.0"></text></g><g class="toyplot-axes-Axis" id="tb727a55606024e92998bcfacb7ec0f9a" transform="translate(100.0,500.0) rotate(0.0) translate(0,20.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="100.0" x2="100.0" y1="-5" y2="0"></line><line style="" x1="200.0" x2="200.0" y1="-5" y2="0"></line><line style="" x1="300.0" x2="300.0" y1="-5" y2="0"></line><line style="" x1="400.0" x2="400.0" y1="-5" y2="0"></line></g><g><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,6)rotate(-45)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,6)rotate(-45)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,6)rotate(-45)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,6)rotate(-45)"><tspan style="dominant-baseline:inherit">500</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(400.0,6)rotate(-45)"><tspan style="dominant-baseline:inherit">1000</tspan></text></g></g><g class="toyplot-axes-Axis" id="tf28a4d7e10814097a05430cdf358141c" transform="translate(100.0,500.0) rotate(-90.0) translate(0,-20.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="100.0" x2="100.0" y1="0" y2="5"></line><line style="" x1="200.0" x2="200.0" y1="0" y2="5"></line><line style="" x1="300.0" x2="300.0" y1="0" y2="5"></line><line style="" x1="400.0" x2="400.0" y1="0" y2="5"></line></g><g><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,-6)rotate(45)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,-6)rotate(45)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,-6)rotate(45)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,-6)rotate(45)"><tspan style="dominant- ...
# (function()
# {
#   var axes = {"t0c310485555d4f318cbdd33d4e1072b4": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 500.0, "min": 100.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 100.0, "min": 500.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coor

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, gutter=100, padding=20)
axes.x.ticks.show = True
axes.y.ticks.show = True
axes.x.ticks.labels.angle = 45
axes.y.ticks.labels.angle = -45
# Out:
# <div align="center" class="toyplot" id="t95658777f1ea4126a1b9655dcf5da234"><svg height="600px" id="t6fc2e8477fbc4d588f784ba904848874" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t62454525fb38416a997265ec3fa87b49"><clipPath id="t106df811bad14a01801af355acc73045"><rect height="440.0" width="440.0" x="80.0" y="80.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t106df811bad14a01801af355acc73045)" style="cursor:crosshair"><rect height="440.0" style="pointer-events:all;visibility:hidden" width="440.0" x="80.0" y="80.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="400.0" y="110.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="445.0" y="117.0"></text></g><g class="toyplot-axes-Axis" id="tc0901b99252b4d54addf0c044ecd0fda" transform="translate(100.0,500.0) rotate(0.0) translate(0,20.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="100.0" x2="100.0" y1="-5" y2="0"></line><line style="" x1="200.0" x2="200.0" y1="-5" y2="0"></line><line style="" x1="300.0" x2="300.0" y1="-5" y2="0"></line><line style="" x1="400.0" x2="400.0" y1="-5" y2="0"></line></g><g><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,6)rotate(-45)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,6)rotate(-45)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,6)rotate(-45)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,6)rotate(-45)"><tspan style="dominant-baseline:inherit">500</tspan></text><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(400.0,6)rotate(-45)"><tspan style="dominant-baseline:inherit">1000</tspan></text></g></g><g class="toyplot-axes-Axis" id="tbc5fd48ed9f8490f9b14005c28f4a731" transform="translate(100.0,500.0) rotate(-90.0) translate(0,-20.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="100.0" x2="100.0" y1="0" y2="5"></line><line style="" x1="200.0" x2="200.0" y1="0" y2="5"></line><line style="" x1="300.0" x2="300.0" y1="0" y2="5"></line><line style="" x1="400.0" x2="400.0" y1="0" y2="5"></line></g><g><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,-6)rotate(45)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,-6)rotate(45)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,-6)rotate(45)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,-6)rotate(45)"><tspan style="dominant- ...
# (function()
# {
#   var axes = {"t62454525fb38416a997265ec3fa87b49": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 500.0, "min": 100.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 100.0, "min": 500.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coor
