# %%
import toyplot

# %%
canvas = toyplot.Canvas(width="4in")
axes = canvas.axes()
axes.x.ticks.labels.style = {"baseline-shift":0}
axes.x.ticks.labels.offset = (0.5, "cm")
axes.y.ticks.show = True
axes.y.ticks.length = "0.5cm"
# Out:
# <div align="center" class="toyplot" id="tc0014c5e4b094898bfd11071b146e766"><svg height="384.0px" id="tcf0b2a64cfb143488e2134e563b84343" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="384.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t11900ab6338e4bb297e955bde9bb4a27"><toyplot:axes>{"x": [{"domain": {"max": 0.5, "min": -0.5}, "range": {"max": 324.0, "min": 60}, "scale": "linear"}], "y": [{"domain": {"max": 0.5, "min": -0.5}, "range": {"max": 324.0, "min": 60}, "scale": "linear"}]}</toyplot:axes><clipPath id="t6a067577a43f41469b06132dfd27e788"><rect height="284.0" width="284.0" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t6a067577a43f41469b06132dfd27e788)" style="cursor:crosshair"><rect height="284.0" style="pointer-events:all;visibility:hidden
# ...
