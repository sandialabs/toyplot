# %%
import numpy
import toyplot

# %%
data = numpy.random.uniform(size=(12, 2))

canvas = toyplot.Canvas(width=600, height=300)
axes = canvas.cartesian()
mark = axes.plot(data)
markers = mark.markers
axes.label.text = markers[0] + " This year sales " + markers[1] + " Last year sales"
# Out:
# <div align="center" class="toyplot" id="t3a460cce02204affb5507fa194d50306"><svg class="toyplot-canvas-Canvas" height="300.0px" id="t1c8eb3172968452a8c97ecc757130d5b" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 300.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t7a3cb69544844214a5268dbdefc82f5e"><clipPath id="t993bad24b28541188e2127f7011f3562"><rect height="220.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t993bad24b28541188e2127f7011f3562)"><g class="toyplot-mark-Plot" id="t229a9498bb8040729b755dc274ca6e3f" style="fill:none"><g class="toyplot-Series"><path d="M 50.0 85.790564346703519 L 91.666666666666657 60.3792528
# ...

# %%
data = numpy.random.uniform(size=(12, 2))

canvas = toyplot.Canvas(width=600, height=300)
axes = canvas.cartesian()
mark = axes.plot(data)
markers = [mark + toyplot.marker.create(shape="o") for mark in mark.markers]
axes.label.text = markers[0] + " This year sales " + markers[1] + " Last year sales"
# Out:
# <div align="center" class="toyplot" id="t99ae5d8fc44a4b3a950d83e83ef6f386"><svg class="toyplot-canvas-Canvas" height="300.0px" id="td00e102891c44b9d83d05aae441012ec" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 300.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t60c5624fdab643d091753ccafe7485b4"><clipPath id="tff7d5eab62b74a729a32fb43f85177fe"><rect height="220.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#tff7d5eab62b74a729a32fb43f85177fe)"><g class="toyplot-mark-Plot" id="t8eb52c6d288d4b1d8eeb4c08e9a69046" style="fill:none"><g class="toyplot-Series"><path d="M 50.0 50.44914830502232 L 91.666666666666657 245.5186084
# ...
