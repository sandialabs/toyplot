# %%
import numpy
import toyplot.layout

# %% [markdown]
# **Shortest Paths**

# %%
toyplot.layout._floyd_warshall_shortest_path(2, numpy.array([[0, 1]]))
# Out:
# array([[  0.,   1.],
#        [ inf,   0.]])

# %%
toyplot.layout._floyd_warshall_shortest_path(3, numpy.array([[0, 1], [1, 2]]))
# Out:
# array([[  0.,   1.,   2.],
#        [ inf,   0.,   1.],
#        [ inf,  inf,   0.]])

# %%
toyplot.layout._floyd_warshall_shortest_path(3, numpy.array([[0, 1], [1, 2], [2, 0]]))
# Out:
# array([[ 0.,  1.,  2.],
#        [ 2.,  0.,  1.],
#        [ 1.,  2.,  0.]])

# %% [markdown]
# **Adjacency Lists**

# %%
edges = numpy.array([[0, 1]])
toyplot.graph(edges, width=200);
print toyplot.layout._adjacency_list(2, edges)
# Out:
# INFO:toyplot:Graph layout time: 67.079782486 ms
# [[1], []]
# <div align="center" class="toyplot" id="t0060472453514c5a869d59812771651e"><svg height="200.0px" id="tc0f7d88ac2ee4c9b8a8e54c561367f98" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 200.0 200.0" width="200.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t37dd9450a9264c1b9f67d10d703d6465"><clipPath id="tcb3257e5f04f47dea3397d08d336142c"><rect height="100.0" width="100.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tcb3257e5f04f47dea3397d08d336142c)" style="cursor:crosshair"><rect height="100.0" style="pointer-events:all;visibility:hidden" width="100.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Graph" id="te80fcff778d34898ac31173c3ff819f0"><g class="toyplot-Edges"><path d="M 60.0 126.522228571 L 140.0 73.4777714295" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="60.0" cy="126.52222857053314" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="140.0" cy="73.477771429466841" r="2.2360679774997898"></circle></g></g></g></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="50.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="95.0" y="67.0"></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   if(window.CSS !== undefined && window.CSS.supports !== undefined)
#   {
#     if(!window.CSS.supports("alignment-baseline", "middle"))
#     {
#       var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t0060472453514c5a869d59812771651e text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           if(match[1] == "middle")
#           {
#             var style = getComputedStyle(text[i]);
#             var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#             var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#             dy += 0.4 * font_size;
#             text[i].setAttribute("dy", dy);
#           }
#         }
#       }
#     }
#     if(!window.CSS.supports("baseline-shift", "0"))
#     {
#       var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t0060472453514c5a869d59812771651e text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           var style = getComputedStyle(text[i]);
#           var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#           var percent = 0.01 * match[1].substr(0, match[1].length-1);
#           var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#           dy -= percent * font_size
#           text[i].setAttribute("dy", dy);
#         }
#       }
#     }
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"t37dd9450a9264c1b9f67d10d703d6465": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": -0.077171654649813265, "min": -0.66433396657817279}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 140.0, "min": 60.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.70104851071778107, "min": 0.11388619878942155}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 60.0, "min": 140.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coordinates[i].style.visibility = "hidden";
#   }
#
#   for(var axes_id in axes)
#   {
#     var event_target = document.querySelector("#" + axes_id + " .toyplot-coordinate-events");
#     event_target.onmousemove = display_coordinates;
#     event_target.onmouseout = clear_coordinates;
#   }
# })();
# </script></div></div>

# %%
edges = numpy.array([[0, 1], [1, 2]])
toyplot.graph(edges, width=200);
print toyplot.layout._adjacency_list(3, edges)
# Out:
# INFO:toyplot:Graph layout time: 42.2101020813 ms
# [[1], [2], []]
# <div align="center" class="toyplot" id="tef54d0c7d4394cbb99511c6fdb031129"><svg height="200.0px" id="t27f35e2331524368ae98d85dbec3b78a" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 200.0 200.0" width="200.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tc30b17f714aa417e8869e461489879dc"><clipPath id="t6542867fe6a644f38a6defb3575401d7"><rect height="100.0" width="100.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t6542867fe6a644f38a6defb3575401d7)" style="cursor:crosshair"><rect height="100.0" style="pointer-events:all;visibility:hidden" width="100.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Graph" id="t5ac3c2f29e6b4aac9a3d7a84e5519b7e"><g class="toyplot-Edges"><path d="M 60.0 74.1707870496 L 99.9819674137 99.9883558122" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path><path d="M 99.9819674137 99.9883558122 L 140.0 125.82921295" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="60.0" cy="74.170787049609189" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="99.981967413721421" cy="99.988355812164485" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="140.0" cy="125.82921295039083" r="2.2360679774997898"></circle></g></g></g></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="50.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="95.0" y="67.0"></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   if(window.CSS !== undefined && window.CSS.supports !== undefined)
#   {
#     if(!window.CSS.supports("alignment-baseline", "middle"))
#     {
#       var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#tef54d0c7d4394cbb99511c6fdb031129 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           if(match[1] == "middle")
#           {
#             var style = getComputedStyle(text[i]);
#             var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#             var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#             dy += 0.4 * font_size;
#             text[i].setAttribute("dy", dy);
#           }
#         }
#       }
#     }
#     if(!window.CSS.supports("baseline-shift", "0"))
#     {
#       var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#tef54d0c7d4394cbb99511c6fdb031129 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           var style = getComputedStyle(text[i]);
#           var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#           var percent = 0.01 * match[1].substr(0, match[1].length-1);
#           var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#           dy -= percent * font_size
#           text[i].setAttribute("dy", dy);
#         }
#       }
#     }
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"tc30b17f714aa417e8869e461489879dc": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.50591063962397842, "min": -0.60271794822530878}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 140.0, "min": 60.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.77387572958244077, "min": -0.33475285826684653}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 60.0, "min": 140.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coordinates[i].style.visibility = "hidden";
#   }
#
#   for(var axes_id in axes)
#   {
#     var event_target = document.querySelector("#" + axes_id + " .toyplot-coordinate-events");
#     event_target.onmousemove = display_coordinates;
#     event_target.onmouseout = clear_coordinates;
#   }
# })();
# </script></div></div>

# %%
edges = numpy.array([[0, 1], [1, 2], [0, 2]])
toyplot.graph(edges, width=200);
print toyplot.layout._adjacency_list(3, edges)
# Out:
# INFO:toyplot:Graph layout time: 41.699886322 ms
# [[1, 2], [2], []]
# <div align="center" class="toyplot" id="tbb25a74652734d08900ef71e9750a31f"><svg height="200.0px" id="t035abc164a0741839a77d3aa90c574be" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 200.0 200.0" width="200.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t6b1b3b6df0e44cb7b20a799069a1a65c"><clipPath id="t5d31c5cec6174403b5f8bdc68b39ef62"><rect height="100.0" width="100.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t5d31c5cec6174403b5f8bdc68b39ef62)" style="cursor:crosshair"><rect height="100.0" style="pointer-events:all;visibility:hidden" width="100.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Graph" id="tbbbaaafa14414785be51389102db6dd2"><g class="toyplot-Edges"><path d="M 62.2433549596 110.792855067 L 125.294129484 60.0" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path><path d="M 125.294129484 60.0 L 137.75664504 140.0" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path><path d="M 62.2433549596 110.792855067 L 137.75664504 140.0" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="62.243354959633955" cy="110.79285506651492" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="125.29412948441203" cy="60.0" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="137.75664504036604" cy="140.0" r="2.2360679774997898"></circle></g></g></g></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="50.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="95.0" y="67.0"></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   if(window.CSS !== undefined && window.CSS.supports !== undefined)
#   {
#     if(!window.CSS.supports("alignment-baseline", "middle"))
#     {
#       var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#tbb25a74652734d08900ef71e9750a31f text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           if(match[1] == "middle")
#           {
#             var style = getComputedStyle(text[i]);
#             var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#             var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#             dy += 0.4 * font_size;
#             text[i].setAttribute("dy", dy);
#           }
#         }
#       }
#     }
#     if(!window.CSS.supports("baseline-shift", "0"))
#     {
#       var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#tbb25a74652734d08900ef71e9750a31f text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           var style = getComputedStyle(text[i]);
#           var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#           var percent = 0.01 * match[1].substr(0, match[1].length-1);
#           var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#           dy -= percent * font_size
#           text[i].setAttribute("dy", dy);
#         }
#       }
#     }
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"t6b1b3b6df0e44cb7b20a799069a1a65c": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.26424974786779987, "min": -0.30798009488887529}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 140.0, "min": 60.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.34822004130811507, "min": -0.22400980144856}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 60.0, "min": 140.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coordinates[i].style.visibility = "hidden";
#   }
#
#   for(var axes_id in axes)
#   {
#     var event_target = document.querySelector("#" + axes_id + " .toyplot-coordinate-events");
#     e

# %% [markdown]
# **Tree Detection**

# %%
edges = numpy.array([[0, 1]])
toyplot.graph(edges, width=200);
print toyplot.layout._require_tree(toyplot.layout._adjacency_list(2, edges))
# Out:
# INFO:toyplot:Graph layout time: 39.8578643799 ms
# (0, 1)
# <div align="center" class="toyplot" id="tbb0431048f6b4c0a81d8d314b53c24d5"><svg height="200.0px" id="tc77166601c1b4aba93fc7cdf46526ea7" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 200.0 200.0" width="200.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t80075a1471204de690b4d061e5bbb608"><clipPath id="t728fa0c253754fd1858bd90453f43fb1"><rect height="100.0" width="100.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t728fa0c253754fd1858bd90453f43fb1)" style="cursor:crosshair"><rect height="100.0" style="pointer-events:all;visibility:hidden" width="100.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Graph" id="t219a3df01b1942339003bad60e8de901"><g class="toyplot-Edges"><path d="M 60.0 126.522228571 L 140.0 73.4777714295" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="60.0" cy="126.52222857053314" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="140.0" cy="73.477771429466841" r="2.2360679774997898"></circle></g></g></g></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="50.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="95.0" y="67.0"></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   if(window.CSS !== undefined && window.CSS.supports !== undefined)
#   {
#     if(!window.CSS.supports("alignment-baseline", "middle"))
#     {
#       var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#tbb0431048f6b4c0a81d8d314b53c24d5 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           if(match[1] == "middle")
#           {
#             var style = getComputedStyle(text[i]);
#             var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#             var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#             dy += 0.4 * font_size;
#             text[i].setAttribute("dy", dy);
#           }
#         }
#       }
#     }
#     if(!window.CSS.supports("baseline-shift", "0"))
#     {
#       var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#tbb0431048f6b4c0a81d8d314b53c24d5 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           var style = getComputedStyle(text[i]);
#           var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#           var percent = 0.01 * match[1].substr(0, match[1].length-1);
#           var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#           dy -= percent * font_size
#           text[i].setAttribute("dy", dy);
#         }
#       }
#     }
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"t80075a1471204de690b4d061e5bbb608": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": -0.077171654649813265, "min": -0.66433396657817279}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 140.0, "min": 60.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.70104851071778107, "min": 0.11388619878942155}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 60.0, "min": 140.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coordinates[i].style.visibility = "hidden";
#   }
#
#   for(var axes_id in axes)
#   {
#     var event_target = document.querySelector("#" + axes_id + " .toyplot-coordinate-events");
#     event_target.onmousemove = display_coordinates;
#     event_target.onmouseout = clear_coordinates;
#   }
# })();
# </script></div></div>

# %%
edges = numpy.array([[0, 1], [0, 2]])
toyplot.graph(edges, width=200);
print toyplot.layout._require_tree(toyplot.layout._adjacency_list(3, edges))
# Out:
# INFO:toyplot:Graph layout time: 40.5411720276 ms
# (0, 1)
# <div align="center" class="toyplot" id="t2fe1cd56dc1d46a48e0f4b5ef7ab4c4b"><svg height="200.0px" id="t3335add23ac844bca5e00c826c8c29b5" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 200.0 200.0" width="200.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tdbf4a46d80b34841b34bc099d32ee3e5"><clipPath id="te626943ace6742729796905bf6da6124"><rect height="100.0" width="100.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#te626943ace6742729796905bf6da6124)" style="cursor:crosshair"><rect height="100.0" style="pointer-events:all;visibility:hidden" width="100.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Graph" id="tab17ebc70e37473f8f3dabde9c1e7dca"><g class="toyplot-Edges"><path d="M 100.04591717 100.070891739 L 74.0909405051 60.0" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path><path d="M 100.04591717 100.070891739 L 125.909059495 140.0" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="100.04591716988132" cy="100.07089173869471" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="74.090940505144403" cy="60.0" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="125.9090594948556" cy="140.0" r="2.2360679774997898"></circle></g></g></g></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="50.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="95.0" y="67.0"></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   if(window.CSS !== undefined && window.CSS.supports !== undefined)
#   {
#     if(!window.CSS.supports("alignment-baseline", "middle"))
#     {
#       var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t2fe1cd56dc1d46a48e0f4b5ef7ab4c4b text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           if(match[1] == "middle")
#           {
#             var style = getComputedStyle(text[i]);
#             var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#             var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#             dy += 0.4 * font_size;
#             text[i].setAttribute("dy", dy);
#           }
#         }
#       }
#     }
#     if(!window.CSS.supports("baseline-shift", "0"))
#     {
#       var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t2fe1cd56dc1d46a48e0f4b5ef7ab4c4b text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           var style = getComputedStyle(text[i]);
#           var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#           var percent = 0.01 * match[1].substr(0, match[1].length-1);
#           var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#           dy -= percent * font_size
#           text[i].setAttribute("dy", dy);
#         }
#       }
#     }
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"tdbf4a46d80b34841b34bc099d32ee3e5": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.36850752058426328, "min": -0.74162597686835185}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 140.0, "min": 60.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.7295277453913388, "min": -0.38060575206127645}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 60.0, "min": 140.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coordinates[i].style.visibility = "hidden";
#   }
#
#   for(var axes_id in axes)
#   {
#     var event_target = document.querySelector("#" + axes_id + " .toyplot-coordinate-events");
#     event_target.onmousemove = display_coordinates;
#     event_target.onmouseout = clear_coordinates;
#   }
# })();
# </script></div></div>

# %%
edges = numpy.array([[0, 1], [1, 2]])
toyplot.graph(edges, width=200);
print toyplot.layout._require_tree(toyplot.layout._adjacency_list(3, edges))
# Out:
# INFO:toyplot:Graph layout time: 43.3399677277 ms
# (0, 2)
# <div align="center" class="toyplot" id="t84381184f4664c959505bb4e467c6db4"><svg height="200.0px" id="t1de43592a7ef459783f58bad9c78d384" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 200.0 200.0" width="200.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t89443dfc76054a5f9b3160db016caf64"><clipPath id="t16b9c2e008fa4bd6a82d8c0650413b6d"><rect height="100.0" width="100.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t16b9c2e008fa4bd6a82d8c0650413b6d)" style="cursor:crosshair"><rect height="100.0" style="pointer-events:all;visibility:hidden" width="100.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Graph" id="ta7cfa5b930c0406e8b672a993dd1d359"><g class="toyplot-Edges"><path d="M 60.0 74.1707870496 L 99.9819674137 99.9883558122" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path><path d="M 99.9819674137 99.9883558122 L 140.0 125.82921295" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="60.0" cy="74.170787049609189" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="99.981967413721421" cy="99.988355812164485" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="140.0" cy="125.82921295039083" r="2.2360679774997898"></circle></g></g></g></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="50.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="95.0" y="67.0"></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   if(window.CSS !== undefined && window.CSS.supports !== undefined)
#   {
#     if(!window.CSS.supports("alignment-baseline", "middle"))
#     {
#       var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t84381184f4664c959505bb4e467c6db4 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           if(match[1] == "middle")
#           {
#             var style = getComputedStyle(text[i]);
#             var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#             var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#             dy += 0.4 * font_size;
#             text[i].setAttribute("dy", dy);
#           }
#         }
#       }
#     }
#     if(!window.CSS.supports("baseline-shift", "0"))
#     {
#       var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t84381184f4664c959505bb4e467c6db4 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           var style = getComputedStyle(text[i]);
#           var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#           var percent = 0.01 * match[1].substr(0, match[1].length-1);
#           var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#           dy -= percent * font_size
#           text[i].setAttribute("dy", dy);
#         }
#       }
#     }
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"t89443dfc76054a5f9b3160db016caf64": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.50591063962397842, "min": -0.60271794822530878}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 140.0, "min": 60.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.77387572958244077, "min": -0.33475285826684653}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 60.0, "min": 140.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coordinates[i].style.visibility = "hidden";
#   }
#
#   for(var axes_id in axes)
#   {
#     var event_target = document.querySelector("#" + axes_id + " .toyplot-coordinate-events");
#     event_target.onmousemove = display_coordinates;
#     event_target.onmouseout = clear_coordinates;
#   }
# })();
# </script></div></div>

# %%
edges = numpy.array([[0, 1], [1, 2], [2, 1]])
toyplot.graph(edges, width=200, layout=toyplot.layout.FruchtermanReingold(toyplot.layout.CurvedEdges()));
print toyplot.layout._require_tree(toyplot.layout._adjacency_list(3, edges))
# Out:
# INFO:toyplot:Graph layout time: 40.3261184692 ms
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-ca63eef693c6> in <module>()
#       1 edges = numpy.array([[0, 1], [1, 2], [2, 1]])
#       2 toyplot.graph(edges, width=200, layout=toyplot.layout.FruchtermanReingold(toyplot.layout.CurvedEdges()));
# ----> 3 print toyplot.layout._require_tree(toyplot.layout._adjacency_list(3, edges))
#
# /Users/tshead/src/toyplot/toyplot/layout.pyc in _require_tree(targets)
#     269         for target in targets[vertex]:
#     270             mark_visited(target, vdepth + 1)
# --> 271     mark_visited(root)
#     272
#     273     return root, max(depth)
#
# /Users/tshead/src/toyplot/toyplot/layout.pyc in mark_visited(vertex, vdepth)
#     268         visited[vertex] = True
#     269         for target in targets[vertex]:
# --> 270             mark_visited(target, vdepth + 1)
#     271     mark_visited(root)
#     272
#
# /Users/tshead/src/toyplot/toyplot/layout.pyc in mark_visited(vertex, vdepth)
#     268         visited[vertex] = True
#     269         for target in targets[vertex]:
# --> 270             mark_visited(target, vdepth + 1)
#     271     mark_visited(root)
#     272
#
# /Users/tshead/src/toyplot/toyplot/layout.pyc in mark_visited(vertex, vdepth)
#     268         visited[vertex] = True
#     269         for target in targets[vertex]:
# --> 270             mark_visited(target, vdepth + 1)
#     271     mark_visited(root)
#     272
#
# /Users/tshead/src/toyplot/toyplot/layout.pyc in mark_visited(vertex, vdepth)
#     264     def mark_visited(vertex, vdepth=0):
#     265         if visited[vertex]:
# --> 266             raise ValueError("Not a tree.")
#     267         depth.append(vdepth)
#     268         visited[vertex] = True
#
# ValueError: Not a tree.
# <div align="center" class="toyplot" id="t24c9a06a6bab43ca82eb830f8c07b5fd"><svg height="200.0px" id="t5b10ac3806c84c50afa1968f3fd65b0a" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 200.0 200.0" width="200.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tc5b27d03e7a4438586798af47e2cd799"><clipPath id="t512468abb38b4be3b6435225aa0f46ba"><rect height="100.0" width="100.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t512468abb38b4be3b6435225aa0f46ba)" style="cursor:crosshair"><rect height="100.0" style="pointer-events:all;visibility:hidden" width="100.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Graph" id="tb4e02527aa60477591a2b4d5856dfbb5"><g class="toyplot-Edges"><path d="M 60.0 68.8426251956 Q 87.8883650836 79.6693332538 105.211656268 104.059538192" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path><path d="M 105.211656268 104.059538192 Q 126.670503626 112.390204939 140.0 131.157374804" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path><path d="M 140.0 131.157374804 Q 118.541152642 122.826708058 105.211656268 104.059538192" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="60.0" cy="68.842625195594891" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="105.21165626819437" cy="104.05953819249666" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="140.0" cy="131.15737480440509" r="2.2360679774997898"></circle></g></g></g></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="50.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="95.0" y="67.0"></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   if(window.CSS !== undefined && window.CSS.supports !== undefined)
#   {
#     if(!window.CSS.supports("alignment-baseline", "middle"))
#     {
#       var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t24c9a06a6bab43ca82eb830f8c07b5fd text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           if(match[1] == "middle")
#           {
#             var style = getComputedStyle(text[i]);
#             var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#             var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#             dy += 0.4 * font_size;
#             text[i].setAttribute("dy", dy);
#           }
#         }
#       }
#     }
#     if(!window.CSS.supports("baseline-shift", "0"))
#     {
#       var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t24c9a06a6bab43ca82eb830f8c07b5fd text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           var style = getComputedStyle(text[i]);
#           var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#           var percent = 0.01 * match[1].substr(0, match[1].length-1);
#           var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#           dy -= percent * font_size
#           text[i].setAttribute("dy", dy);
#         }
#       }
#     }
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"tc5b27d03e7a4438586798af47e2cd799": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.3958464584840225, "min": -0.53759104995317897}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 140.0, "min": 60.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.72562201868660203, "min": -0.20781548975059957}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 60.0, "min": 140.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coordinates[i].style.visibility = "hidden";
#   }
#
#   for(var axes_id in axes)
#   {
