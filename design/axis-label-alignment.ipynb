# %%
import toyplot.pdf

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, padding=20)
axes.x.ticks.show = True
axes.y.ticks.show = True
# Out:
# <div align="center" class="toyplot" id="t05a0d85df3294b7da7e89c462a2a6c74"><svg height="600px" id="teffeccf7b953439592cc955e352a5fbe" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="ta9da3ffcc3db443cb57ae339b7c78a94"><clipPath id="t9a798efc28614b40accba0a4cda7bc99"><rect height="540.0" width="540.0" x="30.0" y="30.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t9a798efc28614b40accba0a4cda7bc99)" style="cursor:crosshair"><rect height="540.0" style="pointer-events:all;visibility:hidden" width="540.0" x="30.0" y="30.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="450.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="495.0" y="67.0"></text></g><g class="toyplot-axes-Axis" id="tad83785d9d5f4f7499d69b39a5a2b47e" transform="translate(50.0,550.0) rotate(0.0) translate(0,20.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="125.0" x2="125.0" y1="-5" y2="0"></line><line style="" x1="250.0" x2="250.0" y1="-5" y2="0"></line><line style="" x1="375.0" x2="375.0" y1="-5" y2="0"></line><line style="" x1="500.0" x2="500.0" y1="-5" y2="0"></line></g><g><text style="dominant-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,0)translate(0,8.0)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(125.0,0)translate(0,8.0)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(250.0,0)translate(0,8.0)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(375.0,0)translate(0,8.0)"><tspan style="dominant-baseline:inherit">500</tspan></text><text style="dominant-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(500.0,0)translate(0,8.0)"><tspan style="dominant-baseline:inherit">1000</tspan></text></g></g><g class="toyplot-axes-Axis" id="t5cdc34246d5e41179132f0b76dbf2ae9" transform="translate(50.0,550.0) rotate(-90.0) translate(0,-20.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="125.0" x2="125.0" y1="0" y2="5"></line><line style="" x1="250.0" x2="250.0" y1="0" y2="5"></line><line style="" x1="375.0" x2="375.0" y1="0" y2="5"></line><line style="" x1="500.0" x2="500.0" y1="0" y2="5"></line></g><g><text style="dominant-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,0)translate(0,-8.0)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(125.0,0)translate(0,-8.0)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(250.0,0)translate(0,-8.0)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transfor ...
# (function()
# {
#   var axes = {"ta9da3ffcc3db443cb57ae339b7c78a94": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 550.0, "min": 50.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 50.0, "min": 550.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coord

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, padding=20)
axes.x.ticks.show = True
axes.x.ticks.labels.style = {"font-size":"18px"}
axes.y.ticks.show = True
axes.y.ticks.labels.style = {"font-size":"18px"}
# Out:
# <div align="center" class="toyplot" id="t0d50c01bd19e4f04ad0a02adf9d41c34"><svg height="600px" id="t36a24cb837ea4db2bee5487f3194bdf7" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t3ba42986b6a94a4fa6d8a35f27a8e87e"><clipPath id="tc731f02845484de7838dee29f19d7e59"><rect height="540.0" width="540.0" x="30.0" y="30.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tc731f02845484de7838dee29f19d7e59)" style="cursor:crosshair"><rect height="540.0" style="pointer-events:all;visibility:hidden" width="540.0" x="30.0" y="30.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="450.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="495.0" y="67.0"></text></g><g class="toyplot-axes-Axis" id="t955a8c694e3b4191b2ff0fbf078c0695" transform="translate(50.0,550.0) rotate(0.0) translate(0,20.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="125.0" x2="125.0" y1="-5" y2="0"></line><line style="" x1="250.0" x2="250.0" y1="-5" y2="0"></line><line style="" x1="375.0" x2="375.0" y1="-5" y2="0"></line><line style="" x1="500.0" x2="500.0" y1="-5" y2="0"></line></g><g><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,0)translate(0,14.4)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(125.0,0)translate(0,14.4)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(250.0,0)translate(0,14.4)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(375.0,0)translate(0,14.4)"><tspan style="dominant-baseline:inherit">500</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(500.0,0)translate(0,14.4)"><tspan style="dominant-baseline:inherit">1000</tspan></text></g></g><g class="toyplot-axes-Axis" id="te10e4c7078c04467ab342693d04f6d31" transform="translate(50.0,550.0) rotate(-90.0) translate(0,-20.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="125.0" x2="125.0" y1="0" y2="5"></line><line style="" x1="250.0" x2="250.0" y1="0" y2="5"></line><line style="" x1="375.0" x2="375.0" y1="0" y2="5"></line><line style="" x1="500.0" x2="500.0" y1="0" y2="5"></line></g><g><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,0)translate(0,-14.4)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(125.0,0)translate(0,-14.4)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(250.0,0)translate(0,-14.4)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle"  ...
# (function()
# {
#   var axes = {"t3ba42986b6a94a4fa6d8a35f27a8e87e": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 550.0, "min": 50.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 50.0, "min": 550.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toy

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, gutter=100, padding=20)
axes.x.ticks.show = True
axes.x.ticks.labels.angle = 90
axes.x.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "-toyplot-anchor-shift":"-10px", "baseline-shift":0}
axes.y.ticks.show = True
axes.y.ticks.labels.angle = -90
axes.y.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "-toyplot-anchor-shift":"-10px", "baseline-shift":0}
# Out:
# <div align="center" class="toyplot" id="t3ad35fd66e17441983cf61f27206e504"><svg height="600px" id="tfd0eea46851a4f6995c80ead8dc1abe4" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t6d8f528d47ef454bb90e56b2df9d42fe"><clipPath id="t3c065a0374e94b9ba6b4b04c21ec21f2"><rect height="440.0" width="440.0" x="80.0" y="80.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t3c065a0374e94b9ba6b4b04c21ec21f2)" style="cursor:crosshair"><rect height="440.0" style="pointer-events:all;visibility:hidden" width="440.0" x="80.0" y="80.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="400.0" y="110.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="445.0" y="117.0"></text></g><g class="toyplot-axes-Axis" id="te59503c63e8b442db3db3b2d5f40ee93" transform="translate(100.0,500.0) rotate(0.0) translate(0,20.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="100.0" x2="100.0" y1="-5" y2="0"></line><line style="" x1="200.0" x2="200.0" y1="-5" y2="0"></line><line style="" x1="300.0" x2="300.0" y1="-5" y2="0"></line><line style="" x1="400.0" x2="400.0" y1="-5" y2="0"></line></g><g><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,0)rotate(-90)translate(-10.0,0)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,0)rotate(-90)translate(-10.0,0)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,0)rotate(-90)translate(-10.0,0)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,0)rotate(-90)translate(-10.0,0)"><tspan style="dominant-baseline:inherit">500</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(400.0,0)rotate(-90)translate(-10.0,0)"><tspan style="dominant-baseline:inherit">1000</tspan></text></g></g><g class="toyplot-axes-Axis" id="t1cf1420dff534683b363e733cd374f47" transform="translate(100.0,500.0) rotate(-90.0) translate(0,-20.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="100.0" x2="100.0" y1="0" y2="5"></line><line style="" x1="200.0" x2="200.0" y1="0" y2="5"></line><line style="" x1="300.0" x2="300.0" y1="0" y2="5"></line><line style="" x1="400.0" x2="400.0" y1="0" y2="5"></line></g><g><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,0)rotate(90)translate(-10.0,0)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,0)rotate(90)translate(-10.0,0)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,0)rotate(90)translate(-10.0,0)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:mid ...
# (function()
# {
#   var axes = {"t6d8f528d47ef454bb90e56b2df9d42fe": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 500.0, "min": 100.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 100.0, "min": 500.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, gutter=100, padding=20)
axes.x.ticks.show = True
axes.x.ticks.labels.angle = 45
axes.x.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "-toyplot-anchor-shift":"-12px", "baseline-shift":0}
axes.y.ticks.show = True
axes.y.ticks.labels.angle = -45
axes.y.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "-toyplot-anchor-shift":"-12px", "baseline-shift":0}
# Out:
# <div align="center" class="toyplot" id="t1dcb0901319b42f6b1cb6ed05d3847c0"><svg height="600px" id="td6699418bbef4371a416d2dc8ed25542" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tdc643b70dd7b4dfe9890eb3586e365c6"><clipPath id="tcc05b0f83d124b94b5d22f78c31f0448"><rect height="440.0" width="440.0" x="80.0" y="80.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tcc05b0f83d124b94b5d22f78c31f0448)" style="cursor:crosshair"><rect height="440.0" style="pointer-events:all;visibility:hidden" width="440.0" x="80.0" y="80.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="400.0" y="110.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="445.0" y="117.0"></text></g><g class="toyplot-axes-Axis" id="tcbb627117e4a4fac927a5ad31f742883" transform="translate(100.0,500.0) rotate(0.0) translate(0,20.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="100.0" x2="100.0" y1="-5" y2="0"></line><line style="" x1="200.0" x2="200.0" y1="-5" y2="0"></line><line style="" x1="300.0" x2="300.0" y1="-5" y2="0"></line><line style="" x1="400.0" x2="400.0" y1="-5" y2="0"></line></g><g><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,0)rotate(-45)translate(-12.0,0)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,0)rotate(-45)translate(-12.0,0)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,0)rotate(-45)translate(-12.0,0)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,0)rotate(-45)translate(-12.0,0)"><tspan style="dominant-baseline:inherit">500</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(400.0,0)rotate(-45)translate(-12.0,0)"><tspan style="dominant-baseline:inherit">1000</tspan></text></g></g><g class="toyplot-axes-Axis" id="t7af2de3b8e7f441294ff2e1d545e20d9" transform="translate(100.0,500.0) rotate(-90.0) translate(0,-20.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="100.0" x2="100.0" y1="0" y2="5"></line><line style="" x1="200.0" x2="200.0" y1="0" y2="5"></line><line style="" x1="300.0" x2="300.0" y1="0" y2="5"></line><line style="" x1="400.0" x2="400.0" y1="0" y2="5"></line></g><g><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,0)rotate(45)translate(-12.0,0)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,0)rotate(45)translate(-12.0,0)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,0)rotate(45)translate(-12.0,0)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:mid ...
# (function()
# {
#   var axes = {"tdc643b70dd7b4dfe9890eb3586e365c6": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 500.0, "min": 100.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 100.0, "min": 500.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, gutter=100, padding=20)
axes.x.ticks.show = True
axes.x.ticks.labels.angle = 45
axes.x.ticks.labels.offset = "12px"
axes.x.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "baseline-shift":0}
axes.y.ticks.show = True
axes.y.ticks.labels.angle = -45
axes.y.ticks.labels.offset = "-12px"
axes.y.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "baseline-shift":0}
# Out:
# <div align="center" class="toyplot" id="t4f52cc2ba0aa479a8c6eb3e26a3867cf"><svg height="600px" id="tf9b177be5bb7438295235728c6695083" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tcaf9d41cfbdd4f328fb03180c3cff20a"><clipPath id="t041f4b7e7b8e413c9e10df4516096a2a"><rect height="440.0" width="440.0" x="80.0" y="80.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t041f4b7e7b8e413c9e10df4516096a2a)" style="cursor:crosshair"><rect height="440.0" style="pointer-events:all;visibility:hidden" width="440.0" x="80.0" y="80.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="400.0" y="110.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="445.0" y="117.0"></text></g><g class="toyplot-axes-Axis" id="tb997578fcdce4b0c9b8def7229e2de92" transform="translate(100.0,500.0) rotate(0.0) translate(0,20.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="100.0" x2="100.0" y1="-5" y2="0"></line><line style="" x1="200.0" x2="200.0" y1="-5" y2="0"></line><line style="" x1="300.0" x2="300.0" y1="-5" y2="0"></line><line style="" x1="400.0" x2="400.0" y1="-5" y2="0"></line></g><g><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,12.0)rotate(-45)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,12.0)rotate(-45)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,12.0)rotate(-45)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,12.0)rotate(-45)"><tspan style="dominant-baseline:inherit">500</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(400.0,12.0)rotate(-45)"><tspan style="dominant-baseline:inherit">1000</tspan></text></g></g><g class="toyplot-axes-Axis" id="t4a36a15ccd3840f098efadbd78df0d4e" transform="translate(100.0,500.0) rotate(-90.0) translate(0,-20.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="100.0" x2="100.0" y1="0" y2="5"></line><line style="" x1="200.0" x2="200.0" y1="0" y2="5"></line><line style="" x1="300.0" x2="300.0" y1="0" y2="5"></line><line style="" x1="400.0" x2="400.0" y1="0" y2="5"></line></g><g><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,-12.0)rotate(45)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,-12.0)rotate(45)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,-12.0)rotate(45)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:middle;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,-12.0)rotate(45)"><tspa ...
# (function()
# {
#   var axes = {"tcaf9d41cfbdd4f328fb03180c3cff20a": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 500.0, "min": 100.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 100.0, "min": 500.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.len
