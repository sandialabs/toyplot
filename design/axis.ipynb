# %%
import numpy
import toyplot

# %%
canvas = toyplot.Canvas(width=400, height=100, style={"border":"1px solid #dedede"})
axis = canvas.number_line(label="Numberline", scale="log")
axis.axis.ticks.show = True
axis.update_domain(numpy.arange(0, 1000))
#canvas._repr_html_()
# Out:
# <div align="center" class="toyplot" id="t72147d48778e4377bf5d78af55c1b9fa"><svg height="100.0px" id="tf4f73f34cc3e4f09b8912c48732db98e" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border:1px solid #dedede;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 400.0 100.0" width="400.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-NumberLine" id="t1ae127f461c5440dae75796ee7363e0c"><g class="toyplot-coordinate-events"></g><g class="toyplot-axes-Axis" id="t5e6334bd32fc40ed86a040563c467f3a" transform="translate(50.0,50.0) rotate(0.0) translate(0,0)"><line style="" x1="0" x2="299.96523905807857" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-3" y2="3"></line><line style="" x1="60.0" x2="60.0" y1="-3" y2="3"></line><line style="" x1="140.0" x2="140.0" y1="-3" y2="3"></line><line style="" x1="220.0" x2="220.0" y1="-3" y2="3"></line><line style="" x1="300.0" x2="300.0" y1="-3" y2="3"></line></g><g><text style="alignment-baseline:middle;baseline-shift:-100%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,0) rotate(0)" x="0" y="0">0</text><text style="alignment-baseline:middle;baseline-shift:-100%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(60.0,0) rotate(0)" x="0" y="0">10 ⁰</text><text style="alignment-baseline:middle;baseline-shift:-100%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(140.0,0) rotate(0)" x="0" y="0">10 ¹</text><text style="alignment-baseline:middle;baseline-shift:-100%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(220.0,0) rotate(0)" x="0" y="0">10 ²</text><text style="alignment-baseline:middle;baseline-shift:-100%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(300.0,0) rotate(0)" x="0" y="0">10 ³</text></g><text style="alignment-baseline:middle;baseline-shift:-200%;font-weight:bold;stroke:none;text-anchor:middle" x="150.0" y="0">Numberline</text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   if(window.CSS !== undefined && window.CSS.supports !== undefined)
#   {
#     if(!window.CSS.supports("alignment-baseline", "middle"))
#     {
#       var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t72147d48778e4377bf5d78af55c1b9fa text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           if(match[1] == "middle")
#           {
#             var style = getComputedStyle(text[i]);
#             var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#             var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#             dy += 0.4 * font_size;
#             text[i].setAttribute("dy", dy);
#           }
#         }
#       }
#     }
#     if(!window.CSS.supports("baseline-shift", "0"))
#     {
#       var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t72147d48778e4377bf5d78af55c1b9fa text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           var style = getComputedStyle(text[i]);
#           var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#           var percent = 0.01 * match[1].substr(0, match[1].length-1);
#           var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#           dy -= percent * font_size
#           text[i].setAttribute("dy", dy);
#         }
#       }
#     }
#   }
# })();
# </script></div></div>

# %%
colormap = toyplot.color.LinearMap(toyplot.color.Palette(), domain_min=0, domain_max=1)
canvas = toyplot.Canvas(width=400, style={"border":"1px solid #dedede"})
axis = canvas.color_scale(colormap, x1=100, y1=300, x2=300, y2=100, label="Color Scale", scale="linear")
axis.axis.ticks.show = True
# Out:
# <div align="center" class="toyplot" id="tf56b0cde17cc4051a29dccddedc334e0"><svg height="400.0px" id="t43ae53d997844c1da0429ee5b8902433" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border:1px solid #dedede;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 400.0 400.0" width="400.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-ColorScale" id="t07de9e29af8a47a0bdbd63b22f2ac9d5"><g class="toyplot-axes-Axis" id="t451fdda57ca643b0bbbe9e21076af646" transform="translate(100.0,300.0) rotate(-45.0) translate(0,5)"><line style="" x1="0" x2="282.84271247461902" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-3" y2="3"></line><line style="" x1="141.4213562373095" x2="141.4213562373095" y1="-3" y2="3"></line><line style="" x1="282.842712474619" x2="282.842712474619" y1="-3" y2="3"></line></g><g><text style="alignment-baseline:middle;baseline-shift:-100%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,0) rotate(0)" x="0" y="0">0.0</text><text style="alignment-baseline:middle;baseline-shift:-100%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(141.4213562373095,0) rotate(0)" x="0" y="0">0.5</text><text style="alignment-baseline:middle;baseline-shift:-100%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(282.842712474619,0) rotate(0)" x="0" y="0">1.0</text></g><text style="alignment-baseline:middle;baseline-shift:-200%;font-weight:bold;stroke:none;text-anchor:middle" x="141.42135623730951" y="0">Color Scale</text></g><g transform="translate(100.0,300.0) rotate(-45.0)"><rect height="10" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;stroke:none" width="1.109187107743604" x="0.0" y="-10"></rect><rect height="10" style="fill:rgb(41.6%,75.5%,64%);fill-opacity:1.0;stroke:none" width="1.109187107743604" x="1.109187107743604" y="-10"></rect><rect height="10" style="fill:rgb(43.2%,74.9%,63.3%);fill-opacity:1.0;stroke:none" width="1.1091871077436042" x="2.2183742154872079" y="-10"></rect><rect height="10" style="fill:rgb(44.8%,74.4%,62.5%);fill-opacity:1.0;stroke:none" width="1.1091871077436037" x="3.3275613232308121" y="-10"></rect><rect height="10" style="fill:rgb(46.5%,73.8%,61.8%);fill-opacity:1.0;stroke:none" width="1.1091871077436037" x="4.4367484309744158" y="-10"></rect><rect height="10" style="fill:rgb(48.1%,73.2%,61.1%);fill-opacity:1.0;stroke:none" width="1.1091871077436046" x="5.5459355387180196" y="-10"></rect><rect height="10" style="fill:rgb(49.7%,72.7%,60.4%);fill-opacity:1.0;stroke:none" width="1.1091871077436037" x="6.6551226464616242" y="-10"></rect><rect height="10" style="fill:rgb(51.3%,72.1%,59.7%);fill-opacity:1.0;stroke:none" width="1.1091871077436037" x="7.764309754205228" y="-10"></rect><rect height="10" style="fill:rgb(52.9%,71.5%,58.9%);fill-opacity:1.0;stroke:none" width="1.1091871077436046" x="8.8734968619488317" y="-10"></rect><rect height="10" style="fill:rgb(54.5%,70.9%,58.2%);fill-opacity:1.0;stroke:none" width="1.1091871077436029" x="9.9826839696924363" y="-10"></rect><rect height="10" style="fill:rgb(56.1%,70.4%,57.5%);fill-opacity:1.0;stroke:none" width="1.1091871077436046" x="11.091871077436039" y="-10"></rect><rect height="10" style="fill:rgb(57.8%,69.8%,56.8%);fill-opacity:1.0;stroke:none" width="1.1091871077436046" x="12.201058185179644" y="-10"></rect><rect height="10" style="fill:rgb(59.4%,69.2%,56.1%);fill-opacity:1.0;stroke:none" width="1.1091871077436029" x="13.310245292923248" y="-10"></rect><rect height="10" style="fill:rgb(61%,68.7%,55.3%);fill-opacity:1.0;stroke:none" width="1.1091871077436046" x="14.419432400666851" y="-10"></rect><rect height="10" style="fill:rgb(62.6%,68.1%,54.6%);fill-opacity:1.0;stroke:none" width="1.1091871077436029" x="15.52861950841045 ...

# %%
colormap = toyplot.color.diverging("BlueRed", domain_min=-0.5, domain_max=0.5)
canvas = toyplot.Canvas(width=400, style={"border":"1px solid #dedede"})
axes = canvas.axes(gutter=70)
axes.color_scale(colormap, label="Color Scale")
# Out:
# <div align="center" class="toyplot" id="t13651ae0d5f94c7289a65fea44674c26"><svg height="400.0px" id="te0fd4fa957374aeb93416e5725b65cb7" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border:1px solid #dedede;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 400.0 400.0" width="400.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t23784bdcb1054370a823eaa231db18e2"><clipPath id="tb218a62fdf57479b8d352a47a67603c2"><rect height="280.0" width="280.0" x="60.0" y="60.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tb218a62fdf57479b8d352a47a67603c2)" style="cursor:crosshair"><rect height="280.0" style="pointer-events:all;visibility:hidden" width="280.0" x="60.0" y="60.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="230.0" y="80.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="275.0" y="87.0"></text></g><g class="toyplot-axes-Axis" id="taab2d6f5628e436090970bbf971c42c2" transform="translate(70.0,330.0) rotate(0.0) translate(0,10.0)"><line style="" x1="0" x2="260.0" y1="0" y2="0"></line><g><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,0) rotate(0)" x="0" y="0">-0.5</text><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(130.0,0) rotate(0)" x="0" y="0">0.0</text><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(260.0,0) rotate(0)" x="0" y="0">0.5</text></g></g><g class="toyplot-axes-Axis" id="t323a6b64ea854b4eac0e16db0a2e4079" transform="translate(70.0,330.0) rotate(-90.0) translate(0,-10.0)"><line style="" x1="0" x2="260.0" y1="0" y2="0"></line><g><text style="alignment-baseline:middle;baseline-shift:80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,0) rotate(0)" x="0" y="0">-0.5</text><text style="alignment-baseline:middle;baseline-shift:80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(130.0,0) rotate(0)" x="0" y="0">0.0</text><text style="alignment-baseline:middle;baseline-shift:80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(260.0,0) rotate(0)" x="0" y="0">0.5</text></g></g></g><g class="toyplot-axes-ColorScale" id="t440e94ffcf9a42a9ab35920e2bfa5c29"><g class="toyplot-axes-Axis" id="t6aaf63f662bb45e69e4384bcf8fcb239" transform="translate(350.0,330.0) rotate(-90.0) translate(0,5)"><line style="" x1="0" x2="260.0" y1="0" y2="0"></line><g><text style="alignment-baseline:middle;baseline-shift:-100%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,0) rotate(0)" x="0" y="0">-0.5</text><text style="alignment-baseline:middle;baseline-shift:-100%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(130.0,0) rotate(0)" x="0" y="0">0.0</text><text style="alignment-baseline:middle;baseline-shift:-100%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(260.0,0) rotate(0)" x="0" y="0">0.5</text></g><text style="alignment-baseline:middle;baseline-shift:-200%;font-weight:bold;stroke:none;text-anchor:middle" x="130.0" y="0">Color Scale</text></g><g transform="translate(350.0,330.0) rotate(-90.0)"><rect height="10" style="fill:rgb(33.5%,28.3%,75.6%);fill-opacity:1.0;stroke:none" width="1.0196078431372513" x="0.0" y="-10"></rect><rect height="10" style="fill:rgb(33.9%,29%,76.3%);f ...

# %%
canvas = toyplot.Canvas(width=400, style={"border":"1px solid #dedede"})
canvas.matrix(numpy.random.normal(size=(10, 10)), scale=True)
# Out:
# <div align="center" class="toyplot" id="t80c5c97cc7fc48e9922f7590e58bc142"><svg height="400.0px" id="td48100855b6d4cf6a9f3cfc95e0c5350" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border:1px solid #dedede;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 400.0 400.0" width="400.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Table" id="tfe12db3c9f2149a0a202d9efdc46553d"><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="rotate(0,101.0,80.0)" x="101.0" y="80.0">0</text><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="rotate(0,123.0,80.0)" x="123.0" y="80.0">1</text><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="rotate(0,145.0,80.0)" x="145.0" y="80.0">2</text><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="rotate(0,167.0,80.0)" x="167.0" y="80.0">3</text><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="rotate(0,189.0,80.0)" x="189.0" y="80.0">4</text><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="rotate(0,211.0,80.0)" x="211.0" y="80.0">5</text><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="rotate(0,233.0,80.0)" x="233.0" y="80.0">6</text><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="rotate(0,255.0,80.0)" x="255.0" y="80.0">7</text><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="rotate(0,277.0,80.0)" x="277.0" y="80.0">8</text><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="rotate(0,299.0,80.0)" x="299.0" y="80.0">9</text><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:end" x="85.0" y="101.0">0</text><rect height="22.0" style="fill:rgb(49.9%,3.04%,13.7%);fill-opacity:1.0;stroke:none" width="22.0" x="90.0" y="90.0"><title>1.61084611343</title></rect><rect height="22.0" style="fill:rgb(97.2%,74%,62.9%);fill-opacity:1.0;stroke:none" width="22.0" x="112.0" y="90.0"><title>0.499805075481</title></rect><rect height="22.0" style="fill:rgb(94.9%,95.9%,96.5%);fill-opacity:1.0;stroke:none" width="22.0" x="134.0" y="90.0"><title>-0.103729566493</title></rect><rect height="22.0" style="fill:rgb(96.9%,71.8%,60%);fill-opacity:1.0;stroke:none" width="22.0" x="156.0" y="90.0"><title>0.536839000131</title></rect><rect height="22.0" style="fill:rgb(95.4%,96.2%,96.6%);fill-opacity:1.0;stroke:none" width="22.0" x="178.0" y="90.0"><title>-0.0918724892173</title></rect><rect height="22.0" style="fill:rgb(86.5%,91.9%,94.9%);fill-opacity:1.0;stroke:none" width="22.0" x="200.0" y="90.0"><title>-0.3059250725</title></rect><rect height="22.0" style="fill:rgb(3.36%,21.5%,41.8%);fill-opacity:1.0;stroke:none" width="22.0" x="222.0" y="90.0"><title>-1.79405513531</title></rect><rect height="22.0" style="fill:rgb(40.4%,0%,12.2%);fill-opacity:1.0;stroke:none" width="22.0"  ...

# %%
values = numpy.random.choice(3, size=(10, 10))
colormap = toyplot.color.CategoricalMap()
canvas = toyplot.Canvas(width=400, style={"border":"1px solid #dedede"})
canvas.matrix((values, colormap), scale=True)
# Out:
# <div align="center" class="toyplot" id="t8be8293408ad4ca7be7370559919ec35"><svg height="400.0px" id="t9f9aa38cf7864897b2e308c00e19051c" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border:1px solid #dedede;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 400.0 400.0" width="400.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Table" id="t0cff311176a14962ab99f56a845d1ffd"><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="rotate(0,101.0,80.0)" x="101.0" y="80.0">0</text><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="rotate(0,123.0,80.0)" x="123.0" y="80.0">1</text><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="rotate(0,145.0,80.0)" x="145.0" y="80.0">2</text><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="rotate(0,167.0,80.0)" x="167.0" y="80.0">3</text><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="rotate(0,189.0,80.0)" x="189.0" y="80.0">4</text><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="rotate(0,211.0,80.0)" x="211.0" y="80.0">5</text><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="rotate(0,233.0,80.0)" x="233.0" y="80.0">6</text><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="rotate(0,255.0,80.0)" x="255.0" y="80.0">7</text><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="rotate(0,277.0,80.0)" x="277.0" y="80.0">8</text><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="rotate(0,299.0,80.0)" x="299.0" y="80.0">9</text><text style="alignment-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:12px;font-weight:bold;stroke:none;text-anchor:end" x="85.0" y="101.0">0</text><rect height="22.0" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;stroke:none" width="22.0" x="90.0" y="90.0"><title>0.0</title></rect><rect height="22.0" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;stroke:none" width="22.0" x="112.0" y="90.0"><title>0.0</title></rect><rect height="22.0" style="fill:rgb(98.8%,55.3%,38.4%);fill-opacity:1.0;stroke:none" width="22.0" x="134.0" y="90.0"><title>1.0</title></rect><rect height="22.0" style="fill:rgb(98.8%,55.3%,38.4%);fill-opacity:1.0;stroke:none" width="22.0" x="156.0" y="90.0"><title>1.0</title></rect><rect height="22.0" style="fill:rgb(55.3%,62.7%,79.6%);fill-opacity:1.0;stroke:none" width="22.0" x="178.0" y="90.0"><title>2.0</title></rect><rect height="22.0" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;stroke:none" width="22.0" x="200.0" y="90.0"><title>0.0</title></rect><rect height="22.0" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;stroke:none" width="22.0" x="222.0" y="90.0"><title>0.0</title></rect><rect height="22.0" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;stroke:none" width="22.0" x="244.0" y="90.0"><title>0.0</title></rect><rect height="22.0" style="fill:rgb(9 ...
