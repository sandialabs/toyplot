# %%
import numpy
import toyplot

# %%
canvas, axes, mark = toyplot.plot(numpy.linspace(0, 1) ** 2, width=600, height=600 / 1.6, canvas_style={"background-color":"white"})
# Out:
# <div align="center" class="toyplot" id="t184ab45077e3441484494f8f7e584d32"><svg height="375.0px" id="t97727771c7a24ae8a6964a6b42ff68b2" style="background-color:white;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t4b2b1e606cfa4e4f90cd01672fe51abc"><toyplot:axes>{"x": [{"domain": {"max": 50.0, "min": 0}, "range": {"max": 540, "min": 60}, "scale": "linear"}], "y": [{"domain": {"max": 1.0, "min": 0.0}, "range": {"max": 315.0, "min": 60}, "scale": "linear"}]}</toyplot:axes><clipPath id="t5fa02482d1014ed7a0cb3ac1c722c24c"><rect height="275.0" width="500" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t5fa02482d1014ed7a0cb3ac1c722c24c)" style="cursor:crosshair"><rect height="275.0" style="pointer-events:all;visibility:hidden" width="500" x
# ...

# %%
import toyplot.png
toyplot.png.render(canvas, "normal.png")
toyplot.png.render(canvas, "width.png", width=450)
toyplot.png.render(canvas, "height.png", height=100)
toyplot.png.render(canvas, "scale.png", scale=2.0)

# %%
import toyplot.pdf
toyplot.pdf.render(canvas, "normal.pdf")
toyplot.pdf.render(canvas, "width.pdf", width=(4.5, "inches"))
toyplot.pdf.render(canvas, "height.pdf", height=(20, "cm"))
toyplot.pdf.render(canvas, "scale.pdf", scale=2.0)

# %%
import toyplot.eps
toyplot.eps.render(canvas, "normal.eps")
toyplot.eps.render(canvas, "width.eps", width=(4.5, "inches"))
toyplot.eps.render(canvas, "height.eps", height=(20, "cm"))
toyplot.eps.render(canvas, "scale.eps", scale=2.0)
