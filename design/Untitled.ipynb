# %%
import numpy
import toyplot

# %%
canvas = toyplot.Canvas()
axes = canvas.axes()
axes.plot(numpy.sin(numpy.linspace(0, 10)))
axes.x.domain.min = 0
axes.x.domain.max = 20
axes._finalize_domain()
axes._xprojection._segments
# Out:
# [('linear', 0.0, 20.0, 60.0, 540.0)]
# ...

# %%
axes._xprojection(21)
# Out:
# 20.0
