# %% [markdown]
# ## Label Alignment
#
# **Default behavior:**
#
# * location: "above" or "below".  If None, default to "below".
# * offset: If None, use -5px for location "above", or 5px for location "below".
# * alignment-baseline: Default to "alphabetic" for location "above", "hanging" for location "below".
# * text-anchor: "middle"
#
# **Then, if the angle is nonzero:**
#
# * alignment-baseline: "central"
# * text-anchor: "start" or "end", determined by the sign of the angle and whether the location is "above" or "below".

# %%
import toyplot.pdf

# %%
canvas = toyplot.Canvas(width=600, height=200)
numberline = canvas.numberline()
numberline.axis.ticks.show = True
numberline.axis.ticks.labels.angle = 30
#numberline.axis.ticks.labels.style = {"font-size":"16px"}
numberline.axis.ticks.labels.location = "above"
# Out:
# <div align="center" class="toyplot" id="t04b1a7211b2b486bb5f1eeb2055109c6"><svg height="200.0px" id="tc59af5da6c744995905646436ece8394" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 200.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-NumberLine" id="tb4a9b07a40514a29a861f70f719ccdf4"><g class="toyplot-coordinate-events"></g><g class="toyplot-axes-Axis" id="t72219cd236a94ce5bc6dc5aab8def010" transform="translate(50.0,100.0) rotate(0.0) translate(0,20.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-3" y2="3"></line><line style="" x1="250.0" x2="250.0" y1="-3" y2="3"></line><line style="" x1="500.0" x2="500.0" y1="-3" y2="3"></line></g><g><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:start" transform="translate(0.0,-12)rotate(-30)"><tspan style="dominant-baseline:inherit">-0.5</tspan></text><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:start" transform="translate(250.0,-12)rotate(-30)"><tspan style="dominant-baseline:inherit">0.0</tspan></text><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:start" transform="translate(500.0,-12)rotate(-30)"><tspan style="dominant-baseline:inherit">0.5</tspan></text></g></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul></div></div>

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, padding=20)
axes.x.ticks.show = True
axes.y.ticks.show = True
# Out:
# <div align="center" class="toyplot" id="ta051611ea6f7417992c6d9674e833d19"><svg height="600px" id="tcd020048e20f47ca91739d7ba487459b" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="ta777d7ee0b7849eaa78a7c3fe40a0c18"><clipPath id="t13457518944d424a8e77fa4405725ad1"><rect height="540.0" width="540.0" x="30.0" y="30.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t13457518944d424a8e77fa4405725ad1)" style="cursor:crosshair"><rect height="540.0" style="pointer-events:all;visibility:hidden" width="540.0" x="30.0" y="30.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="450.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="495.0" y="67.0"></text></g><g class="toyplot-axes-Axis" id="tb918037768d04f008a634191e3be4969" transform="translate(50.0,550.0) rotate(0.0) translate(0,20.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="125.0" x2="125.0" y1="-5" y2="0"></line><line style="" x1="250.0" x2="250.0" y1="-5" y2="0"></line><line style="" x1="375.0" x2="375.0" y1="-5" y2="0"></line><line style="" x1="500.0" x2="500.0" y1="-5" y2="0"></line></g><g><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,5)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(125.0,5)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(250.0,5)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(375.0,5)"><tspan style="dominant-baseline:inherit">500</tspan></text><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(500.0,5)"><tspan style="dominant-baseline:inherit">1000</tspan></text></g></g><g class="toyplot-axes-Axis" id="t11ff63dfcebb4cf1aab251df5f58f011" transform="translate(50.0,550.0) rotate(-90.0) translate(0,-20.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="125.0" x2="125.0" y1="0" y2="5"></line><line style="" x1="250.0" x2="250.0" y1="0" y2="5"></line><line style="" x1="375.0" x2="375.0" y1="0" y2="5"></line><line style="" x1="500.0" x2="500.0" y1="0" y2="5"></line></g><g><text style="dominant-baseline:alphabetic;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,-5)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:alphabetic;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(125.0,-5)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:alphabetic;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(250.0,-5)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:alphabetic;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(375.0,-5)"><tspan style="dominant-baseline:inherit">500</tspan></text><text style="dominant-ba ...
# (function()
# {
#   var axes = {"ta777d7ee0b7849eaa78a7c3fe40a0c18": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 550.0, "min": 50.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 50.0, "min": 550.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coordinates[i].style.visibility = "hidden";
#   }
#
#   for(var axes_id in

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, padding=20)
axes.x.ticks.show = True
axes.x.ticks.labels.style = {"font-size":"18px"}
axes.y.ticks.show = True
axes.y.ticks.labels.style = {"font-size":"18px"}
# Out:
# <div align="center" class="toyplot" id="tde60f87bc3ab4b989e0651fa95661a28"><svg height="600px" id="t4bb62986d2594944b6a3ba956470c7b9" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="ta3740aaeb24b4bf1956db7425fc6a1de"><clipPath id="t32d995d42bdd4c7b8f7f198a4652f770"><rect height="540.0" width="540.0" x="30.0" y="30.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t32d995d42bdd4c7b8f7f198a4652f770)" style="cursor:crosshair"><rect height="540.0" style="pointer-events:all;visibility:hidden" width="540.0" x="30.0" y="30.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="450.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="495.0" y="67.0"></text></g><g class="toyplot-axes-Axis" id="t6894c7d9eede4a7b831b23f18ca6a4df" transform="translate(50.0,550.0) rotate(0.0) translate(0,20.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="125.0" x2="125.0" y1="-5" y2="0"></line><line style="" x1="250.0" x2="250.0" y1="-5" y2="0"></line><line style="" x1="375.0" x2="375.0" y1="-5" y2="0"></line><line style="" x1="500.0" x2="500.0" y1="-5" y2="0"></line></g><g><text style="dominant-baseline:hanging;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,5)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:hanging;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(125.0,5)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:hanging;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(250.0,5)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:hanging;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(375.0,5)"><tspan style="dominant-baseline:inherit">500</tspan></text><text style="dominant-baseline:hanging;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(500.0,5)"><tspan style="dominant-baseline:inherit">1000</tspan></text></g></g><g class="toyplot-axes-Axis" id="t41df20154c3b4b6ea1f1b907a64bdfe4" transform="translate(50.0,550.0) rotate(-90.0) translate(0,-20.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="125.0" x2="125.0" y1="0" y2="5"></line><line style="" x1="250.0" x2="250.0" y1="0" y2="5"></line><line style="" x1="375.0" x2="375.0" y1="0" y2="5"></line><line style="" x1="500.0" x2="500.0" y1="0" y2="5"></line></g><g><text style="dominant-baseline:alphabetic;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,-5)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:alphabetic;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(125.0,-5)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:alphabetic;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(250.0,-5)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:alphabetic;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(375.0,-5)"><tspan style="dominant-baseline:inherit">500</tspan></text><text style="dominant-ba ...
# (function()
# {
#   var axes = {"ta3740aaeb24b4bf1956db7425fc6a1de": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 550.0, "min": 50.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 50.0, "min": 550.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coordinates[i].style.visibility = "hidden";
#   }
#
#   for(var axes_id in

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, gutter=100, padding=20)
axes.x.ticks.show = True
axes.x.ticks.labels.angle = 90
axes.x.ticks.labels.style = {"font-size":"18px"}
axes.y.ticks.show = True
axes.y.ticks.labels.angle = -90
axes.y.ticks.labels.style = {"font-size":"18px"}
# Out:
# <div align="center" class="toyplot" id="t4b37ec358cbf4d5697687c9a984f59e6"><svg height="600px" id="t94a09a2bf7e94279b5183b8ce57b2302" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t400906755855456cb4110bef749cf9fd"><clipPath id="t66a39b4059444cdcbe781af4a74a2d6e"><rect height="440.0" width="440.0" x="80.0" y="80.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t66a39b4059444cdcbe781af4a74a2d6e)" style="cursor:crosshair"><rect height="440.0" style="pointer-events:all;visibility:hidden" width="440.0" x="80.0" y="80.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="400.0" y="110.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="445.0" y="117.0"></text></g><g class="toyplot-axes-Axis" id="t05c0303781aa4952be3d9101d3e95e31" transform="translate(100.0,500.0) rotate(0.0) translate(0,20.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="100.0" x2="100.0" y1="-5" y2="0"></line><line style="" x1="200.0" x2="200.0" y1="-5" y2="0"></line><line style="" x1="300.0" x2="300.0" y1="-5" y2="0"></line><line style="" x1="400.0" x2="400.0" y1="-5" y2="0"></line></g><g><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,12)rotate(-90)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,12)rotate(-90)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,12)rotate(-90)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,12)rotate(-90)"><tspan style="dominant-baseline:inherit">500</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(400.0,12)rotate(-90)"><tspan style="dominant-baseline:inherit">1000</tspan></text></g></g><g class="toyplot-axes-Axis" id="t71ce3bef483f444ab02ce2ed8882b32f" transform="translate(100.0,500.0) rotate(-90.0) translate(0,-20.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="100.0" x2="100.0" y1="0" y2="5"></line><line style="" x1="200.0" x2="200.0" y1="0" y2="5"></line><line style="" x1="300.0" x2="300.0" y1="0" y2="5"></line><line style="" x1="400.0" x2="400.0" y1="0" y2="5"></line></g><g><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,-12)rotate(90)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,-12)rotate(90)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,-12)rotate(90)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,-12)rotate(90)"><tspan style=" ...
# (function()
# {
#   var axes = {"t400906755855456cb4110bef749cf9fd": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 500.0, "min": 100.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 100.0, "min": 500.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, gutter=100, padding=20)
axes.x.ticks.show = True
axes.x.ticks.labels.angle = 45
axes.x.ticks.labels.style = {"font-size":"18px"}
axes.y.ticks.show = True
axes.y.ticks.labels.angle = -45
axes.y.ticks.labels.style = {"font-size":"18px"}
# Out:
# <div align="center" class="toyplot" id="t0f3f50e162394ee4958d59ec483ea350"><svg height="600px" id="tfe685d214923470ea41254179f922f18" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t77d68ece5fff49b5ab71ae45ee0c970f"><clipPath id="t3fda1e87aeaa4c25aa85019705e9e78e"><rect height="440.0" width="440.0" x="80.0" y="80.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t3fda1e87aeaa4c25aa85019705e9e78e)" style="cursor:crosshair"><rect height="440.0" style="pointer-events:all;visibility:hidden" width="440.0" x="80.0" y="80.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="400.0" y="110.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="445.0" y="117.0"></text></g><g class="toyplot-axes-Axis" id="t425ec2d039954aed88b3039d9f766238" transform="translate(100.0,500.0) rotate(0.0) translate(0,20.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="100.0" x2="100.0" y1="-5" y2="0"></line><line style="" x1="200.0" x2="200.0" y1="-5" y2="0"></line><line style="" x1="300.0" x2="300.0" y1="-5" y2="0"></line><line style="" x1="400.0" x2="400.0" y1="-5" y2="0"></line></g><g><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,12)rotate(-45)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,12)rotate(-45)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,12)rotate(-45)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,12)rotate(-45)"><tspan style="dominant-baseline:inherit">500</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(400.0,12)rotate(-45)"><tspan style="dominant-baseline:inherit">1000</tspan></text></g></g><g class="toyplot-axes-Axis" id="t533ae5e6d3c94f85bf4d9f376e670998" transform="translate(100.0,500.0) rotate(-90.0) translate(0,-20.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="100.0" x2="100.0" y1="0" y2="5"></line><line style="" x1="200.0" x2="200.0" y1="0" y2="5"></line><line style="" x1="300.0" x2="300.0" y1="0" y2="5"></line><line style="" x1="400.0" x2="400.0" y1="0" y2="5"></line></g><g><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,-12)rotate(45)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,-12)rotate(45)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,-12)rotate(45)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:central;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,-12)rotate(45)"><tspan style=" ...
# (function()
# {
#   var axes = {"t77d68ece5fff49b5ab71ae45ee0c970f": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 500.0, "min": 100.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 100.0, "min": 500.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, gutter=100, padding=20)
axes.x.ticks.show = True
axes.x.ticks.labels.angle = 45
#axes.x.ticks.labels.offset = "6px"
#axes.x.ticks.labels.style = {"font-size":"18px"}
axes.y.ticks.show = True
axes.y.ticks.labels.angle = -45
#axes.y.ticks.labels.offset = "-6px"
#axes.y.ticks.labels.style = {"font-size":"18px"}
# Out:
# <div align="center" class="toyplot" id="t2fb70c17b8be458a9354c3a359cf258b"><svg height="600px" id="t2f1159e9a34c4ec9acecf1ac03d303e1" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t016cd51438fa4c1581acc39673d29dcb"><clipPath id="t8c6a51c325a44d8689aeeb856ab8ae79"><rect height="440.0" width="440.0" x="80.0" y="80.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t8c6a51c325a44d8689aeeb856ab8ae79)" style="cursor:crosshair"><rect height="440.0" style="pointer-events:all;visibility:hidden" width="440.0" x="80.0" y="80.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="400.0" y="110.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="445.0" y="117.0"></text></g><g class="toyplot-axes-Axis" id="td72941bfff834a5d907feb7466247e9f" transform="translate(100.0,500.0) rotate(0.0) translate(0,20.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="100.0" x2="100.0" y1="-5" y2="0"></line><line style="" x1="200.0" x2="200.0" y1="-5" y2="0"></line><line style="" x1="300.0" x2="300.0" y1="-5" y2="0"></line><line style="" x1="400.0" x2="400.0" y1="-5" y2="0"></line></g><g><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,12)rotate(-45)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,12)rotate(-45)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,12)rotate(-45)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,12)rotate(-45)"><tspan style="dominant-baseline:inherit">500</tspan></text><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(400.0,12)rotate(-45)"><tspan style="dominant-baseline:inherit">1000</tspan></text></g></g><g class="toyplot-axes-Axis" id="tf7a0779a25b5455e853b334c6fba7c45" transform="translate(100.0,500.0) rotate(-90.0) translate(0,-20.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="100.0" x2="100.0" y1="0" y2="5"></line><line style="" x1="200.0" x2="200.0" y1="0" y2="5"></line><line style="" x1="300.0" x2="300.0" y1="0" y2="5"></line><line style="" x1="400.0" x2="400.0" y1="0" y2="5"></line></g><g><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,-12)rotate(45)"><tspan style="dominant-baseline:inherit">-1000</tspan></text><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,-12)rotate(45)"><tspan style="dominant-baseline:inherit">-500</tspan></text><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,-12)rotate(45)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:central;font-size:10px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,-12)rotate(45)"><tspan style=" ...
# (function()
# {
#   var axes = {"t016cd51438fa4c1581acc39673d29dcb": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 500.0, "min": 100.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 100.0, "min": 500.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
