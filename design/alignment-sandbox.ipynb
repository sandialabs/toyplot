# %%
import toyplot.font
import toyplot.text

text = """The quick brown fox jumped over the lazy <span style="">dogs.</span>"""
text += """<br/>The quick brown fox jumped over the lazy dogs."""
text += """<br/>The quick brown fox jumped over the lazy dogs."""
style = {
    "alignment-baseline": "alphabetic",
    "font-size": "20px",
    "line-height": "200%",
    "text-anchor": "middle",
    "-toyplot-text-layout-visibility": "visible",
    "-toyplot-text-layout-line-visibility": "visible",
    "-toyplot-text-layout-box-visibility": "hidden",
}

canvas = toyplot.Canvas()
axes = canvas.cartesian()
axes.text(0, 0, text, style=style);
# Out:
# <div align="center" class="toyplot" id="ta97190023b4b4bc69b7f7cff67628aaa"><svg class="toyplot-canvas-Canvas" height="600px" id="t97b928eec0e64ce3a770e0a2a03fc021" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="ta96737f7420249279846837dfaa3a742"><clipPath id="t23fd135f7a384f9ea0a2c9fbab86b0ed"><rect height="520.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t23fd135f7a384f9ea0a2c9fbab86b0ed)"><g class="toyplot-mark-Text" id="t2bfe6893df8a46c0bdd6475afc62989c"><g class="toyplot-Series"><g class="toyplot-Datum" transform="translate(300.0,300.0)"><rect fill="none" height="120.0" opacity="0.5" stroke="red" width="423.52" x="-211.76" y="-25.11"></rect><circle fill="red" opacity="0.5" r="3" stroke="none" x="0" y="0"></circle><rect fill="none" height="40.0" opacity="0.5" stroke="green" width="423.52" x="-211.76" y="-25.11"></rect><line fill="none" opacity="0.5" stroke="green" x1="-211.76" x2="211.76" y1="0" y2="0"></line><text style="-toyplot-text-layout-box-visibility:hidden;-toyplot-text-layout-line-visibility:visible;-toyplot-text-layout-visibility:visible;fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;font-family:helvetica;font-size:20.0;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="-211.76" y="0">The quick brown fox jumped over the lazy </text><text style="-toyplot-text-layout-box-visibility:hidden;-toyplot-text-layout-line-visibility:visible;-toyplot-text-layout-visibility:visible;fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;font-family:helvetica;font-size:20.0;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="162.84" y="0">dogs.</text><rect fill="none" height="40.0" opacity="0.5" stroke="green" width="423.52" x="-211.76" y="14.89"></rect><line fill="none" opacity="0.5" stroke="green" x1="-211.76" x2="211.76" y1="40.0" y2="40.0"></line><text style="-toyplot-text-layout-box-visibility:hidden;-toyplot-text-layout-line-visibility:visible;-toyplot-text-layout-visibility:visible;fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;font-family:helvetica;font-size:20.0;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="-211.76" y="40.0">The quick brown fox jumped over the lazy dogs.</text><rect fill="none" height="40.0" opacity="0.5" stroke="green" width="423.52" x="-211.76" y="54.89"></rect><line fill="none" opacity="0.5" stroke="green" x1="-211.76" x2="211.76" y1="80.0" y2="80.0"></line><text style="-toyplot-text-layout-box-visibility:hidden;-toyplot-text-layout-line-visibility:visible;-toyplot-text-layout-visibility:visible;fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;font-family:helvetica;font-size:20.0;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="-211.76" y="80.0">The quick brown fox jumped over the lazy dogs.</text></g></g></g></g><g class="toyplot-coordinates-Axis" id="t534ada48da024bf9a2fa3a7edf34be66" transform="translate(50.0,550.0)translate(0,10.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><g transform="translate(0.0,6)"><text style="font-family:helvetica;font-size:10.0;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-8.615" y="7.18">-0.5</text></g><g transform="translate(250.0,6)"><text style="font-family:helvetica;font-size:10.0;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-6.95" y="7.18">0.0</text></g><g transform="translate(500.0,6)"><text style="font-family:helvetica;font-size:10.0;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-6.95" y="7.18">0.5</text></g></g><g class="toypl ...
#         (function()
#         {
#             function _sign(x)
#             {
#                 return x < 0 ? -1 : x > 0 ? 1 : 0;
#             }
#
#             function _mix(a, b, amount)
#             {
#                 return ((1.0 - amount) * a) + (amount * b);
#             }
#
#             function _log(x, base)
#             {
#                 return Math.log(Math.abs(x)) / Math.log(base);
#             }
#
#             function _in_range(a, x, b)
#             {
#                 var left = Math.min(a, b);
#                 var right = Math.max(a, b);
#                 return left <= x && x <= right;
#             }
#
#             function inside(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(_in_range(segment.range.min, range, segment.range.max))
#                         return true;
#                 }
#                 return false;
#             }
#
#             function to_domain(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#                     {
#                         if(segment.scale == "linear")
#                         {
#                             var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#                             return _mix(segment.domain.min, segment.domain.max, amount)
#                         }
#                         else if(segment.scale[0] == "log")
#                         {
#                             var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#                             var base = segment.scale[1];
#                             return _sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#                         }
#                     }
#                 }
#             }
#
#             function display_coordinates(e)
#             {
#                 var current = svg.createSVGPoint();
#                 current.x = e.clientX;
#                 current.y = e.clientY;
#
#                 for(var axis_id in axes)
#                 {
#                     var axis = document.querySelector("#" + axis_id);
#                     var coordinates =

# %%
fonts = toyplot.font.ReportlabLibrary()
layout = toyplot.text.layout(text, style, fonts)
toyplot.text.dump(layout)
# Out:
# toyplot.text.Layout
#   bottom: 183.824
#   height: 244.088
#   left: -118.24
#   right: 118.24
#   style:
#     -toyplot-text-layout-box-visibility: hidden
#     -toyplot-text-layout-line-visibility: visible
#     -toyplot-text-layout-visibility: visible
#     font-family: helvetica
#     font-size: 32.0
#     vertical-align: baseline
#     white-space: pre
#   top: -60.264
#   width: 236.48
#
#   toyplot.text.LineBox
#     baseline: 0
#     bottom: 35.736
#     height: 96.0
#     left: -96.5
#     right: 96.5
#     style:
#       -toyplot-text-layout-box-visibility: hidden
#       -toyplot-text-layout-line-visibility: visible
#       -toyplot-text-layout-visibility: visible
#       font-family: helvetica
#       font-size: 48.0
#       vertical-align: baseline
#       white-space: pre
#     top: -60.264
#     width: 193.0
#
#     toyplot.text.TextBox
#       baseline: 0
#       bottom: 9.936
#       height: 44.4
#       left: -96.5
#       right: 26.236
#       style:
#         -toyplot-text-layout-box-visibility: hidden
#         -toyplot-text-layout-line-visibility: visible
#         -toyplot-text-layout-visibility: visible
#         font-family: helvetica
#         font-size: 48.0
#         vertical-align: baseline
#         white-space: pre
#       text: 'Alpha'
#       top: -34.464
#       width: 122.736
#
#     toyplot.text.TextBox
#       baseline: 0
#       bottom: 6.624
#       height: 29.6
#       left: 26.236
#       right: 35.132
#       style:
#         -toyplot-text-layout-box-visibility: hidden
#         -toyplot-text-layout-line-visibility: visible
#         -toyplot-text-layout-visibility: visible
#         font-family: helvetica
#         font-size: 32.0
#         vertical-align: baseline
#         white-space: pre
#       text: ' '
#       top: -22.976
#       width: 8.896
#
#     toyplot.text.TextBox
#       baseline: 0
#       bottom: 4.968
#       height: 22.2
#       left: 35.132
#       right: 96.5
#       style:
#         -toyplot-text-layout-box-visibility: hidden
#         -toyplot-text-layout-line-visibility: visible
#         -toyplot-text-layout-visibility: visible
#         font-family: helvetica
#         font-size: 24.0
#         vertical-align: baseline
#         white-space: pre
#       text: 'Alpha'
#       top: -17.232
#       width: 61.368
#
#   toyplot.text.LineBox
#     baseline: 96.0
#     bottom: 119.824
#     height: 64.0
#     left: -70.272
#     right: 70.272
#     style:
#       -toyplot-text-layout-box-visibility: hidden
#       -toyplot-text-layout-line-visibility: visible
#       -toyplot-text-layout-visibility: visible
#       font-family: helvetica
#       font-size: 32.0
#       vertical-align: baseline
#       white-space: pre
#     top: 55.824
#     width: 140.544
#
#     toyplot.text.TextBox
#       baseline: 96.0
#       bottom: 102.624
#       height: 29.6
#       left: -70.272
#       right: 70.272
#       style:
#         -toyplot-text-layout-box-visibility: hidden
#         -toyplot-text-layout-line-visibility: visible
#         -toyplot-text-layout-visibility: visible
#         font-family: helvetica
#         font-size: 32.0
#         vertical-align: baseline
#         white-space: pre
#       text: 'Beta Beta'
#       top: 73.024
#       width: 140.544
#
#   toyplot.text.LineBox
#     baseline: 160.0
#     bottom: 183.824
#     height: 64.0
#     left: -118.24
#     right: 118.24
#     style:
#       -toyplot-text-layout-box-visibility: hidden
#       -toyplot-text-layout-line-visibility: visible
#       -toyplot-text-layout-visibility: visible
#       font-family: helvetica
#       font-size: 32.0
#       vertical-align: baseline
#       white-space: pre
#     top: 119.824
#     width: 236.48
#
#     toyplot.text.TextBox
#       baseline: 160.0
#       bottom: 166.624
#       height: 29.6
#       left: -118.24
#       right: 118.24
#       style:
#         -toyplot-text-layout-box-visibility: hidden
#         -toyplot-text-layout-line-visibility: visible
#         -toyplot-text-layout-visibility: visible
#         font-family: helvetica
#         font-size: 32.0
#         vertical-align: baseline
#         white-space: pre
#       text: 'Gamma Gamma'
#       top: 137.024
#       width: 236.48
