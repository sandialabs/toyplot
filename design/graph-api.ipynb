# %% [markdown]
# Regardless of the kinds of inputs supported by the graph API, the mark itself should have the following characteristics:
#
# * Doesn't care about directionality in the internal representation - it renders every edge it receives, regardless of direction, parallel edges, etc.
# * Vertices support all of the styles / attributes of a scatterplot - color, size, marker, etc.
# * Edges support color, opacity, stroke width attributes.
# * Edges support start / end markers for directionality.
# * Supports multiple layout algorithms.
# * Are graphs added to Cartesian axes?  Or are they a type of axis, like table axes?

# %%
import numpy
import toyplot

# %%
import igraph
graph = igraph.Graph.GRG(100, 0.2)
graph.summary()
coords = numpy.array(graph.layout("auto").coords)
x = coords[:, 0]
y = coords[:, 1]
source = [edge.source for edge in graph.es]
target = [edge.target for edge in graph.es]

# %%
color_map = toyplot.color.LinearMap(toyplot.color.Palette(["white", "yellow", "orange", "red"]))

weight = (1 - numpy.random.power(5, size=len(graph.es))) * 2
#ecolor = numpy.random.uniform(size=len(graph.es))
vcolor = numpy.random.uniform(size=len(graph.vs))
ecolor = ["#666"] * len(graph.es)
for i in numpy.arange(100):
    ecolor[i] = color_map.css(i, domain_min=0, domain_max=100)

canvas = toyplot.Canvas(style={"background-color":"#888"})
axes = canvas.axes(show=False)
axes.graph(x, y, source, target, edge_color=ecolor, edge_opacity=1, vertex_color="#666", edge_width=weight)
# Out:
# <div align="center" class="toyplot" id="tff6d40f9463d46b88b95bf9d358e5602"><svg height="600px" id="t9b24ac46b3894931916405c9d33a821f" style="background-color:#888;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t4ba33b48811b4bcda395069a5369203a"><clipPath id="tc4c704be71ae4dd89688b3deb7b99d9b"><rect height="500.0" width="500.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tc4c704be71ae4dd89688b3deb7b99d9b)" style="cursor:crosshair"><rect height="500.0" style="pointer-events:all;visibility:hidden" width="500.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Graph" id="t2cd50042c6ec44edb94e07d07d49a3b7"><g class="toyplot-Edges"><line style="stroke:rgba(100%,100%,100%,1);stroke-opacity:1.0;stroke-width:0.169463842803" x1="60.0" x2="115.3493434143524" y1="384.602447072686" y2="456.95195836872301"></line><line style="stroke:rgba(100%,100%,97%,1);stroke-opacity:1.0;stroke-width:0.0973675677921" x1="65.419456942278984" x2="75.80220723223259" y1="165.904196502849" y2="111.3823492288965"></line><line style="stroke:rgba(100%,100%,94%,1);stroke-opacity:1.0;stroke-width:0.296004642163" x1="65.419456942278984" x2="101.51849662105047" y1="165.904196502849" y2="246.28463614166898