# %%
import numpy
import toyplot.data

# %%
data = toyplot.data.Table()
data["a"] = numpy.arange(10)
data["b"] = data["a"] ** 2

# %%
canvas = toyplot.Canvas()
axes = canvas.table(data)
axes.cell_axes(0, 0, show=False).plot(numpy.sin(numpy.linspace(0, 10)))
# Out:
# <div align="center" class="toyplot" id="t7e2ec7a2e34445ea807661a589550131"><svg height="600px" id="tb84ad521b9384ca8a806bc0e213ba4a0" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Table" id="t56042187a431426facac1809ccccf0b4"><line style="stroke:black" x1="50.0" x2="50.0" y1="50" y2="550"></line><line style="stroke:black" x1="300.0" x2="300.0" y1="50" y2="550"></line><line style="stroke:black" x1="550.0" x2="550.0" y1="50" y2="550"></line><line style="stroke:black" x1="50" x2="550" y1="50.0" y2="50.0"></line><line style="stroke:black" x1="50" x2="550" y1="100.0" y2="100.0"></line><line style="stroke:black" x1="50" x2="550" y1="150.0" y2="150.0"></line><line style="stroke:black" x1="50" x2="550" y1="200.0" y2="200.0"></line><line style="stroke:black"
# ...
