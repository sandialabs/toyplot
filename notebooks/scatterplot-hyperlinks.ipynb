# %%
import numpy
import toyplot

canvas, axes, mark = toyplot.scatterplot(numpy.random.uniform(size=100), size=10, hyperlink="http://sandia.gov")
# Out:
# <div class="toyplot" id="t268bd589d1134d67a107600e1697a62c" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="600px" id="tc794679c44e945039f965b2b3d083608" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="te80ad86e24c642da97cf002852925eac"><clipPath id="tc86b738e11c44d4d8e49da457c5862d5"><rect height="520.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#tc86b738e11c44d4d8e49da457c5862d5)"><g class="toyplot-mark-Scatterplot" id="tbca3b0d3d2ff4c57949cb9dc8e6bdb16"><g class="toyplot-Series"><a xlink:href="http://sandia.gov"><g class="toyplot-Datum" style="fill:rgb
# ...

# %%
canvas = toyplot.Canvas(width=800, height=200)
axes = canvas.numberline()
mark = axes.scatterplot(numpy.random.uniform(size=50), size=10, hyperlink="http://shead-custom-design.com")
# Out:
# <div class="toyplot" id="t2d679789752f4cc6986ffead2d12a5d1" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="200.0px" id="tc5bb79edb49249979d1b7f17a61f2dde" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 800.0 200.0" width="800.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Numberline" id="t972c0ba8fbc744d88b7c38e2741fb8df"><clipPath id="t5ea2b183e97b4018b931fbc6b36a2d8e"><rect height="40.0" width="700.0" x="0" y="-20.0"></rect></clipPath><g clip-path="url(#t5ea2b183e97b4018b931fbc6b36a2d8e)" transform="translate(50.0,100.0)"><g class="toyplot-mark-Scatterplot" id="t47b5a0ce207a4f4c83708358d37074ff"><g class="toyplot-Series"><a xlink:href="http://shead-custom
# ...
