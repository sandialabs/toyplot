# %%
import pprint

import numpy
import toyplot.mp4

x = numpy.random.normal(size=100)
y = numpy.random.normal(size=len(x))

# %%
canvas = toyplot.Canvas(300, 300, style={"background-color":"white"})
axes = canvas.cartesian()
mark = axes.scatterplot(x, y, size=10)
text_mark = canvas.text(150, 20, " ")

def callback(frame):
    frame.set_datum_text(text_mark, 0, 0,
        text="%s/%s (%.2f)" % (frame.index, frame.count - 1, frame.time),
        style={"font-size": "14px", "font-weight":"bold"},
        )
    
    if frame.index == 0:
        for i in range(len(x)):
            frame.set_datum_style(mark, 0, i, style={"opacity":0.1})
            
    else:
        frame.set_datum_style(mark, 0, frame.index - 1, style={"opacity":1.0})
        
canvas.animate(len(x) + 1, callback)
# Out:
# 102
# <div class="toyplot" id="tf5c42b4b08054f3290b6fd2de81670a9" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="t3cc23ac85c76423aab1209aff9e646ba" preserveAspectRatio="xMidYMid meet" style="background-color:white;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 300.0 300.0" width="300.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tc5d904b769224e5f992fc39c2c05519a"><clipPath id="t9a9a9dafd59c4c228c775495517f4eab"><rect height="220.0" width="220.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t9a9a9dafd59c4c228c775495517f4eab)"><g class="toyplot-mark-Scatterplot" id="t0e6b88c6558c4ba89f730364ed04481c"><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(202.79242701914342, 181.04748620142868)"><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(147.61512598003534, 134.33711147754283)"><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(142.2360695492555, 182.0293742832697)"><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(175.5764469801855, 136.46234554767983)"><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(164.6210084446482, 112.49944770825091)"><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(138.37637701248167, 100.26359265417656)"><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(130.6322268884511, 101.31379656893327)"><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(188.82381087480417, 115.78044898518851)"><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(142.50628714310756, 178.5910048875374)"><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(179.5788659689569, 76.29836251372248)"><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(140.60196526525723, 129.5592242181678)"><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(172.82591651804233, 140.6119472607758)"><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(172.86130084041355, 133.52206725372807)"><circle r="5.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform=" ...

# %%
begin, end, changes = canvas.animation()
print("begin:", begin, "end:", end, "count:", len(changes))
# Out:
# ('begin:', 3.3333333333333335, 'end:', 3.3666666666666667, 'count:', 101)

# %%
for time, change in sorted(changes.items()):
    print("%.2f" % time, type(change))
# Out:
# ('0.00', <type 'collections.defaultdict'>)
# ('0.03', <type 'collections.defaultdict'>)
# ('0.07', <type 'collections.defaultdict'>)
# ('0.10', <type 'collections.defaultdict'>)
# ('0.13', <type 'collections.defaultdict'>)
# ('0.17', <type 'collections.defaultdict'>)
# ('0.20', <type 'collections.defaultdict'>)
# ('0.23', <type 'collections.defaultdict'>)
# ('0.27', <type 'collections.defaultdict'>)
# ('0.30', <type 'collections.defaultdict'>)
# ('0.33', <type 'collections.defaultdict'>)
# ('0.37', <type 'collections.defaultdict'>)
# ('0.40', <type 'collections.defaultdict'>)
# ('0.43', <type 'collections.defaultdict'>)
# ('0.47', <type 'collections.defaultdict'>)
# ('0.50', <type 'collections.defaultdict'>)
# ('0.53', <type 'collections.defaultdict'>)
# ('0.57', <type 'collections.defaultdict'>)
# ('0.60', <type 'collections.defaultdict'>)
# ('0.63', <type 'collections.defaultdict'>)
# ('0.67', <type 'collections.defaultdict'>)
# ('0.70', <type 'collections.defaultdict'>)
# ('0.73', <type 'collections.defaultdict'>)
# ('0.77', <type 'collections.defaultdict'>)
# ('0.80', <type 'collections.defaultdict'>)
# ('0.83', <type 'collections.defaultdict'>)
# ('0.87', <type 'collections.defaultdict'>)
# ('0.90', <type 'collections.defaultdict'>)
# ('0.93', <type 'collections.defaultdict'>)
# ('0.97', <type 'collections.defaultdict'>)
# ('1.00', <type 'collections.defaultdict'>)
# ('1.03', <type 'collections.defaultdict'>)
# ('1.07', <type 'collections.defaultdict'>)
# ('1.10', <type 'collections.defaultdict'>)
# ('1.13', <type 'collections.defaultdict'>)
# ('1.17', <type 'collections.defaultdict'>)
# ('1.20', <type 'collections.defaultdict'>)
# ('1.23', <type 'collections.defaultdict'>)
# ('1.27', <type 'collections.defaultdict'>)
# ('1.30', <type 'collections.defaultdict'>)
# ('1.33', <type 'collections.defaultdict'>)
# ('1.37', <type 'collections.defaultdict'>)
# ('1.40', <type 'collections.defaultdict'>)
# ('1.43', <type 'collections.defaultdict'>)
# ('1.47', <type 'collections.defaultdict'>)
# ('1.50', <type 'collections.defaultdict'>)
# ('1.53', <type 'collections.defaultdict'>)
# ('1.57', <type 'collections.defaultdict'>)
# ('1.60', <type 'collections.defaultdict'>)
# ('1.63', <type 'collections.defaultdict'>)
# ('1.67', <type 'collections.defaultdict'>)
# ('1.70', <type 'collections.defaultdict'>)
# ('1.73', <type 'collections.defaultdict'>)
# ('1.77', <type 'collections.defaultdict'>)
# ('1.80', <type 'collections.defaultdict'>)
# ('1.83', <type 'collections.defaultdict'>)
# ('1.87', <type 'collections.defaultdict'>)
# ('1.90', <type 'collections.defaultdict'>)
# ('1.93', <type 'collections.defaultdict'>)
# ('1.97', <type 'collections.defaultdict'>)
# ('2.00', <type 'collections.defaultdict'>)
# ('2.03', <type 'collections.defaultdict'>)
# ('2.07', <type 'collections.defaultdict'>)
# ('2.10', <type 'collections.defaultdict'>)
# ('2.13', <type 'collections.defaultdict'>)
# ('2.17', <type 'collections.defaultdict'>)
# ('2.20', <type 'collections.defaultdict'>)
# ('2.23', <type 'collections.defaultdict'>)
# ('2.27', <type 'collections.defaultdict'>)
# ('2.30', <type 'collections.defaultdict'>)
# ('2.33', <type 'collections.defaultdict'>)
# ('2.37', <type 'collections.defaultdict'>)
# ('2.40', <type 'collections.defaultdict'>)
# ('2.43', <type 'collections.defaultdict'>)
# ('2.47', <type 'collections.defaultdict'>)
# ('2.50', <type 'collections.defaultdict'>)
# ('2.53', <type 'collections.defaultdict'>)
# ('2.57', <type 'collections.defaultdict'>)
# ('2.60', <type 'collections.defaultdict'>)
# ('2.63', <type 'collections.defaultdict'>)
# ('2.67', <type 'collections.defaultdict'>)
# ('2.70', <type 'collections.defaultdict'>)
# ('2.73', <type 'collections.defaultdict'>)
# ('2.77', <type 'collections.defaultdict'>)
# ('2.80', <type 'collections.defaultdict'>)
# ('2.83', <type 'collections.defaultdict'>)
# ('2.87', <type 'collections.defaultdict'>)
# ('2.90', <type 'collections.defaultdict'>)
# ('2.93', <type 'collections.defaultdict'>)
# ('2.97', <type 'collections.defaultdict'>)
# ('3.00', <type 'collections.defaultdict'>)
# ('3.03', <type 'collections.defaultdict'>)
# ('3.07', <type 'collections.defaultdict'>)
# ('3.10', <type 'collections.defaultdict'>)
# ('3.13', <type 'collections.defaultdict'>)
# ('3.17', <type 'collections.defaultdict'>)
# ('3.20', <type 'collections.defaultdict'>)
# ('3.23', <type 'collections.defaultdict'>)
# ('3.27', <type 'collections.defaultdict'>)
# ('3.30', <type 'collections.defaultdict'>)
# ('3.33', <type 'collections.defaultdict'>)

# %% [raw]
# def progress(frame):
#     print(frame, end=" ")
#
# toyplot.mp4.render(canvas, "test.mp4", progress=progress)
