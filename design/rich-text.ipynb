# %%
import numpy
import toyplot
canvas = toyplot.Canvas(width=600, height=200, style={"border":"1px solid lightgray"})
canvas.text(300, 100, "100<sup>-53</sup><br>H<sub>2</sub>O", style={"font-size":"32px"}, angle=0);
# Out:
# <div align="center" class="toyplot" id="t80e292be32484437b176271caab104eb"><svg height="200.0px" id="t78780a899bbc45c2afb15aac8ff5a770" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border:1px solid lightgray;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 200.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-mark-Text" id="tc2ba283e55274b86820f29247dede424" style="alignment-baseline:middle;font-size:32px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:32px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(300.0,100.0)"><tspan dominant-baseline="inherit">100</tspan><tspan dominant-baseli
# ...

# %%
canvas = toyplot.Canvas(width=600, height=200, style={"border":"1px solid lightgray"})
canvas.text(300, 100, "foo<b><i>bar</i><br>baz</b>blah", style={"font-size":"32px"});
# Out:
# <div align="center" class="toyplot" id="t6042d9286d294cd980d5ca017d77a7c8"><svg height="200.0px" id="tdd899cb1bcc348249ad8997abe016c94" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border:1px solid lightgray;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 200.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-mark-Text" id="t9dd80ef2d261496ab25e7ab86e17fbf8" style="alignment-baseline:middle;font-size:32px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:32px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(300.0,100.0)"><tspan dominant-baseline="inherit">foo</tspan><tspan dominant-baseli
# ...

# %%
canvas = toyplot.Canvas(width=600, height=200, style={"border":"1px solid lightgray"})
canvas.text(300, 100, "2<sup>10<sup>awesome!</sup></sup>", style={"font-size":"32px"});
# Out:
# <div align="center" class="toyplot" id="t98e40f60dade419f89742f177bf825cf"><svg height="200.0px" id="t5d2d2902d06a4ce0971138a0a8643e7c" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border:1px solid lightgray;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 200.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-mark-Text" id="t2f7a14baf06a46c19c7026c6a24c0c94" style="alignment-baseline:middle;font-size:32px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:32px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(300.0,100.0)"><tspan dominant-baseline="inherit">2</tspan><tspan dominant-baseline
# ...

# %%
canvas = toyplot.Canvas(width=600, height=200, style={"border":"1px solid lightgray"})
canvas.text(300, 100, "0.567832<br><small>(243, 128, 19)</small>", style={"font-size":"16px"});
# Out:
# <div align="center" class="toyplot" id="tb2b4bdd2aae3432d915b2c30fc8b63d7"><svg height="200.0px" id="te1c633d5055e42d3a3036d0989c4b54b" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border:1px solid lightgray;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 200.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-mark-Text" id="tcde2e616afaa45228177f8fa671628dc" style="alignment-baseline:middle;font-size:16px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:16px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(300.0,100.0)"><tspan dominant-baseline="inherit">0.567832</tspan><tspan dominant-b
# ...

# %%
toyplot.plot(numpy.linspace(0, 1)**2, label="My<br>plot.");
# Out:
# <div align="center" class="toyplot" id="t0ac0cfa66c4e4377b65c5f10215b264b"><svg height="600px" id="t9470fc28138c46e2adf8e84e1e02aeaf" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t8489d3f792d647ee8d38c81ec0268346"><clipPath id="t1ebb49d3dfda4af982f45e2053a8c542"><rect height="520.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t1ebb49d3dfda4af982f45e2053a8c542)" style="cursor:crosshair"><rect height="520.0" style="pointer-events:all;visibility:hidden" width="520.0" x="40.0" y="40.0"></rect><g class="toyplot-mark-Plot" id="ted6aec5fb24145f59537437cc84fc57d" style="fill:none"><g class="toyplo
# ...

# %%
canvas, axes, mark = toyplot.plot(numpy.sin(numpy.linspace(0, 20, 200)))
axes.label.text = "Howdy!"
axes.label.style = {"fill":"red"}
# Out:
# <div align="center" class="toyplot" id="tdfeeffe2175e4af2b29049551fe43d9f"><svg height="600px" id="t41810cd3fd24409695e3a83b7317f059" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t3b947276e96a47ee88978862ca931997"><clipPath id="tbb69e44614c04a89b6bc2a91902722c7"><rect height="520.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tbb69e44614c04a89b6bc2a91902722c7)" style="cursor:crosshair"><rect height="520.0" style="pointer-events:all;visibility:hidden" width="520.0" x="40.0" y="40.0"></rect><g class="toyplot-mark-Plot" id="tac28ce03d43343d5b62866d5f2972ea7" style="fill:none"><g class="toyplo
# ...

# %%
import toyplot.svg
toyplot.svg.render(canvas, "test.svg")
