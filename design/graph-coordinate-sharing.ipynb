# %% [markdown]
# ## Overview
#
# To facilitate graph analysis, we need to support sharing layouts between graphs, something I haven't seen done very well elsewhere.  In particular, it should be possible to:
#
# * &#x2713; "Pin" a few key vertices while letting the layout handle the remaining vertices.
# * &#x2713; Render a graph using another graph's vertices, whether it is a superset or subset of the original.
# * &#x2713; An implicit requirement is the ability to perform a layout on some vertices while leaving others unchanged.
# * &#x2713; Another implicit requirement is the ability to supply disconnected vertex ids to be merged with the induced ids.

# %% [markdown]
# So the process to layout graph $G_1$, given an (optional) layout of graph $G_0$ is (I think):
#
# * Extract the edges for $G_1$.
#     * Either an $E \times 2$ matrix, or
#     * Two $|E|$ vectors.
# * Identify the vertex ids $V_1$ induced by those edges.
# * Merge optional user-supplied vertex ids with $V_1$ (to allow for disconnected vertices).
# * Create a set of completely masked vertex coordinates, $V_{C_1}$.
# * If the user supplied an "other" toyplot.layout.GraphLayout object from $G_0$, use the $V_0$ vertex ids to merge $V_{C_0}$ coordinates into $V_{C_1}$.
# * If the user supplied a set of external vertex coordinates $V_{C_{external}}$ with length $|V_1|$, merge them into $V_{C_1}$.
# * Apply a layout algorithm to any remaining masked values in $V_{C_1}$.

# %% [markdown]
# Allowed input formats:
#
# * toyplot.graph(edges, [vids], [olayout], [vcoordinates])
# * toyplot.graph(sources, targets, [vids], [olayout], [vcoordinates])

# %%
import numpy
import toyplot.color
import toyplot.generate

# %%
numpy.random.seed(1234)

# %%
colormap = toyplot.color.LinearMap(toyplot.color.Palette(["white", "yellow", "red"]))

# %%
G0 = toyplot.generate.prufer_tree(numpy.random.choice(4, 12))
G1 = G0[:-4]
G2 = G0[4:]

# %%
canvas = toyplot.Canvas(width=1000, height=500)

axes = canvas.axes(grid=(1, 2, 0), show=False)
axes.aspect = "expand-domain"
mark = axes.graph(
    G0,
    vcolor=colormap,
    vstyle={"stroke":"black"},
    vsize=20,
    ecolor="black",
    eopacity=0.2,
);
axes.text(mark.vcoordinates.T[0], mark.vcoordinates.T[1], mark.vids, color="black")

vcoordinates = numpy.ma.masked_all((mark.vcount, 2))
vcoordinates[0] = (-1, 0)
vcoordinates[1] = (0, 0)
vcoordinates[2] = (1, 0)

axes = canvas.axes(grid=(1, 2, 1), show=False)
axes.aspect = "expand-domain"
mark = axes.graph(
    G0,
    vcoordinates=vcoordinates,
    vcolor=colormap,
    vstyle={"stroke":"black"},
    vsize=20,
    ecolor="black",
    eopacity=0.2,
);
axes.text(mark.vcoordinates.T[0], mark.vcoordinates.T[1], mark.vids, color="black");

print "Pinned Vertices:"
# Out:
# INFO:toyplot:Graph layout time: 61.9859695435 ms
# INFO:toyplot:Graph layout time: 44.4211959839 ms
# Pinned Vertices:
# <div align="center" class="toyplot" id="t6f8d4e13ef4d4e07a7426399b2724ac8"><svg height="500.0px" id="tfa59bfad3adf4c7aa905ee7acbd5320d" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 1000.0 500.0" width="1000.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t3c9d460cd2b04f29a1aac06c190d86ac"><clipPath id="t6d15a74c04ee4e529e0dfa0515bd2195"><rect height="400.0" width="400.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t6d15a74c04ee4e529e0dfa0515bd2195)" style="cursor:crosshair"><rect height="400.0" style="pointer-events:all;visibility:hidden" width="400.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Graph" id="tb823c4a4cb3b47e0a5c23dd4be9108b3"><g class="toyplot-Edges"><path d="M 215.573731617 133.42753133 L 242.493378334 65.8163265306" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 215.573731617 133.42753133 L 155.008663421 103.445883594" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 295.555783634 266.39774148 L 361.26241402 278.175819181" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 212.433137819 252.044108984 L 295.555783634 266.39774148" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 195.525383064 363.373933839 L 138.73758598 402.393053961" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 195.525383064 363.373933839 L 184.727696167 434.183673469" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 195.525383064 363.373933839 L 238.020654977 415.515031381" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 212.433137819 252.044108984 L 195.525383064 363.373933839" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 215.573731617 133.42753133 L 191.433202078 66.3145542475" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 212.433137819 252.044108984 L 160.620757752 279.871632398" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 215.573731617 133.42753133 L 276.464160976 106.376937229" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 212.433137819 252.044108984 L 215.573731617 133.42753133" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 212.433137819 252.044108984 L 156.668375041 227.19482479" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="195.52538306382877" cy="363.37393383941713" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,84.6%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="212.4331378191514" cy="252.04410898445707" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,69.2%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="295.55578363393721" cy="266.39774147950794" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,53.8%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="215.57373161679027" cy="133.42753133021463" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,38.5%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="242.49337833372502" cy="65.8163265306123 ...

# %%
#G0_layout = toyplot.layout.graph(G0)

canvas = toyplot.Canvas(width=1000, height=500)

axes = canvas.axes(grid=(1, 2, 0), show=False)
axes.aspect = "expand-domain"
mark = axes.graph(
    G0,
    vcolor=colormap,
    vstyle={"stroke":"black"},
    vsize=20,
    ecolor="black",
    eopacity=0.2,
);
axes.text(mark.vcoordinates.T[0], mark.vcoordinates.T[1], mark.vids, color="black")

axes = canvas.axes(grid=(1, 2, 1), show=False)
axes.aspect = "expand-domain"
mark = axes.graph(
    G1,
    olayout = mark,
    vcolor=colormap,
    vstyle={"stroke":"black"},
    vsize=20,
    ecolor="black",
    eopacity=0.2,
);
axes.text(mark.vcoordinates.T[0], mark.vcoordinates.T[1], mark.vids, color="black");

print "Shared Layout (Subset):"
# Out:
# INFO:toyplot:Graph layout time: 46.9298362732 ms
# INFO:toyplot:Graph layout time: 43.4799194336 ms
# Shared Layout (Subset):
# <div align="center" class="toyplot" id="t000fef80edf8485c9ac8cddf89c6f4f2"><svg height="500.0px" id="t21a2a882e6814fea9360697ba1e59585" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 1000.0 500.0" width="1000.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t4b478482030d485bb43d01485c397ada"><clipPath id="t16b66608a297482592b467bb1a0c0705"><rect height="400.0" width="400.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t16b66608a297482592b467bb1a0c0705)" style="cursor:crosshair"><rect height="400.0" style="pointer-events:all;visibility:hidden" width="400.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Graph" id="t912fdb1a4c6e43adaaa5a26a655655e1"><g class="toyplot-Edges"><path d="M 215.573731617 133.42753133 L 242.493378334 65.8163265306" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 215.573731617 133.42753133 L 155.008663421 103.445883594" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 295.555783634 266.39774148 L 361.26241402 278.175819181" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 212.433137819 252.044108984 L 295.555783634 266.39774148" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 195.525383064 363.373933839 L 138.73758598 402.393053961" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 195.525383064 363.373933839 L 184.727696167 434.183673469" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 195.525383064 363.373933839 L 238.020654977 415.515031381" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 212.433137819 252.044108984 L 195.525383064 363.373933839" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 215.573731617 133.42753133 L 191.433202078 66.3145542475" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 212.433137819 252.044108984 L 160.620757752 279.871632398" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 215.573731617 133.42753133 L 276.464160976 106.376937229" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 212.433137819 252.044108984 L 215.573731617 133.42753133" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 212.433137819 252.044108984 L 156.668375041 227.19482479" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="195.52538306382877" cy="363.37393383941713" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,84.6%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="212.4331378191514" cy="252.04410898445707" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,69.2%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="295.55578363393721" cy="266.39774147950794" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,53.8%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="215.57373161679027" cy="133.42753133021463" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,38.5%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="242.49337833372502" cy="65.8163265306123 ...

# %%
canvas = toyplot.Canvas(width=1000, height=500)

axes = canvas.axes(grid=(1, 2, 0), show=False)
axes.aspect = "expand-domain"
mark = axes.graph(
    G2,
    vcolor=colormap,
    vstyle={"stroke":"black"},
    vsize=20,
    ecolor="black",
    eopacity=0.2,
);
axes.text(mark.vcoordinates.T[0], mark.vcoordinates.T[1], mark.vids, color="black")

axes = canvas.axes(grid=(1, 2, 1), show=False)
axes.aspect = "expand-domain"
mark = axes.graph(
    G0,
    olayout = mark,
    vcolor=colormap,
    vstyle={"stroke":"black"},
    vsize=20,
    ecolor="black",
    eopacity=0.2,
);
axes.text(mark.vcoordinates.T[0], mark.vcoordinates.T[1], mark.vids, color="black");

print "Shared Layout (Superset):"
# Out:
# INFO:toyplot:Graph layout time: 46.7410087585 ms
# INFO:toyplot:Graph layout time: 44.3050861359 ms
# Shared Layout (Superset):
# <div align="center" class="toyplot" id="tca5681de4517441db49561ec77d4f398"><svg height="500.0px" id="t13d0933e8b5d48948e9f0a211714bd3d" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 1000.0 500.0" width="1000.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="