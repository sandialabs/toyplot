# %%
import numpy
import toyplot

# %%
numpy.random.seed(1234)
y = numpy.column_stack([numpy.cumsum(numpy.random.normal(loc=0.05, size=100)) for i in range(5)])

# %%
canvas = toyplot.Canvas()
axes = canvas.axes()
mark = axes.plot(y, title=[1, 2, 3, 4, 5])
# Out:
# <div align="center" class="toyplot" id="t6cfcb13b4ac0454a9757a6b542066320"><svg height="600px" id="te91a9aa595134bf08b54b6d90b04cb92" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tade4812647b346169118d91b6e6e6e11"><toyplot:axes>{"x": [{"domain": {"max": 100.0, "min": 0}, "range": {"max": 540, "min": 60}, "scale": "linear"}], "y": [{"domain": {"max": 22.166892994866387, "min": -14.205429009037882}, "range": {"max": 540, "min": 60}, "scale": "linear"}]}</toyplot:axes><clipPath id="t50a83e12aba64b7087c3ad970aa3e8b7"><rect height="500" width="500" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t50a83e12aba64b7087c3ad970aa3e8b7)" style="cursor:crosshair"><rect height="500" style="pointer-events:all;vi
# ...
