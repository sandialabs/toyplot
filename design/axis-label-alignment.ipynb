# %%
import toyplot

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, padding=20)
axes.x.ticks.show = True
axes.y.ticks.show = True
# Out:
# <div align="center" class="toyplot" id="tca42445679c74859b5ced0ccb8d27d7f"><svg height="600px" id="t8aabacf5a5e4496da431b4803c28bb3f" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t5d687ebd7e5d47bcbae800680bd24def"><toyplot:axes>{"x": [{"domain": {"max": 1000, "min": -1000}, "range": {"max": 530, "min": 70}, "scale": "linear"}], "y": [{"domain": {"max": 1000, "min": -1000}, "range": {"max": 530, "min": 70}, "scale": "linear"}]}</toyplot:axes><clipPath id="t910e1534156c419e9d90b7a8fc4a0e41"><rect height="500" width="500" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t910e1534156c419e9d90b7a8fc4a0e41)" style="cursor:crosshair"><rect height="500" style="pointer-events:all;visibility:hidden" width="500" x="50" y="50"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14" style="fill:white;opacity:0.75;stroke:none" width="90" x="450" y="60"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="495.0" y="67.0"></text></g><line style="" x1="50" x2="550" y1="550" y2="550"></line><g><line style="" x1="70.0" x2="70.0" y1="550" y2="545"></line><line style="" x1="185.0" x2="185.0" y1="550" y2="545"></line><line style="" x1="300.0" x2="300.0" y1="550" y2="545"></line><line style="" x1="415.0" x2="415.0" y1="550" y2="545"></line><line style="" x1="530.0" x2="530.0" y1="550" y2="545"></line></g><g><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="70.0" y="550">-1000</text><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="185.0" y="550">-500</text><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="300.0" y="550">0</text><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="415.0" y="550">500</text><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="530.0" y="550">1000</text></g><line style="" x1="50" x2="50" y1="50" y2="550"></line><g><line style="" x1="50" x2="55" y1="530.0" y2="530.0"></line><line style="" x1="50" x2="55" y1="415.0" y2="415.0"></line><line style="" x1="50" x2="55" y1="300.0" y2="300.0"></line><line style="" x1="50" x2="55" y1="185.0" y2="185.0"></line><line style="" x1="50" x2="55" y1="70.0" y2="70.0"></line></g><g><text style="alignment-baseline:middle;baseline-shift:80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="rotate(-90, 50, 530.0)" x="50" y="530.0">-1000</text><text style="alignment-baseline:middle;baseline-shift:80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="rotate(-90, 50, 415.0)" x="50" y="415.0">-500</text><text style="alignment-baseline:middle;baseline-shift:80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="rotate(-90, 50, 300.0)" x="50" y="300.0">0</text><text style="alignment-baseline:middle;baseline-shift:80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="rotate(-90, 50, 185.0)" x="50" y="185.0">500</text><text style="alignment-baseline:middle;baseline-shift:80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="rotate(-90, 50, 70.0)" x="50" y="70.0">1000</text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5p ...
#     (function()
#     {
#       // Workaround for browsers that don't support alignment-baseline
#       if(window.CSS !== undefined && window.CSS.supports !== undefined)
#       {
#         if(!window.CSS.supports("alignment-baseline", "middle"))
#         {
#           var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#tca42445679c74859b5ced0ccb8d27d7f text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               if(match[1] == "middle")
#               {
#                 var style = getComputedStyle(text[i]);
#                 var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#                 var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#                 dy += 0.4 * font_size;
#                 text[i].setAttribute("dy", dy);
#               }
#             }
#           }
#         }
#         if(!window.CSS.supports("baseline-shift", "0"))
#         {
#           var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#tca42445679c74859b5ced0ccb8d27d7f text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               var style = getComputedStyle(text[i]);
#               var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#               var percent = 0.01 * match[1].substr(0, match[1].length-1);
#               var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#               dy -= percent * font_size
#               text[i].setAttribute("dy", dy);
#             }
#           }
#         }
#       }
#     })();
#     </script><script>
#     (function()
#     {
#       var root_id="tca42445679c74859b5ced0ccb8d27d7f";
#
#       function sign(x)
#       {
#         if(x < 0)
#           return -1;
#         if(x > 0)
#           return 1;
#         return 0;
#       }
#
#       function log_n(x, base)
#       {
#         return Math.log(x) / Math.log(base);
#       }
#
#       function mix(a, b, amount)
#       {
#         return ((1.0 - amount) * a) + (amount * b);
#       }
#
#       // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#       function d3_mousePoint(container, e)
#       {
#         if (e.changedTouches) e = e.changedTouches[0];
#         var svg = container.ownerSVGElement || container;
#         if (svg.createSVGPoint) {
#           var point = svg.createSVGPoint();
#           point.x = e.clientX, point.y = e.clientY;
#           point = point.matrixTransform(container.getScreenCTM().inverse());
#           return [point.x, point.y];
#         }
#         var rect = container.getBoundingClientRect();
#         return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#       };
#
#       function display_coordinates(e)
#       {
#         var x = null;
#         var y = null;
#
#         var axes = e.currentTarget.parentElement;
#         var data = JSON.parse(axes.querySelector("toyplot\\:axes").textContent);
#
#         point = d3_mousePoint(e.target, e);
#
#         for(var i = 0; i != data["x"].length; ++i)
#         {
#           var segment = data["x"][i];
#           if(segment.range.min <= point[0] && point[0] < segment.range.max)
#           {
#             var normalized = (point[0] - segment.range.min) / (segment.range.max - segment.range.min);
#             if(segment.scale == "linear")
#             {
#               x = Number(

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, padding=20)
axes.x.ticks.show = True
axes.x.ticks.labels.style = {"font-size":"18px"}
axes.y.ticks.show = True
axes.y.ticks.labels.style = {"font-size":"18px"}
# Out:
# <div align="center" class="toyplot" id="t590d7f4015634f448c3eefc6f607d224"><svg height="600px" id="t25e8cf4f4c744319b1fc7018824501e3" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t075146141a074c8a9b059eaa0fb05eda"><toyplot:axes>{"x": [{"domain": {"max": 1000, "min": -1000}, "range": {"max": 530, "min": 70}, "scale": "linear"}], "y": [{"domain": {"max": 1000, "min": -1000}, "range": {"max": 530, "min": 70}, "scale": "linear"}]}</toyplot:axes><clipPath id="t58b6054e678847fda881e9acc210fd85"><rect height="500" width="500" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t58b6054e678847fda881e9acc210fd85)" style="cursor:crosshair"><rect height="500" style="pointer-events:all;visibility:hidden" width="500" x="50" y="50"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14" style="fill:white;opacity:0.75;stroke:none" width="90" x="450" y="60"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="495.0" y="67.0"></text></g><line style="" x1="50" x2="550" y1="550" y2="550"></line><g><line style="" x1="70.0" x2="70.0" y1="550" y2="545"></line><line style="" x1="185.0" x2="185.0" y1="550" y2="545"></line><line style="" x1="300.0" x2="300.0" y1="550" y2="545"></line><line style="" x1="415.0" x2="415.0" y1="550" y2="545"></line><line style="" x1="530.0" x2="530.0" y1="550" y2="545"></line></g><g><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" x="70.0" y="550">-1000</text><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" x="185.0" y="550">-500</text><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" x="300.0" y="550">0</text><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" x="415.0" y="550">500</text><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" x="530.0" y="550">1000</text></g><line style="" x1="50" x2="50" y1="50" y2="550"></line><g><line style="" x1="50" x2="55" y1="530.0" y2="530.0"></line><line style="" x1="50" x2="55" y1="415.0" y2="415.0"></line><line style="" x1="50" x2="55" y1="300.0" y2="300.0"></line><line style="" x1="50" x2="55" y1="185.0" y2="185.0"></line><line style="" x1="50" x2="55" y1="70.0" y2="70.0"></line></g><g><text style="alignment-baseline:middle;baseline-shift:80%;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="rotate(-90, 50, 530.0)" x="50" y="530.0">-1000</text><text style="alignment-baseline:middle;baseline-shift:80%;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="rotate(-90, 50, 415.0)" x="50" y="415.0">-500</text><text style="alignment-baseline:middle;baseline-shift:80%;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="rotate(-90, 50, 300.0)" x="50" y="300.0">0</text><text style="alignment-baseline:middle;baseline-shift:80%;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="rotate(-90, 50, 185.0)" x="50" y="185.0">500</text><text style="alignment-baseline:middle;baseline-shift:80%;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="rotate(-90, 50, 70.0)" x="50" y="70.0">1000</text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5p ...
#     (function()
#     {
#       // Workaround for browsers that don't support alignment-baseline
#       if(window.CSS !== undefined && window.CSS.supports !== undefined)
#       {
#         if(!window.CSS.supports("alignment-baseline", "middle"))
#         {
#           var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t590d7f4015634f448c3eefc6f607d224 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               if(match[1] == "middle")
#               {
#                 var style = getComputedStyle(text[i]);
#                 var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#                 var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#                 dy += 0.4 * font_size;
#                 text[i].setAttribute("dy", dy);
#               }
#             }
#           }
#         }
#         if(!window.CSS.supports("baseline-shift", "0"))
#         {
#           var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t590d7f4015634f448c3eefc6f607d224 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               var style = getComputedStyle(text[i]);
#               var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#               var percent = 0.01 * match[1].substr(0, match[1].length-1);
#               var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#               dy -= percent * font_size
#               text[i].setAttribute("dy", dy);
#             }
#           }
#         }
#       }
#     })();
#     </script><script>
#     (function()
#     {
#       var root_id="t590d7f4015634f448c3eefc6f607d224";
#
#       function sign(x)
#       {
#         if(x < 0)
#           return -1;
#         if(x > 0)
#           return 1;
#         return 0;
#       }
#
#       function log_n(x, base)
#       {
#         return Math.log(x) / Math.log(base);
#       }
#
#       function mix(a, b, amount)
#       {
#         return ((1.0 - amount) * a) + (amount * b);
#       }
#
#       // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#       function d3_mousePoint(container, e)
#       {
#         if (e.changedTouches) e = e.changedTouches[0];
#         var svg = container.ownerSVGElement || container;
#         if (svg.createSVGPoint) {
#           var point = svg.createSVGPoint();
#           point.x = e.clientX, point.y = e.clientY;
#           point = point.matrixTransform(container.getScreenCTM().inverse());
#           return [point.x, point.y];
#         }
#         var rect = container.getBoundingClientRect();
#         return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#       };
#
#       function display_coordinates(e)
#       {
#         var x = null;
#         var y = null;
#
#         var axes = e.currentTarget.parentElement;
#         var data = JSON.parse(axes.querySelector("toyplot\\:axes").textContent);
#
#         point = d3_mousePoint(e.target, e);
#
#         for(var i = 0; i != data["x"].length; ++i)
#         {
#           var segment = data["x"][i];
#           if(segment.range.min <= point[0] && point[0] < segment.range.max)
#           {
#             var normalized = (point[0] - segment.range.min) / (segment.range.max - segment.range.min);
#             if(segment.scale == "linear")
#             {
#               x = Number(

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, padding=20)
axes.x.ticks.show = True
axes.x.ticks.labels.angle = -90
axes.x.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "-toyplot-anchor-shift":"-6px", "baseline-shift":0}
axes.y.ticks.show = True
axes.y.ticks.labels.angle = 0
axes.y.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "-toyplot-anchor-shift":"-6px", "baseline-shift":0}
# Out:
# <div align="center" class="toyplot" id="t4c97d3ac66b246ce9ad62aecbcdbe118"><svg height="600px" id="t9b9327d4f25d4a4893a212715663141d" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t0641dba591f24b4495a7f33724d1c3e5"><toyplot:axes>{"x": [{"domain": {"max": 1000, "min": -1000}, "range": {"max": 530, "min": 70}, "scale": "linear"}], "y": [{"domain": {"max": 1000, "min": -1000}, "range": {"max": 530, "min": 70}, "scale": "linear"}]}</toyplot:axes><clipPath id="te2852fcb57d349fc97dbd0e6711f5a9c"><rect height="500" width="500" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#te2852fcb57d349fc97dbd0e6711f5a9c)" style="cursor:crosshair"><rect height="500" style="pointer-events:all;visibility:hidden" width="500" x="50" y="50"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14" style="fill:white;opacity:0.75;stroke:none" width="90" x="450" y="60"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="495.0" y="67.0"></text></g><line style="" x1="50" x2="550" y1="550" y2="550"></line><g><line style="" x1="70.0" x2="70.0" y1="550" y2="545"></line><line style="" x1="185.0" x2="185.0" y1="550" y2="545"></line><line style="" x1="300.0" x2="300.0" y1="550" y2="545"></line><line style="" x1="415.0" x2="415.0" y1="550" y2="545"></line><line style="" x1="530.0" x2="530.0" y1="550" y2="545"></line></g><g><text dx="-6px" style="-toyplot-anchor-shift:-6px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-90, 70.0, 550)" x="70.0" y="550">-1000</text><text dx="-6px" style="-toyplot-anchor-shift:-6px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-90, 185.0, 550)" x="185.0" y="550">-500</text><text dx="-6px" style="-toyplot-anchor-shift:-6px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-90, 300.0, 550)" x="300.0" y="550">0</text><text dx="-6px" style="-toyplot-anchor-shift:-6px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-90, 415.0, 550)" x="415.0" y="550">500</text><text dx="-6px" style="-toyplot-anchor-shift:-6px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-90, 530.0, 550)" x="530.0" y="550">1000</text></g><line style="" x1="50" x2="50" y1="50" y2="550"></line><g><line style="" x1="50" x2="55" y1="530.0" y2="530.0"></line><line style="" x1="50" x2="55" y1="415.0" y2="415.0"></line><line style="" x1="50" x2="55" y1="300.0" y2="300.0"></line><line style="" x1="50" x2="55" y1="185.0" y2="185.0"></line><line style="" x1="50" x2="55" y1="70.0" y2="70.0"></line></g><g><text dx="-6px" style="-toyplot-anchor-shift:-6px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" x="50" y="530.0">-1000</text><text dx="-6px" style="-toyplot-anchor-shift:-6px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" x="50" y="415.0">-500</text><text dx="-6px" style="-toyplot-anchor-shift:-6px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" x="50" y="300.0">0</text><text dx="-6px" style="-toyplot-anchor-shift:-6px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" x="50" y="185.0">500</text><text dx="-6px" style="-toyplot-anchor-shift:-6px;alignment-baseline:middle;baseline-shift:0;font-size:18px;fon ...
#     (function()
#     {
#       // Workaround for browsers that don't support alignment-baseline
#       if(window.CSS !== undefined && window.CSS.supports !== undefined)
#       {
#         if(!window.CSS.supports("alignment-baseline", "middle"))
#         {
#           var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t4c97d3ac66b246ce9ad62aecbcdbe118 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               if(match[1] == "middle")
#               {
#                 var style = getComputedStyle(text[i]);
#                 var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#                 var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#                 dy += 0.4 * font_size;
#                 text[i].setAttribute("dy", dy);
#               }
#             }
#           }
#         }
#         if(!window.CSS.supports("baseline-shift", "0"))
#         {
#           var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t4c97d3ac66b246ce9ad62aecbcdbe118 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               var style = getComputedStyle(text[i]);
#               var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#               var percent = 0.01 * match[1].substr(0, match[1].length-1);
#               var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#               dy -= percent * font_size
#               text[i].setAttribute("dy", dy);
#             }
#           }
#         }
#       }
#     })();
#     </script><script>
#     (function()
#     {
#       var root_id="t4c97d3ac66b246ce9ad62aecbcdbe118";
#
#       function sign(x)
#       {
#         if(x < 0)
#           return -1;
#         if(x > 0)
#           return 1;
#         return 0;
#       }
#
#       function log_n(x, base)
#       {
#         return Math.log(x) / Math.log(base);
#       }
#
#       function mix(a, b, amount)
#       {
#         return ((1.0 - amount) * a) + (amount * b);
#       }
#
#       // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#       function d3_mousePoint(container, e)
#       {
#         if (e.changedTouches) e = e.changedTouches[0];
#         var svg = container.ownerSVGElement || container;
#         if (svg.createSVGPoint) {
#           var point = svg.createSVGPoint();
#           point.x = e.clientX, point.y = e.clientY;
#           point = point.matrixTransform(container.getScreenCTM().inverse());
#           return [point.x, point.y];
#         }
#         var rect = container.getBoundingClientRect();
#         return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#       };
#
#       function display_coordinates(e)
#       {
#         var x = null;
#         var y = null;
#
#         var axes = e.currentTarget.parentElement;
#         var data = JSON.parse(axes.querySelector("toyplot\\:axes").textContent);
#
#         point = d3_mousePoint(e.target, e);
#
#         for(var i = 0; i != data["x"].length; ++i)

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, padding=20)
axes.x.ticks.show = True
axes.x.ticks.labels.angle = -45
axes.x.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "-toyplot-anchor-shift":"-12px", "baseline-shift":0}
axes.y.ticks.show = True
axes.y.ticks.labels.angle = -45
axes.y.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "-toyplot-anchor-shift":"-12px", "baseline-shift":0}
# Out:
# <div align="center" class="toyplot" id="t5cd84cc53998483eb6e72e53b9c27b76"><svg height="600px" id="t79dbb0767b3644b6b5422ca21ef2c15b" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t58879c6910334cbeb1ebfd08f4d483f4"><toyplot:axes>{"x": [{"domain": {"max": 1000, "min": -1000}, "range": {"max": 530, "min": 70}, "scale": "linear"}], "y": [{"domain": {"max": 1000, "min": -1000}, "range": {"max": 530, "min": 70}, "scale": "linear"}]}</toyplot:axes><clipPath id="tdf15b89cb3494a79a460696fbe47448d"><rect height="500" width="500" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tdf15b89cb3494a79a460696fbe47448d)" style="cursor:crosshair"><rect height="500" style="pointer-events:all;visibility:hidden" width="500" x="50" y="50"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14" style="fill:white;opacity:0.75;stroke:none" width="90" x="450" y="60"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="495.0" y="67.0"></text></g><line style="" x1="50" x2="550" y1="550" y2="550"></line><g><line style="" x1="70.0" x2="70.0" y1="550" y2="545"></line><line style="" x1="185.0" x2="185.0" y1="550" y2="545"></line><line style="" x1="300.0" x2="300.0" y1="550" y2="545"></line><line style="" x1="415.0" x2="415.0" y1="550" y2="545"></line><line style="" x1="530.0" x2="530.0" y1="550" y2="545"></line></g><g><text dx="-12px" style="-toyplot-anchor-shift:-12px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-45, 70.0, 550)" x="70.0" y="550">-1000</text><text dx="-12px" style="-toyplot-anchor-shift:-12px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-45, 185.0, 550)" x="185.0" y="550">-500</text><text dx="-12px" style="-toyplot-anchor-shift:-12px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-45, 300.0, 550)" x="300.0" y="550">0</text><text dx="-12px" style="-toyplot-anchor-shift:-12px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-45, 415.0, 550)" x="415.0" y="550">500</text><text dx="-12px" style="-toyplot-anchor-shift:-12px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-45, 530.0, 550)" x="530.0" y="550">1000</text></g><line style="" x1="50" x2="50" y1="50" y2="550"></line><g><line style="" x1="50" x2="55" y1="530.0" y2="530.0"></line><line style="" x1="50" x2="55" y1="415.0" y2="415.0"></line><line style="" x1="50" x2="55" y1="300.0" y2="300.0"></line><line style="" x1="50" x2="55" y1="185.0" y2="185.0"></line><line style="" x1="50" x2="55" y1="70.0" y2="70.0"></line></g><g><text dx="-12px" style="-toyplot-anchor-shift:-12px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-45, 50, 530.0)" x="50" y="530.0">-1000</text><text dx="-12px" style="-toyplot-anchor-shift:-12px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-45, 50, 415.0)" x="50" y="415.0">-500</text><text dx="-12px" style="-toyplot-anchor-shift:-12px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-45, 50, 300.0)" x="50" y="300.0">0</text><text dx="-12px" style="-toyplot-anchor-shift:-12px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rota ...
#     (function()
#     {
#       // Workaround for browsers that don't support alignment-baseline
#       if(window.CSS !== undefined && window.CSS.supports !== undefined)
#       {
#         if(!window.CSS.supports("alignment-baseline", "middle"))
#         {
#           var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t5cd84cc53998483eb6e72e53b9c27b76 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               if(match[1] == "middle")
#               {
#                 var style = getComputedStyle(text[i]);
#                 var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#                 var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#                 dy += 0.4 * font_size;
#                 text[i].setAttribute("dy", dy);
#               }
#             }
#           }
#         }
#         if(!window.CSS.supports("baseline-shift", "0"))
#         {
#           var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t5cd84cc53998483eb6e72e53b9c27b76 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               var style = getComputedStyle(text[i]);
#               var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#               var percent = 0.01 * match[1].substr(0, match[1].length-1);
#               var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#               dy -= percent * font_size
#               text[i].setAttribute("dy", dy);
#             }
#           }
#         }
#       }
#     })();
#     </script><script>
#     (function()
#     {
#       var root_id="t5cd84cc53998483eb6e72e53b9c27b76";
#
#       function sign(x)
#       {
#         if(x < 0)
#           return -1;
#         if(x > 0)
#           return 1;
#         return 0;
#       }
#
#       function log_n(x, base)
#       {
#         return Math.log(x) / Math.log(base);
#       }
#
#       function mix(a, b, amount)
#       {
#         return ((1.0 - amount) * a) + (amount * b);
#       }
#
#       // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#       function d3_mousePoint(container, e)
#       {
#         if (e.changedTouches) e = e.changedTouches[0];
#         var svg = container.ownerSVGElement || container;
#         if (svg.createSVGPoint) {
#           var point = svg.createSVGPoint();
#           point.x = e.clientX, point.y = e.clientY;
#           point = point.matrixTransform(container.getScreenCTM().inverse());
#           return [point.x, point.y];
#         }
#         var rect = container.getBoundingClientRect();
#         return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#       };
#
#       function display_coordinates(e)
#       {
#         var x = null;
#         var y = null;
#
#         var axes = e.currentTarget

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, padding=20)
axes.x.ticks.show = True
axes.x.ticks.labels.angle = -45
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "baseline-shift":0}
axes.y.ticks.show = True
axes.y.ticks.labels.angle = -45
axes.y.ticks.labels.offset = 10
axes.y.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "baseline-shift":0}
# Out:
# <div align="center" class="toyplot" id="t67b418ec584f4ea7bf1c04e1e3034e89"><svg height="600px" id="tf6b9898ae6154000bf7adf9a1e0b146a" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t81e120d1569b4d8096e518cc79da92f8"><toyplot:axes>{"x": [{"domain": {"max": 1000, "min": -1000}, "range": {"max": 530, "min": 70}, "scale": "linear"}], "y": [{"domain": {"max": 1000, "min": -1000}, "range": {"max": 530, "min": 70}, "scale": "linear"}]}</toyplot:axes><clipPath id="t939f73fa6770494793d99e91302ca68d"><rect height="500" width="500" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t939f73fa6770494793d99e91302ca68d)" style="cursor:crosshair"><rect height="500" style="pointer-events:all;visibility:hidden" width="500" x="50" y="50"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14" style="fill:white;opacity:0.75;stroke:none" width="90" x="450" y="60"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="495.0" y="67.0"></text></g><line style="" x1="50" x2="550" y1="550" y2="550"></line><g><line style="" x1="70.0" x2="70.0" y1="550" y2="545"></line><line style="" x1="185.0" x2="185.0" y1="550" y2="545"></line><line style="" x1="300.0" x2="300.0" y1="550" y2="545"></line><line style="" x1="415.0" x2="415.0" y1="550" y2="545"></line><line style="" x1="530.0" x2="530.0" y1="550" y2="545"></line></g><g><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-45, 70.0, 570)" x="70.0" y="570">-1000</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-45, 185.0, 570)" x="185.0" y="570">-500</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-45, 300.0, 570)" x="300.0" y="570">0</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-45, 415.0, 570)" x="415.0" y="570">500</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-45, 530.0, 570)" x="530.0" y="570">1000</text></g><line style="" x1="50" x2="50" y1="50" y2="550"></line><g><line style="" x1="50" x2="55" y1="530.0" y2="530.0"></line><line style="" x1="50" x2="55" y1="415.0" y2="415.0"></line><line style="" x1="50" x2="55" y1="300.0" y2="300.0"></line><line style="" x1="50" x2="55" y1="185.0" y2="185.0"></line><line style="" x1="50" x2="55" y1="70.0" y2="70.0"></line></g><g><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-45, 30, 530.0)" x="30" y="530.0">-1000</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-45, 30, 415.0)" x="30" y="415.0">-500</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-45, 30, 300.0)" x="30" y="300.0">0</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-45, 30, 185.0)" x="30" y="185.0">500</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-45, 30, 70.0)" x="30" y="70.0">1000</text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" sty ...
#     (function()
#     {
#       // Workaround for browsers that don't support alignment-baseline
#       if(window.CSS !== undefined && window.CSS.supports !== undefined)
#       {
#         if(!window.CSS.supports("alignment-baseline", "middle"))
#         {
#           var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t67b418ec584f4ea7bf1c04e1e3034e89 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               if(match[1] == "middle")
#               {
#                 var style = getComputedStyle(text[i]);
#                 var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#                 var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#                 dy += 0.4 * font_size;
#                 text[i].setAttribute("dy", dy);
#               }
#             }
#           }
#         }
#         if(!window.CSS.supports("baseline-shift", "0"))
#         {
#           var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t67b418ec584f4ea7bf1c04e1e3034e89 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               var style = getComputedStyle(text[i]);
#               var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#               var percent = 0.01 * match[1].substr(0, match[1].length-1);
#               var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#               dy -= percent * font_size
#               text[i].setAttribute("dy", dy);
#             }
#           }
#         }
#       }
#     })();
#     </script><script>
#     (function()
#     {
#       var root_id="t67b418ec584f4ea7bf1c04e1e3034e89";
#
#       function sign(x)
#       {
#         if(x < 0)
#           return -1;
#         if(x > 0)
#           return 1;
#         return 0;
#       }
#
#       function log_n(x, base)
#       {
#         return Math.log(x) / Math.log(base);
#       }
#
#       function mix(a, b, amount)
#       {
#         return ((1.0 - amount) * a) + (amount * b);
#       }
#
#       // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#       function d3_mousePoint(container, e)
#       {
#         if (e.changedTouches) e = e.changedTouches[0];
#         var svg = container.ownerSVGElement || container;
#         if (svg.createSVGPoint) {
#           var point = svg.createSVGPoint();
#           point.x = e.clientX, point.y = e.clientY;
#           point = point.matrixTransform(container.getScreenCTM().inverse());
#           return [point.x, point.y];
#         }
#         var rect = container.getBoundingClientRect();
#         return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#       };
#
#       function display_coordinates(e)
#       {
#         var x = null;
#         var y = null;
#
#         var axes = e.currentTarget.parentElement;
#         var data = JSON.parse(axes.querySelector("toyplot\\:axes").textContent);
#
#         point = d3_mousePoint(e.target, e);
#
#         for(var i = 0; i != data["x"].length; ++i)
#         {
#           var segment = data["x"][i];
#           if(segment.range.min <= point[0] && point[0] < segment.range.max)
#           {
#             var normalized = (point[0] - segment.range.min)

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, padding=20)
axes.x.ticks.show = True
axes.x.ticks.labels.angle = -90
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "baseline-shift":"-10%"}
axes.y.ticks.show = True
axes.y.ticks.labels.angle = 0
axes.y.ticks.labels.offset = 10
axes.y.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "baseline-shift":0}
# Out:
# <div align="center" class="toyplot" id="teca56d6b2036495e96533fd5ca54204b"><svg height="600px" id="t7011970abdc4416083845c21b1118a63" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tcf06dd715be1471d95ddcd4667e9ba0b"><toyplot:axes>{"x": [{"domain": {"max": 1000, "min": -1000}, "range": {"max": 530, "min": 70}, "scale": "linear"}], "y": [{"domain": {"max": 1000, "min": -1000}, "range": {"max": 530, "min": 70}, "scale": "linear"}]}</toyplot:axes><clipPath id="t9e2ed39a0aec4f17925c9b97276a7be6"><rect height="500" width="500" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t9e2ed39a0aec4f17925c9b97276a7be6)" style="cursor:crosshair"><rect height="500" style="pointer-events:all;visibility:hidden" width="500" x="50" y="50"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14" style="fill:white;opacity:0.75;stroke:none" width="90" x="450" y="60"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="495.0" y="67.0"></text></g><line style="" x1="50" x2="550" y1="550" y2="550"></line><g><line style="" x1="70.0" x2="70.0" y1="550" y2="545"></line><line style="" x1="185.0" x2="185.0" y1="550" y2="545"></line><line style="" x1="300.0" x2="300.0" y1="550" y2="545"></line><line style="" x1="415.0" x2="415.0" y1="550" y2="545"></line><line style="" x1="530.0" x2="530.0" y1="550" y2="545"></line></g><g><text style="alignment-baseline:middle;baseline-shift:-10%;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-90, 70.0, 560)" x="70.0" y="560">-1000</text><text style="alignment-baseline:middle;baseline-shift:-10%;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-90, 185.0, 560)" x="185.0" y="560">-500</text><text style="alignment-baseline:middle;baseline-shift:-10%;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-90, 300.0, 560)" x="300.0" y="560">0</text><text style="alignment-baseline:middle;baseline-shift:-10%;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-90, 415.0, 560)" x="415.0" y="560">500</text><text style="alignment-baseline:middle;baseline-shift:-10%;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="rotate(-90, 530.0, 560)" x="530.0" y="560">1000</text></g><line style="" x1="50" x2="50" y1="50" y2="550"></line><g><line style="" x1="50" x2="55" y1="530.0" y2="530.0"></line><line style="" x1="50" x2="55" y1="415.0" y2="415.0"></line><line style="" x1="50" x2="55" y1="300.0" y2="300.0"></line><line style="" x1="50" x2="55" y1="185.0" y2="185.0"></line><line style="" x1="50" x2="55" y1="70.0" y2="70.0"></line></g><g><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" x="40" y="530.0">-1000</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" x="40" y="415.0">-500</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" x="40" y="300.0">0</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" x="40" y="185.0">500</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" x="40" y="70.0">1000</text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden" ...
#     (function()
#     {
#       // Workaround for browsers that don't support alignment-baseline
#       if(window.CSS !== undefined && window.CSS.supports !== undefined)
#       {
#         if(!window.CSS.supports("alignment-baseline", "middle"))
#         {
#           var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#teca56d6b2036495e96533fd5ca54204b text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               if(match[1] == "middle")
#               {
#                 var style = getComputedStyle(text[i]);
#                 var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#                 var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#                 dy += 0.4 * font_size;
#                 text[i].setAttribute("dy", dy);
#               }
#             }
#           }
#         }
#         if(!window.CSS.supports("baseline-shift", "0"))
#         {
#           var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#teca56d6b2036495e96533fd5ca54204b text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               var style = getComputedStyle(text[i]);
#               var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#               var percent = 0.01 * match[1].substr(0, match[1].length-1);
#               var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#               dy -= percent * font_size
#               text[i].setAttribute("dy", dy);
#             }
#           }
#         }
#       }
#     })();
#     </script><script>
#     (function()
#     {
#       var root_id="teca56d6b2036495e96533fd5ca54204b";
#
#       function sign(x)
#       {
#         if(x < 0)
#           return -1;
#         if(x > 0)
#           return 1;
#         return 0;
#       }
#
#       function log_n(x, base)
#       {
#         return Math.log(x) / Math.log(base);
#       }
#
#       function mix(a, b, amount)
#       {
#         return ((1.0 - amount) * a) + (amount * b);
#       }
#
#       // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#       function d3_mousePoint(container, e)
#       {
#         if (e.changedTouches) e = e.changedTouches[0];
#         var svg = container.ownerSVGElement || container;
#         if (svg.createSVGPoint) {
#           var point = svg.createSVGPoint();
#           point.x = e.clientX, point.y = e.clientY;
#           point = point.matrixTransform(container.getScreenCTM().inverse());
#           return [point.x, point.y];
#         }
#         var rect = container.getBoundingClientRect();
#         return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#       };
#
#       function display_coordinates(e)
#       {
#         var x = null;
#         var y = null;
#
#         var axes = e.currentTarget.parentElement;
#         var data = JSON.parse(axes.querySelector("toyplot\\:axes").textContent);
#
#         point = d3_mousePoint(e.target, e);
#
#         for(var i = 0; i != data["x"].length; ++i)
#         {
#           var segment = data["x"][i];
#           if(segment.range.min <= point[0] && point[0] < segment.range.max)
#           {
#             var normalized = (point[0] - segment.range.min) / (segment.range.max - segment.range.min);
#             if(segment.scale == "linear")
#             {
#               x = Number(mix(segment.domain.min, segment.dom
