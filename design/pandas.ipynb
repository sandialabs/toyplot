# %%
import pandas
import toyplot.data

# %%
df = pandas.read_csv("../docs/temperatures.csv")

# %%
toyplot.data.Table(df)
# Out:
# <table class="toyplot-data-Table" style="border-collapse:collapse; border:none; color: #292724"><tr style="border:none;border-bottom:1px solid #292724"><th style="text-align:left;border:none;padding-right:1em;">STATION</th><th style="text-align:left;border:none;padding-right:1em;">STATION_NAME</th><th style="text-align:left;border:none;padding-right:1em;">DATE</th><th style="text-align:left;border:none;padding-right:1em;">TMAX</th><th style="text-align:left;border:none;padding-right:1em;">TMIN</th><th style="text-align:left;border:none;padding-right:1em;">TOBS</th></tr><tr style="border:none"><td style="border:none;padding-right:1em;">GHCND:USC00294366</td><td style="border:none;padding-right:1em;">JEMEZ DAM NM US</td><td style="border:none;padding-right:1em;">20130101</td><td style="border:none;padding-right:1em;">39</td><td style="border:none;padding-right:1em;">-72</td><td style="border:none;padding-right:1em;">-67</td></tr><tr style="border:none"><td style="border:none;padding-ri
# ...
