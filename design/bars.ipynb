# %%
import numpy
import toyplot

# %%
numpy.random.seed(1234)
data = numpy.random.random(10)
x = numpy.linspace(0, 2, len(data))
x2 = numpy.linspace(0, 1, len(data)) ** 1.5
x3 = numpy.cumsum(numpy.random.random(len(data) + 1))
x4 = x3[:-1]
x5 = x3[1:]

toyplot.bars(data, width=300, height=300);
toyplot.bars(x, data, width=300, height=300);
toyplot.bars(x2, data, width=300, height=300);
toyplot.bars(x4, x5, data, width=300, height=300);
# Out:
# <div align="center" class="toyplot" id="t6582d3e96f2b43b7b9d0f4b7d49dacd6"><svg height="300px" id="tc6e1d9f882524ccf9402b980ae795a80" style="opacity:1.0;font-size:12px;font-family:helvetica;stroke-opacity:1.0;fill-opacity:1.0;stroke:#343434;stroke-width:1.0;background-color:transparent;fill:#343434;" width="300px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-Axes2D" id="t50e8e8bb5d0f47cfa943aeea863678e6"><toyplot:axes>{"y": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 1.0, "min": 0.0}}], "x": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 10.0, "min": -0.5}}]}</toyplot:axes><clipPath id="t97081a052191430dbbe576822ab1df1e"><rect height="200" width="200" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t97081a052191430dbbe576822ab1df1e)" style="cursor:crosshair;"><rect height="200" style="pointer-events:all;visibility:hidden;" width="200" x="50" y="50"></rect><g class="toyplot-BarMagnitudesMark" id="t95a00d61b00344fb8f9f2a7a89d05d62" style="stroke:white;stroke-width:1.0;"><toyplot:data-table title="Bar Data">{"data": [[-0.5, 0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5], [0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5], [0.1915194503788923, 0.6221087710398319, 0.4377277390071145, 0.7853585837137692, 0.7799758081188035, 0.2725926052826416, 0.2764642551430967, 0.8018721775350193, 0.9581393536837052, 0.8759326347420947]], "names": ["position0", "position1", "series0"]}</toyplot:data-table><g class="toyplot-Series"><rect class="toyplot-Datum" height="34.4735010682" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="60.0" y="205.526498932"></rect><rect class="toyplot-Datum" height="111.979578787" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="77.1428571429" y="128.020421213"></rect><rect class="toyplot-Datum" height="78.7909930213" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="94.2857142857" y="161.209006979"></rect><rect class="toyplot-Datum" height="141.364545068" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="111.428571429" y="98.6354549315"></rect><rect class="toyplot-Datum" height="140.395645461" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="128.571428571" y="99.6043545386"></rect><rect class="toyplot-Datum" height="49.0666689509" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="145.714285714" y="190.933331049"></rect><rect class="toyplot-Datum" height="49.7635659258" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="162.857142857" y="190.236434074"></rect><rect class="toyplot-Datum" height="144.336991956" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="180.0" y="95.6630080437"></rect><rect class="toyplot-Datum" height="172.465083663" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="197.142857143" y="67.5349163369"></rect><rect class="toyplot-Datum" height="157.667874254" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="214.285714286" y="82.3321257464"></rect></g></g></g><g class="toyplot-coordinates" style="visibility:hidden;"><rect height="14" style="opacity:0.75;stroke:none;fill:white;" width="90" x="150" y="60"></rect><text style="font-size:10px;font-weight:normal;stroke:none;text-anchor:middle;alignment-baseline:middle;" x="195.0" y="67.0"></text></g><line style="" x1="60.0" x2="231.428571429" y1="250" y2="250"></line><g><text style="font-size:10px;baseline-shift:-80%;alignment-baseline:middle;font-weight:normal;stroke:none; ...
#     (function()
#     {
#       // Workaround for browsers that don't support alignment-baseline
#       if(window.CSS !== undefined && window.CSS.supports !== undefined)
#       {
#         if(!window.CSS.supports("alignment-baseline", "middle"))
#         {
#           var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t6582d3e96f2b43b7b9d0f4b7d49dacd6 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               if(match[1] == "middle")
#               {
#                 var style = getComputedStyle(text[i]);
#                 var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#                 var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#                 dy += 0.4 * font_size;
#                 text[i].setAttribute("dy", dy);
#               }
#             }
#           }
#         }
#         if(!window.CSS.supports("baseline-shift", "0"))
#         {
#           var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t6582d3e96f2b43b7b9d0f4b7d49dacd6 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               var style = getComputedStyle(text[i]);
#               var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#               var percent = 0.01 * match[1].substr(0, match[1].length-1);
#               var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#               dy -= percent * font_size
#               text[i].setAttribute("dy", dy);
#             }
#           }
#         }
#       }
#     })();
#     </script><script>
#     // Allow users to extract embedded raw data
#     (function()
#     {
#       var root_id="t6582d3e96f2b43b7b9d0f4b7d49dacd6";
#
#       function save_csv(dataset)
#       {
#         uri = "data:text/csv;charset=utf-8,";
#         data = JSON.parse(dataset.textContent);
#         uri += data.names.join(",") + "\n";
#         for(var i = 0; i != data.data[0].length; ++i)
#         {
#           for(var j = 0; j != data.data.length; ++j)
#           {
#             if(j)
#               uri += ",";
#             uri += d
# <div align="center" class="toyplot" id="ta62c70d7448f4cbeb44d21c11152f517"><svg height="300px" id="t4625eaf0f46d4a21b4eecfa68ac695b6" style="opacity:1.0;font-size:12px;font-family:helvetica;stroke-opacity:1.0;fill-opacity:1.0;stroke:#343434;stroke-width:1.0;background-color:transparent;fill:#343434;" width="300px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-Axes2D" id="t6049d4d3caeb42218f0613843f2ab754"><toyplot:axes>{"y": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 1.0, "min": 0.0}}], "x": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 2.1111111111111112, "min": -0.1111111111111111}}]}</toyplot:axes><clipPath id="td3f857a69aed45459630a46e4ec19f95"><rect height="200" width="200" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#td3f857a69aed45459630a46e4ec19f95)" style="cursor:crosshair;"><rect height="200" style="pointer-events:all;visibility:hidden;" width="200" x="50" y="50"></rect><g class="toyplot-BarMagnitudesMark" id="t4141c761ecbc4c51865d4c372c5531ad" style="stroke:white;stroke-width:1.0;"><toyplot:data-table title="Bar Data">{"data": [[-0.1111111111111111, 0.1111111111111111, 0.3333333333333333, 0.5555555555555556, 0.7777777777777777, 1.0, 1.2222222222222223, 1.4444444444444442, 1.6666666666666665, 1.8888888888888888], [0.1111111111111111, 0.3333333333333333, 0.5555555555555556, 0.7777777777777777, 1.0, 1.2222222222222223, 1.4444444444444442, 1.6666666666666665, 1.8888888888888888, 2.111111111111111], [0.1915194503788923, 0.6221087710398319, 0.4377277390071145, 0.7853585837137692, 0.7799758081188035, 0.2725926052826416, 0.2764642551430967, 0.8018721775350193, 0.9581393536837052, 0.8759326347420947]], "names": ["position0", "position1", "series0"]}</toyplot:data-table><g class="toyplot-Series"><rect class="toyplot-Datum" height="34.4735010682" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="60.0" y="205.526498932"></rect><rect class="toyplot-Datum" height="111.979578787" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="78.0" y="128.020421213"></rect><rect class="toyplot-Datum" height="78.7909930213" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="96.0" y="161.209006979"></rect><rect class="toyplot-Datum" height="141.364545068" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="114.0" y="98.6354549315"></rect><rect class="toyplot-Datum" height="140.395645461" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="132.0" y="99.6043545386"></rect><rect class="toyplot-Datum" height="49.0666689509" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="150.0" y="190.933331049"></rect><rect class="toyplot-Datum" height="49.7635659258" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="168.0" y="190.236434074"></rect><rect class="toyplot-Datum" height="144.336991956" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="186.0" y="95.6630080437"></rect><rect class="toyplot-Datum" height="172.465083663" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="204.0" y="67.5349163369"></rect><rect class="toyplot-Datum" height="157.667874254" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="222.0" y="82.3321257464"></rect></g></g></g><g class="toyplot-coordinates" style="visibility:hidden;"><rect height="14" style="opacity:0.75;stroke:none;fill:white;" width="90" x="150" y="60"></rect><text style="font-size:10px;font-weight:normal;stroke:none;text-anchor:middle;alignment-baseline:middle;" x="195.0" y="67.0"></text></g><line style="" x1="60.0" x2="240.0" ...
#     (function()
#     {
#       // Workaround for browsers that don't support alignment-baseline
#       if(window.CSS !== undefined && window.CSS.supports !== undefined)
#       {
#         if(!window.CSS.supports("alignment-baseline", "middle"))
#         {
#           var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#ta62c70d7448f4cbeb44d21c11152f517 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               if(match[1] == "middle")
#               {
#                 var style = getComputedStyle(text[i]);
#                 var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#                 var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#                 dy += 0.4 * font_size;
#                 text[i].setAttribute("dy", dy);
#               }
#             }
#           }
#         }
#         if(!window.CSS.supports("baseline-shift", "0"))
#         {
#           var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#ta62c70d7448f4cbeb44d21c11152f517 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               var style = getComputedStyle(text[i]);
#               var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#               var percent = 0.01 * match[1].substr(0, match[1].length-1);
#               var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#               dy -= percent * font_size
#               text[i].setAttribute("dy", dy);
#             }
#           }
#         }
#       }
#     })();
#     </script><script>
#     // Allow users to extract embedded raw data
#     (function()
#     {
#       var root_id="ta62c70d7448f4cbeb44d21c11152f517";
#
#       function save_csv(dataset)
#       {
#         uri = "data:text/csv;charset=utf-8,";
#         data = JSON.parse(dataset.textContent);
#         uri += data.names.join(",") + "\n";
#         for(var i = 0; i != data.data[0].length; ++i)
#         {
#           for
# <div align="center" class="toyplot" id="te6eef41885b444c487fb6658b2736d93"><svg height="300px" id="tbf1e260fa7c04190878872af440e28f8" style="opacity:1.0;font-size:12px;font-family:helvetica;stroke-opacity:1.0;fill-opacity:1.0;stroke:#343434;stroke-width:1.0;background-color:transparent;fill:#343434;" width="300px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-Axes2D" id="t7296801a1fbd4d6f9ef3cbcc6af2a305"><toyplot:axes>{"y": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 1.0, "min": 0.0}}], "x": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 1.0809737592968607, "min": -0.018518518518518517}}]}</toyplot:axes><clipPath id="ta5562387591b4bc6b260d9c7e1e5632b"><rect height="200" width="200" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#ta5562387591b4bc6b260d9c7e1e5632b)" style="cursor:crosshair;"><rect height="200" style="pointer-events:all;visibility:hidden;" width="200" x="50" y="50"></rect><g class="toyplot-BarMagnitudesMark" id="taa77b606015c498fa91265905771fb0e" style="stroke:white;stroke-width:1.0;"><toyplot:data-table title="Bar Data">{"data": [[-0.018518518518518517, 0.018518518518518517, 0.07089679860641093, 0.14860332495283002, 0.24437319301308574, 0.3551914793981287, 0.4792088582258892, 0.6151332895213185, 0.761994003248549, 0.9190262407031393], [0.018518518518518517, 0.07089679860641093, 0.14860332495283002, 0.24437319301308574, 0.3551914793981287, 0.4792088582258892, 0.6151332895213185, 0.761994003248549, 0.9190262407031393, 1.0809737592968607], [0.1915194503788923, 0.6221087710398319, 0.4377277390071145, 0.7853585837137692, 0.7799758081188035, 0.2725926052826416, 0.2764642551430967, 0.8018721775350193, 0.9581393536837052, 0.8759326347420947]], "names": ["position0", "position1", "series0"]}</toyplot:data-table><g class="toyplot-Series"><rect class="toyplot-Datum" height="34.4735010682" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="6.06340471978" x="60.0" y="205.526498932"></rect><rect class="toyplot-Datum" height="111.979578787" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="8.57494918887" x="66.0634047198" y="128.020421213"></rect><rect class="toyplot-Datum" height="78.7909930213" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="12.7214852024" x="74.6383539086" y="161.209006979"></rect><rect class="toyplot-Datum" height="141.364545068" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="15.6786696902" x="87.359839111" y="98.6354549315"></rect><rect class="toyplot-Datum" height="140.395645461" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.142275259" x="103.038508801" y="99.6043545386"></rect><rect class="toyplot-Datum" height="49.0666689509" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="20.3031241232" x="121.18078406" y="190.933331049"></rect><rect class="toyplot-Datum" height="49.7635659258" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="22.2524506328" x="141.483908184" y="190.236434074"></rect><rect class="toyplot-Datum" height="144.336991956" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="24.0428505086" x="163.736358816" y="95.6630080437"></rect><rect class="toyplot-Datum" height="172.465083663" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="25.708050263" x="187.779209325" y="67.5349163369"></rect><rect class="toyplot-Datum" height="157.667874254" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="26.5127404121" x="213.487259588" y="82.3321257464"></rect></g></g></g><g class="toyplot-coordinates" style="visibility:hidden;"><rect height="14" style="opacity:0.75;stroke:none;fill:white;" w ...
#     (function()
#     {
#       // Workaround for browsers that don't support alignment-baseline
#       if(window.CSS !== undefined && window.CSS.supports !== undefined)
#       {
#         if(!window.CSS.supports("alignment-baseline", "middle"))
#         {
#           var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#te6eef41885b444c487fb6658b2736d93 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               if(match[1] == "middle")
#               {
#                 var style = getComputedStyle(text[i]);
#                 var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#                 var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#                 dy += 0.4 * font_size;
#                 text[i].setAttribute("dy", dy);
#               }
#             }
#           }
#         }
#         if(!window.CSS.supports("baseline-shift", "0"))
#         {
#           var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#te6eef41885b444c487fb6658b2736d93 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               var style = getComputedStyle(text[i]);
#               var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#               var percent = 0.01 * match[1].substr(0, match[1].length-1);
#               var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#               dy -= percent * font_size
#               text[i].setAttribute("dy", dy);
#             }
#           }
#         }
#       }
#     })();
#     </script><script>
#     // Allow users to extract embedded raw data
#     (function()
#     {
#       var root_id="te6eef41885b444c487fb6658b2736d93";
#
#       function save_cs
# <div align="center" class="toyplot" id="t0fb58cd309674c1e8c6e137c174da327"><svg height="300px" id="t147d4b441b8c4a50a91e742b3384a606" style="opacity:1.0;font-size:12px;font-family:helvetica;stroke-opacity:1.0;fill-opacity:1.0;stroke:#343434;stroke-width:1.0;background-color:transparent;fill:#343434;" width="300px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-Axes2D" id="t143c24a904f642a38cac801b1d338bf2"><toyplot:axes>{"y": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 1.0, "min": 0.0}}], "x": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 6.0, "min": 0.0}}]}</toyplot:axes><clipPath id="t6720f4c936204cc5b661513359035d0d"><rect height="200" width="200" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t6720f4c936204cc5b661513359035d0d)" style="cursor:crosshair;"><rect height="200" style="pointer-events:all;visibility:hidden;" width="200" x="50" y="50"></rect><g class="toyplot-BarMagnitudesMark" id="teefa636895e94c538dfe9e4ecdd2f48b" style="stroke:white;stroke-width:1.0;"><toyplot:data-table title="Bar Data">{"data": [[0.35781726995786667, 0.8588123954813254, 1.5422753306534616, 2.2549773576363616, 2.6252281124267567, 3.1864242984923816, 3.6895074638001915, 3.7032759133908737, 4.476102535003248, 5.358743725639364], [0.8588123954813254, 1.5422753306534616, 2.2549773576363616, 2.6252281124267567, 3.1864242984923816, 3.6895074638001915, 3.7032759133908737, 4.476102535003248, 5.358743725639364, 5.723629709540736], [0.1915194503788923, 0.6221087710398319, 0.4377277390071145, 0.7853585837137692, 0.7799758081188035, 0.2725926052826416, 0.2764642551430967, 0.8018721775350193, 0.9581393536837052, 0.8759326347420947]], "names": ["position0", "position1", "series0"]}</toyplot:data-table><g class="toyplot-Series"><rect class="toyplot-Datum" height="34.4735010682" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="15.0298537657" x="70.7345180987" y="205.526498932"></rect><rect class="toyplot-Datum" height="111.979578787" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="20.5038880552" x="85.7643718644" y="128.020421213"></rect><rect class="toyplot-Datum" height="78.7909930213" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="21.3810608095" x="106.26825992" y="161.209006979"></rect><rect class="toyplot-Datum" height="141.364545068" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="11.1075226437" x="127.649320729" y="98.6354549315"></rect><rect class="toyplot-Datum" height="140.395645461" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="16.835885582" x="138.756843373" y="99.6043545386"></rect><rect class="toyplot-Datum" height="49.0666689509" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="15.0924949592" x="155.592728955" y="190.933331049"></rect><rect class="toyplot-Datum" height="49.7635659258" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="0.41305348772" x="170.685223914" y="190.236434074"></rect><rect class="toyplot-Datum" height="144.336991956" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="23.1847986484" x="171.098277402" y="95.6630080437"></rect><rect class="toyplot-Datum" height="172.465083663" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="26.4792357191" x="194.28307605" y="67.5349163369"></rect><rect class="toyplot-Datum" height="157.667874254" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="10.946579517" x="220.762311769" y="82.3321257464"></rect></g></g></g><g class="toyplot-coordinates" style="visibility:hidden;"><rect height="14" style="opacity:0.75;stroke:none;fill:white;" width="90" x="150" y="60"></rect><text s ...
#     (function()
#     {
#       // Workaround for browsers that don't support alignment-baseline
#       if(window.CSS !== undefined && window.CSS.supports !== undefined)
#       {
#         if(!window.CSS.supports("alignment-baseline", "middle"))
#         {
#           var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t0fb58cd309674c1e8c6e137c174da327 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               if(match[1] == "middle")
#               {
#                 var style = getComputedStyle(text[i]);
#                 var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#                 var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#                 dy += 0.4 * font_size;
#                 text[i].setAttribute("dy", dy);
#               }
#             }
#           }
#         }
#         if(!window.CSS.supports("baseline-shift", "0"))
#         {
#           var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t0fb58cd309674c1e8c6e137c174da327 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               var style = getComputedStyle(text[i]);
#               var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#               var percent = 0.01 * match[1].substr(0, match[1].length-1);
#               var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#               dy -= percent * font_size
#               text[i].setAttribute("dy", dy);
#             }
#           }
#         }
#       }
#     })();
#     </script><script>
#     // Allow users to extract embedded raw data

# %%
observations = numpy.random.normal(size=(10000))
toyplot.bars(numpy.histogram(observations, 10), width=300, height=300);
# Out:
# <div align="center" class="toyplot" id="t0a34afb843a841cd99e3d751acaf5e7e"><svg height="300px" id="t923a7d7902f74ee89a4209334cc05b1e" style="opacity:1.0;font-size:12px;font-family:helvetica;stroke-opacity:1.0;fill-opacity:1.0;stroke:#343434;stroke-width:1.0;background-color:transparent;fill:#343434;" width="300px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-Axes2D" id="tac93b97209f84ff9b99f4bacc626920e"><toyplot:axes>{"y": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 3000.0, "min": 0.0}}], "x": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 4.0, "min": -4.0}}]}</toyplot:axes><clipPath id="te5e39ebb39bb466a848411a394b07ec7"><rect height="200" width="200" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#te5e39ebb39bb466a848411a394b07ec7)" style="cursor:crosshair;"><rect height="200" style="pointer-events:all;visibility:hidden;" width="200" x="50" y="50"></rect><g class="toyplot-BarMagnitudesMark" id="t26f61e4c211a4b0aa395a5ca0f618aee" style="stroke:white;stroke-width:1.0;"><toyplot:data-table title="Bar Data">{"data": [[-3.9813647709032844, -3.213924454200332, -2.446484137497379, -1.6790438207944263, -0.9116035040914738, -0.1441631873885214, 0.6232771293144319, 1.3907174460173843, 2.1581577627203368, 2.925598079423289], [-3.213924454200332, -2.446484137497379, -1.6790438207944263, -0.9116035040914738, -0.1441631873885214, 0.6232771293144319, 1.3907174460173843, 2.1581577627203368, 2.925598079423289, 3.6930383961262416], [9.0, 70.0, 381.0, 1338.0, 2554.0, 2931.0, 1885.0, 662.0, 153.0, 17.0]], "names": ["position0", "position1", "series0"]}</toyplot:data-table><g class="toyplot-Series"><rect class="toyplot-Datum" height="0.54" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.2674071258" x="60.4192926547" y="239.46"></rect><rect class="toyplot-Datum" height="4.2" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.2674071258" x="77.6866997805" y="235.8"></rect><rect class="toyplot-Datum" height="22.86" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.2674071258" x="94.9541069063" y="217.14"></rect><rect class="toyplot-Datum" height="80.28" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.2674071258" x="112.221514032" y="159.72"></rect><rect class="toyplot-Datum" height="153.24" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.2674071258" x="129.488921158" y="86.76"></rect><rect class="toyplot-Datum" height="175.86" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.2674071258" x="146.756328284" y="64.14"></rect><rect class="toyplot-Datum" height="113.1" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.2674071258" x="164.02373541" y="126.9"></rect><rect class="toyplot-Datum" height="39.72" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.2674071258" x="181.291142535" y="200.28"></rect><rect class="toyplot-Datum" height="9.18" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.2674071258" x="198.558549661" y="230.82"></rect><rect class="toyplot-Datum" height="1.02" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.2674071258" x="215.825956787" y="238.98"></rect></g></g></g><g class="toyplot-coordinates" style="visibility:hidden;"><rect height="14" style="opacity:0.75;stroke:none;fill:white;" width="90" x="150" y="60"></rect><text style="font-size:10px;font-weight:normal;stroke:none;text-anchor:middle;alignment-baseline:middle;" x="195.0" y="67.0"></text></g><line style="" x1="60.4192926547" x2="233.093363913" y1="250" y2="250"></line><g><text style="font-size:10px;baseline-shift:-80%;alignment-bas ...
#     (function()
#     {
#       // Workaround for browsers that don't support alignment-baseline
#       if(window.CSS !== undefined && window.CSS.supports !== undefined)
#       {
#         if(!window.CSS.supports("alignment-baseline", "middle"))
#         {
#           var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t0a34afb843a841cd99e3d751acaf5e7e text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               if(match[1] == "middle")
#               {
#                 var style = getComputedStyle(text[i]);
#                 var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#                 var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#                 dy += 0.4 * font_size;
#                 text[i].setAttribute("dy", dy);
#               }
#             }
#           }
#         }
#         if(!window.CSS.supports("baseline-shift", "0"))
#         {
#           var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t0a34afb843a841cd99e3d751acaf5e7e text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               var style = getComputedStyle(text[i]);
#               var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#               var percent = 0.01 * match[1].substr(0, match[1].length-1);
#               var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#               dy -= percent * font_size
#               text[i].setAttribute("dy", dy);
#             }
#           }
#         }
#       }
#     })();
#     </sc

# %%
data = numpy.column_stack((numpy.random.random(10), numpy.random.random(10)))

toyplot.bars(data, width=300, height=300);
toyplot.bars(x, data, width=300, height=300);
toyplot.bars(x2, data, width=300, height=300);
toyplot.bars(x4, x5, data, width=300, height=300);
# Out:
# <div align="center" class="toyplot" id="t81d80f981def433da0a0522251cb1084"><svg height="300px" id="t22f41d0f767f4cb0a7992513847e160a" style="opacity:1.0;font-size:12px;font-family:helvetica;stroke-opacity:1.0;fill-opacity:1.0;stroke:#343434;stroke-width:1.0;background-color:transparent;fill:#343434;" width="300px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-Axes2D" id="ta99d1e21fbff455babcc2aac93eab83d"><toyplot:axes>{"y": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 1.7255830023647287, "min": 0.0}}], "x": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 10.0, "min": -0.5}}]}</toyplot:axes><clipPath id="t0c71cae9f79a4d6885effd69a534613a"><rect height="200" width="200" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t0c71cae9f79a4d6885effd69a534613a)" style="cursor:crosshair;"><rect height="200" style="pointer-events:all;visibility:hidden;" width="200" x="50" y="50"></rect><g class="toyplot-BarMagnitudesMark" id="td42f92e51b464f13a7554848ef5aa63b" style="stroke:white;stroke-width:1.0;"><toyplot:data-table title="Bar Data">{"data": [[-0.5, 0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5], [0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5], [0.9446142393124688, 0.2018885708773941, 0.22164458879382343, 0.37475858551970886, 0.8730276147996948, 0.7602558238200506, 0.3931468975406761, 0.5739268568327561, 0.1288836006832733, 0.8602040650419305], [0.48158204664059034, 0.20294297591853705, 0.7459864990979725, 0.11302668495114399, 0.8525553875650338, 0.8618417444823707, 0.20814850497831372, 0.5325007797081057, 0.6481564599426972, 0.5539959704420471]], "names": ["position0", "position1", "series0", "series1"]}</toyplot:data-table><g class="toyplot-Series"><rect class="toyplot-Datum" height="98.5351402067" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="60.0" y="141.464859793"></rect><rect class="toyplot-Datum" height="21.059515948" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="77.1428571429" y="218.940484052"></rect><rect class="toyplot-Datum" height="23.1203169759" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="94.2857142857" y="216.879683024"></rect><rect class="toyplot-Datum" height="39.0920316792" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="111.428571429" y="200.907968321"></rect><rect class="toyplot-Datum" height="91.0677553317" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="128.571428571" y="148.932244668"></rect><rect class="toyplot-Datum" height="79.3042398425" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="145.714285714" y="160.695760158"></rect><rect class="toyplot-Datum" height="41.0101637883" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="162.857142857" y="198.989836212"></rect><rect class="toyplot-Datum" height="59.8677861849" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="180.0" y="180.132213815"></rect><rect class="toyplot-Datum" height="13.444179788" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="197.142857143" y="226.555820212"></rect><rect class="toyplot-Datum" height="89.7300978831" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="214.285714286" y="150.269902117"></rect></g><g class="toyplot-Series"><rect class="toyplot-Datum" height="50.2350615859" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(98.8%,55.3%,38.4%,1);" width="17.1428571429" x="60.0" y="91.2297982075"></rect><rect class="toyplot-Datum"  ...
# <div align="center" class="toyplot" id="t2245efecf9a1455181cdbaa65d3c41fc"><svg height="300px" id="tfcaa46feac3643e79a112fe4123e423a" style="opacity:1.0;font-size:12px;font-family:helvetica;stroke-opacity:1.0;fill-opacity:1.0;stroke:#343434;stroke-width:1.0;background-color:transparent;fill:#343434;" width="300px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-Axes2D" id="te3b0e6500e5d4c289b56f09c8f618d9d"><toyplot:axes>{"y": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 1.7255830023647287, "min": 0.0}}], "x": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 2.1111111111111112, "min": -0.1111111111111111}}]}</toyplot:axes><clipPath id="tb15347d837a7475e841b186ddcae8cbb"><rect height="200" width="200" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tb15347d837a7475e841b186ddcae8cbb)" style="cursor:crosshair;"><rect height="200" style="pointer-events:all;visibility:hidden;" width="200" x="50" y="50"></rect><g class="toyplot-BarMagnitudesMark" id="t93839e99f47948f9996d513c4a94c395" style="stroke:white;stroke-width:1.0;"><toyplot:data-table title="Bar Data">{"data": [[-0.1111111111111111, 0.1111111111111111, 0.3333333333333333, 0.5555555555555556, 0.7777777777777777, 1.0, 1.2222222222222223, 1.4444444444444442, 1.6666666666666665, 1.8888888888888888], [0.1111111111111111, 0.3333333333333333, 0.5555555555555556, 0.7777777777777777, 1.0, 1.2222222222222223, 1.4444444444444442, 1.6666666666666665, 1.8888888888888888, 2.111111111111111], [0.9446142393124688, 0.2018885708773941, 0.22164458879382343, 0.37475858551970886, 0.8730276147996948, 0.7602558238200506, 0.3931468975406761, 0.5739268568327561, 0.1288836006832733, 0.8602040650419305], [0.48158204664059034, 0.20294297591853705, 0.7459864990979725, 0.11302668495114399, 0.8525553875650338, 0.8618417444823707, 0.20814850497831372, 0.5325007797081057, 0.6481564599426972, 0.5539959704420471]], "names": ["position0", "position1", "series0", "series1"]}</toyplot:data-table><g class="toyplot-Series"><rect class="toyplot-Datum" height="98.5351402067" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="60.0" y="141.464859793"></rect><rect class="toyplot-Datum" height="21.059515948" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="78.0" y="218.940484052"></rect><rect class="toyplot-Datum" height="23.1203169759" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="96.0" y="216.879683024"></rect><rect class="toyplot-Datum" height="39.0920316792" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="114.0" y="200.907968321"></rect><rect class="toyplot-Datum" height="91.0677553317" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="132.0" y="148.932244668"></rect><rect class="toyplot-Datum" height="79.3042398425" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="150.0" y="160.695760158"></rect><rect class="toyplot-Datum" height="41.0101637883" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="168.0" y="198.989836212"></rect><rect class="toyplot-Datum" height="59.8677861849" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="186.0" y="180.132213815"></rect><rect class="toyplot-Datum" height="13.444179788" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="204.0" y="226.555820212"></rect><rect class="toyplot-Datum" height="89.7300978831" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="222.0" y="150.269902117"></rect></g><g class="toyplot-Series"><rect class="toyplot-Datum" height="50.2350615859" style="opacity:1.0;strok ...
# <div align="center" class="toyplot" id="t9b5509bbade241589267a39fc2a0ad6c"><svg height="300px" id="td9df0c10946d4f9eaac69d4bc1ffe5f8" style="opacity:1.0;font-size:12px;font-family:helvetica;stroke-opacity:1.0;fill-opacity:1.0;stroke:#343434;stroke-width:1.0;background-color:transparent;fill:#343434;" width="300px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-Axes2D" id="t8ae9842503314a4fa9c8a5c3e4a093ec"><toyplot:axes>{"y": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 1.7255830023647287, "min": 0.0}}], "x": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 1.0809737592968607, "min": -0.018518518518518517}}]}</toyplot:axes><clipPath id="t5a23205e8c154239a324d1811b4de7d3"><rect height="200" width="200" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t5a23205e8c154239a324d1811b4de7d3)" style="cursor:crosshair;"><rect height="200" style="pointer-events:all;visibility:hidden;" width="200" x="50" y="50"></rect><g class="toyplot-BarMagnitudesMark" id="t3906dd539b694da39181ece1f7dd3f04" style="stroke:white;stroke-width:1.0;"><toyplot:data-table title="Bar Data">{"data": [[-0.018518518518518517, 0.018518518518518517, 0.07089679860641093, 0.14860332495283002, 0.24437319301308574, 0.3551914793981287, 0.4792088582258892, 0.6151332895213185, 0.761994003248549, 0.9190262407031393], [0.018518518518518517, 0.07089679860641093, 0.14860332495283002, 0.24437319301308574, 0.3551914793981287, 0.4792088582258892, 0.6151332895213185, 0.761994003248549, 0.9190262407031393, 1.0809737592968607], [0.9446142393124688, 0.2018885708773941, 0.22164458879382343, 0.37475858551970886, 0.8730276147996948, 0.7602558238200506, 0.3931468975406761, 0.5739268568327561, 0.1288836006832733, 0.8602040650419305], [0.48158204664059034, 0.20294297591853705, 0.7459864990979725, 0.11302668495114399, 0.8525553875650338, 0.8618417444823707, 0.20814850497831372, 0.5325007797081057, 0.6481564599426972, 0.5539959704420471]], "names": ["position0", "position1", "series0", "series1"]}</toyplot:data-table><g class="toyplot-Series"><rect class="toyplot-Datum" height="98.5351402067" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="6.06340471978" x="60.0" y="141.464859793"></rect><rect class="toyplot-Datum" height="21.059515948" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="8.57494918887" x="66.0634047198" y="218.940484052"></rect><rect class="toyplot-Datum" height="23.1203169759" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="12.7214852024" x="74.6383539086" y="216.879683024"></rect><rect class="toyplot-Datum" height="39.0920316792" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="15.6786696902" x="87.359839111" y="200.907968321"></rect><rect class="toyplot-Datum" height="91.0677553317" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.142275259" x="103.038508801" y="148.932244668"></rect><rect class="toyplot-Datum" height="79.3042398425" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="20.3031241232" x="121.18078406" y="160.695760158"></rect><rect class="toyplot-Datum" height="41.0101637883" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="22.2524506328" x="141.483908184" y="198.989836212"></rect><rect class="toyplot-Datum" height="59.8677861849" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="24.0428505086" x="163.736358816" y="180.132213815"></rect><rect class="toyplot-Datum" height="13.444179788" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="25.708050263" x="187.779209325" y="226.555820212"></rect><rect class="toyplot-Datum" height="89.7300978831" style="opacity:1.0;stroke:white;stroke-width:1. ...
# <div align="center" class="toyplot" id="tf97cc7165c394ed498c0905c5a4c5e42"><svg height="300px" id="tecf7396cd6324add9c0dd4951bfb3035" style="opacity:1.0;font-size:12px;font-family:helvetica;stroke-opacity:1.0;fill-opacity:1.0;stroke:#343434;stroke-width:1.0;background-color:transparent;fill:#343434;" width="300px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-Axes2D" id="t5227196ac87741f6a273853f4e92c0ac"><toyplot:axes>{"y": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 1.7255830023647287, "min": 0.0}}], "x": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 6.0, "min": 0.0}}]}</toyplot:axes><clipPath id="tcbcf063bab8240dc8dc52495c486c650"><rect height="200" width="200" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tcbcf063bab8240dc8dc52495c486c650)" style="cursor:crosshair;"><rect height="200" style="pointer-events:all;visibility:hidden;" width="200" x="50" y="50"></rect><g class="toyplot-BarMagnitudesMark" id="t114b9f49de8a41518a86fcc5dea2dcf4" style="stroke:white;stroke-width:1.0;"><toyplot:data-table title="Bar Data">{"data": [[0.35781726995786667, 0.8588123954813254, 1.5422753306534616, 2.2549773576363616, 2.6252281124267567, 3.1864242984923816, 3.6895074638001915, 3.7032759133908737, 4.476102535003248, 5.358743725639364], [0.8588123954813254, 1.5422753306534616, 2.2549773576363616, 2.6252281124267567, 3.1864242984923816, 3.6895074638001915, 3.7032759133908737, 4.476102535003248, 5.358743725639364, 5.723629709540736], [0.9446142393124688, 0.2018885708773941, 0.22164458879382343, 0.37475858551970886, 0.8730276147996948, 0.7602558238200506, 0.3931468975406761, 0.5739268568327561, 0.1288836006832733, 0.8602040650419305], [0.48158204664059034, 0.20294297591853705, 0.7459864990979725, 0.11302668495114399, 0.8525553875650338, 0.8618417444823707, 0.20814850497831372, 0.5325007797081057, 0.6481564599426972, 0.5539959704420471]], "names": ["position0", "position1", "series0", "series1"]}</toyplot:data-table><g class="toyplot-Series"><rect class="toyplot-Datum" height="98.5351402067" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="15.0298537657" x="70.7345180987" y="141.464859793"></rect><rect class="toyplot-Datum" height="21.059515948" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="20.5038880552" x="85.7643718644" y="218.940484052"></rect><rect class="toyplot-Datum" height="23.1203169759" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="21.3810608095" x="106.26825992" y="216.879683024"></rect><rect class="toyplot-Datum" height="39.0920316792" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="11.1075226437" x="127.649320729" y="200.907968321"></rect><rect class="toyplot-Datum" height="91.0677553317" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="16.835885582" x="138.756843373" y="148.932244668"></rect><rect class="toyplot-Datum" height="79.3042398425" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="15.0924949592" x="155.592728955" y="160.695760158"></rect><rect class="toyplot-Datum" height="41.0101637883" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="0.41305348772" x="170.685223914" y="198.989836212"></rect><rect class="toyplot-Datum" height="59.8677861849" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="23.1847986484" x="171.098277402" y="180.132213815"></rect><rect class="toyplot-Datum" height="13.444179788" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="26.4792357191" x="194.28307605" y="226.555820212"></rect><rect class="toyplot-Datum" height="89.7300978831" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width ...

# %%
toyplot.bars(data, width=300, height=300, baseline=None);
toyplot.bars(x, data, width=300, height=300, baseline=None);
toyplot.bars(x2, data, width=300, height=300, baseline=None);
toyplot.bars(x4, x5, data, width=300, height=300, baseline=None);
# Out:
# <div align="center" class="toyplot" id="t68b62b5cb9a24543aab886350a58ccf0"><svg height="300px" id="t837b20929bdd49129e3252788c5e3a82" style="opacity:1.0;font-size:12px;font-family:helvetica;stroke-opacity:1.0;fill-opacity:1.0;stroke:#343434;stroke-width:1.0;background-color:transparent;fill:#343434;" width="300px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-Axes2D" id="t7babe56c33c140619da9fc6ebe1457fb"><toyplot:axes>{"y": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 0.9446142393124688, "min": 0.0}}], "x": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 10.0, "min": -0.5}}]}</toyplot:axes><clipPath id="tb394752e3704443da0295c37aabb52ad"><rect height="200" width="200" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tb394752e3704443da0295c37aabb52ad)" style="cursor:crosshair;"><rect height="200" style="pointer-events:all;visibility:hidden;" width="200" x="50" y="50"></rect><g class="toyplot-BarBoundariesMark" id="t54f121e0d4a043a49680034a0200993b" style="stroke:white;stroke-width:1.0;"><toyplot:data-table title="Bar Data">{"data": [[[-0.5, 0.5], [0.5, 1.5], [1.5, 2.5], [2.5, 3.5], [3.5, 4.5], [4.5, 5.5], [5.5, 6.5], [6.5, 7.5], [7.5, 8.5], [8.5, 9.5]], [0.9446142393124688, 0.2018885708773941, 0.22164458879382343, 0.37475858551970886, 0.8730276147996948, 0.7602558238200506, 0.3931468975406761, 0.5739268568327561, 0.1288836006832733, 0.8602040650419305], [0.48158204664059034, 0.20294297591853705, 0.7459864990979725, 0.11302668495114399, 0.8525553875650338, 0.8618417444823707, 0.20814850497831372, 0.5325007797081057, 0.6481564599426972, 0.5539959704420471]], "names": ["position", "series0", "series1"]}</toyplot:data-table><g class="toyplot-Series"><rect class="toyplot-Datum" height="88.2326257771" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="60.0" y="60.0"></rect><rect class="toyplot-Datum" height="0.200921073923" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="77.1428571429" y="201.328408841"></rect><rect class="toyplot-Datum" height="99.9154362986" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="94.2857142857" y="97.8493058337"></rect><rect class="toyplot-Datum" height="49.8740545523" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="111.428571429" y="168.588261127"></rect><rect class="toyplot-Datum" height="3.90106431692" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="128.571428571" y="73.6411159985"></rect><rect class="toyplot-Datum" height="19.357601186" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="145.714285714" y="75.7726280733"></rect><rect class="toyplot-Datum" height="35.2521794351" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="162.857142857" y="165.084295142"></rect><rect class="toyplot-Datum" height="7.89390374622" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="180.0" y="130.635954943"></rect><rect class="toyplot-Datum" height="98.9495084626" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="197.142857143" y="116.491208862"></rect><rect class="toyplot-Datum" height="58.3491702053" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="17.1428571429" x="214.285714286" y="76.0846944037"></rect></g></g></g><g class="toyplot-coordinates" style="visibility:hidden;"><rect height="14" style="opacity:0.75;stroke:none;fill:white;" width="90" x="150" y="60"></rect><text style="font-size:10px;font-weight:normal;stroke:none;text-anchor:middle;alignm ...
#     (function()
#     {
#       // Workaround for browsers that don't support alignment-baseline
#       if(window.CSS !== undefined && window.CSS.supports !== undefined)
#       {
#         if(!window.CSS.supports("alignment-baseline", "middle"))
#         {
#           var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t68b62b5cb9a24543aab886350a58ccf0 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               if(match[1] == "middle")
#               {
#                 var style = getComputedStyle(text[i]);
#                 var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#                 var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#                 dy += 0.4 * font_size;
#                 text[i].setAttribute("dy", dy);
#               }
#             }
#           }
#         }
#         if(!window.CSS.supports("baseline-shift", "0"))
#         {
#           var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t68b62b5cb9a24543aab886350a58ccf0 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               var style = getComputedStyle(text[i]);
#               var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#               var percent = 0.01 * match[1].substr(0, match[1].length-1);
#               var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#               dy -= percent * font_size
#               text[i].setAttribute("dy", dy);
#             }
#           }
#         }
#       }
#     })();
#     </script><script>
#     // Allow users to extract embedde
# <div align="center" class="toyplot" id="t31d0000d8bb647f6aee93b1973276067"><svg height="300px" id="te2476d0a18d14603802e13b07b26f05a" style="opacity:1.0;font-size:12px;font-family:helvetica;stroke-opacity:1.0;fill-opacity:1.0;stroke:#343434;stroke-width:1.0;background-color:transparent;fill:#343434;" width="300px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-Axes2D" id="t788cef0d565947499a8dae9363114acc"><toyplot:axes>{"y": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 0.9446142393124688, "min": 0.0}}], "x": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 2.1111111111111112, "min": -0.1111111111111111}}]}</toyplot:axes><clipPath id="te3e959c7fcb7487a9ef48532777db2ef"><rect height="200" width="200" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#te3e959c7fcb7487a9ef48532777db2ef)" style="cursor:crosshair;"><rect height="200" style="pointer-events:all;visibility:hidden;" width="200" x="50" y="50"></rect><g class="toyplot-BarBoundariesMark" id="tbc648249d2bc4f6e805da123225cf2c6" style="stroke:white;stroke-width:1.0;"><toyplot:data-table title="Bar Data">{"data": [[[-0.1111111111111111, 0.1111111111111111], [0.1111111111111111, 0.3333333333333333], [0.3333333333333333, 0.5555555555555556], [0.5555555555555556, 0.7777777777777777], [0.7777777777777777, 1.0], [1.0, 1.2222222222222223], [1.2222222222222223, 1.4444444444444442], [1.4444444444444442, 1.6666666666666665], [1.6666666666666665, 1.8888888888888888], [1.8888888888888888, 2.111111111111111]], [0.9446142393124688, 0.2018885708773941, 0.22164458879382343, 0.37475858551970886, 0.8730276147996948, 0.7602558238200506, 0.3931468975406761, 0.5739268568327561, 0.1288836006832733, 0.8602040650419305], [0.48158204664059034, 0.20294297591853705, 0.7459864990979725, 0.11302668495114399, 0.8525553875650338, 0.8618417444823707, 0.20814850497831372, 0.5325007797081057, 0.6481564599426972, 0.5539959704420471]], "names": ["position", "series0", "series1"]}</toyplot:data-table><g class="toyplot-Series"><rect class="toyplot-Datum" height="88.2326257771" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="60.0" y="60.0"></rect><rect class="toyplot-Datum" height="0.200921073923" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="78.0" y="201.328408841"></rect><rect class="toyplot-Datum" height="99.9154362986" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="96.0" y="97.8493058337"></rect><rect class="toyplot-Datum" height="49.8740545523" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="114.0" y="168.588261127"></rect><rect class="toyplot-Datum" height="3.90106431692" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="132.0" y="73.6411159985"></rect><rect class="toyplot-Datum" height="19.357601186" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="150.0" y="75.7726280733"></rect><rect class="toyplot-Datum" height="35.2521794351" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="168.0" y="165.084295142"></rect><rect class="toyplot-Datum" height="7.89390374622" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="186.0" y="130.635954943"></rect><rect class="toyplot-Datum" height="98.9495084626" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="204.0" y="116.491208862"></rect><rect class="toyplot-Datum" height="58.3491702053" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.0" x="222.0" y="76.0846944037"></rect></g></g></g><g class="toyplot-coordinates" style="visibility:hidden;"><rect height="14" style="opacity:0.75; ...
#     (function()
#     {
#       // Workaround for browsers that don't support alignment-baseline
#       if(window.CSS !== undefined && window.CSS.supports !== undefined)
#       {
#         if(!window.CSS.supports("alignment-baseline", "middle"))
#         {
#           var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t31d0000d8bb647f6aee93b1973276067 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               if(match[1] == "middle")
#               {
#                 var style = getComputedStyle(text[i]);
#                 var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#                 var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#                 dy += 0.4 * font_size;
#                 text[i].setAttribute("dy", dy);
#               }
#             }
#           }
#         }
#         if(!window.CSS.supports("baseline-shift", "0"))
#         {
#           var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t31d0000d8bb647f6aee93b1973276067 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               var style = getComputedStyle(text[i]);
#               var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#               var percent = 0.01 * match[1].substr(0, match[1].length-1);
#               var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#               dy -= percent * font_size
#               text[i].setAttribute("dy", dy
# <div align="center" class="toyplot" id="t10472eec3cea481db020006b66c8ec98"><svg height="300px" id="tef0c1192df5b43ce9a3862d9343ace1a" style="opacity:1.0;font-size:12px;font-family:helvetica;stroke-opacity:1.0;fill-opacity:1.0;stroke:#343434;stroke-width:1.0;background-color:transparent;fill:#343434;" width="300px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-Axes2D" id="t3fc8ebd99d5849f2b46f5819d585d369"><toyplot:axes>{"y": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 0.9446142393124688, "min": 0.0}}], "x": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 1.0809737592968607, "min": -0.018518518518518517}}]}</toyplot:axes><clipPath id="tefffdef2c49d4fcc93bf2429b479812a"><rect height="200" width="200" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tefffdef2c49d4fcc93bf2429b479812a)" style="cursor:crosshair;"><rect height="200" style="pointer-events:all;visibility:hidden;" width="200" x="50" y="50"></rect><g class="toyplot-BarBoundariesMark" id="t5807a1b7152d4fc68cceca805caf914b" style="stroke:white;stroke-width:1.0;"><toyplot:data-table title="Bar Data">{"data": [[[-0.018518518518518517, 0.018518518518518517], [0.018518518518518517, 0.07089679860641093], [0.07089679860641093, 0.14860332495283002], [0.14860332495283002, 0.24437319301308574], [0.24437319301308574, 0.3551914793981287], [0.3551914793981287, 0.4792088582258892], [0.4792088582258892, 0.6151332895213185], [0.6151332895213185, 0.761994003248549], [0.761994003248549, 0.9190262407031393], [0.9190262407031393, 1.0809737592968607]], [0.9446142393124688, 0.2018885708773941, 0.22164458879382343, 0.37475858551970886, 0.8730276147996948, 0.7602558238200506, 0.3931468975406761, 0.5739268568327561, 0.1288836006832733, 0.8602040650419305], [0.48158204664059034, 0.20294297591853705, 0.7459864990979725, 0.11302668495114399, 0.8525553875650338, 0.8618417444823707, 0.20814850497831372, 0.5325007797081057, 0.6481564599426972, 0.5539959704420471]], "names": ["position", "series0", "series1"]}</toyplot:data-table><g class="toyplot-Series"><rect class="toyplot-Datum" height="88.2326257771" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="6.06340471978" x="60.0" y="60.0"></rect><rect class="toyplot-Datum" height="0.200921073923" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="8.57494918887" x="66.0634047198" y="201.328408841"></rect><rect class="toyplot-Datum" height="99.9154362986" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="12.7214852024" x="74.6383539086" y="97.8493058337"></rect><rect class="toyplot-Datum" height="49.8740545523" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="15.6786696902" x="87.359839111" y="168.588261127"></rect><rect class="toyplot-Datum" height="3.90106431692" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="18.142275259" x="103.038508801" y="73.6411159985"></rect><rect class="toyplot-Datum" height="19.357601186" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="20.3031241232" x="121.18078406" y="75.7726280733"></rect><rect class="toyplot-Datum" height="35.2521794351" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="22.2524506328" x="141.483908184" y="165.084295142"></rect><rect class="toyplot-Datum" height="7.89390374622" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="24.0428505086" x="163.736358816" y="130.635954943"></rect><rect class="toyplot-Datum" height="98.9495084626" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="25.708050263" x="187.779209325" y="116.491208862"></rect><rect class="toyplot-Datum" height="58.3491702053" style="opacity:1.0;stroke:white;stroke-width:1.0;f ...
#     (function()
#     {
#       // Workaround for browsers that don't support alignment-baseline
#       if(window.CSS !== undefined && window.CSS.supports !== undefined)
#       {
#         if(!window.CSS.supports("alignment-baseline", "middle"))
#         {
#           var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t10472eec3cea481db020006b66c8ec98 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               if(match[1] == "middle")
#               {
#                 var style = getComputedStyle(text[i]);
#                 var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#                 var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#                 dy += 0.4 * font_size;
#                 text[i].setAttribute("dy", dy);
#               }
#             }
#           }
#         }
#         if(!window.CSS.supports("baseline-shift", "0"))
#         {
#           var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t10472eec3cea481db020006b66c8ec98 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               var style = getComputedStyle(text[i]);
#               var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
# <div align="center" class="toyplot" id="t2382206cd5014e55b323804b339a5181"><svg height="300px" id="t551d336de13044e8ba301d22e0f945d9" style="opacity:1.0;font-size:12px;font-family:helvetica;stroke-opacity:1.0;fill-opacity:1.0;stroke:#343434;stroke-width:1.0;background-color:transparent;fill:#343434;" width="300px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-Axes2D" id="tf43074aa25c34f02a6b3258e2725a39a"><toyplot:axes>{"y": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 0.9446142393124688, "min": 0.0}}], "x": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 6.0, "min": 0.0}}]}</toyplot:axes><clipPath id="t0ba19562c7bb47d2b494bba4478c5a7c"><rect height="200" width="200" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t0ba19562c7bb47d2b494bba4478c5a7c)" style="cursor:crosshair;"><rect height="200" style="pointer-events:all;visibility:hidden;" width="200" x="50" y="50"></rect><g class="toyplot-BarBoundariesMark" id="t98b41f879c904888a568d922f01927a5" style="stroke:white;stroke-width:1.0;"><toyplot:data-table title="Bar Data">{"data": [[[0.35781726995786667, 0.8588123954813254], [0.8588123954813254, 1.5422753306534616], [1.5422753306534616, 2.2549773576363616], [2.2549773576363616, 2.6252281124267567], [2.6252281124267567, 3.1864242984923816], [3.1864242984923816, 3.6895074638001915], [3.6895074638001915, 3.7032759133908737], [3.7032759133908737, 4.476102535003248], [4.476102535003248, 5.358743725639364], [5.358743725639364, 5.723629709540736]], [0.9446142393124688, 0.2018885708773941, 0.22164458879382343, 0.37475858551970886, 0.8730276147996948, 0.7602558238200506, 0.3931468975406761, 0.5739268568327561, 0.1288836006832733, 0.8602040650419305], [0.48158204664059034, 0.20294297591853705, 0.7459864990979725, 0.11302668495114399, 0.8525553875650338, 0.8618417444823707, 0.20814850497831372, 0.5325007797081057, 0.6481564599426972, 0.5539959704420471]], "names": ["position", "series0", "series1"]}</toyplot:data-table><g class="toyplot-Series"><rect class="toyplot-Datum" height="88.2326257771" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="15.0298537657" x="70.7345180987" y="60.0"></rect><rect class="toyplot-Datum" height="0.200921073923" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="20.5038880552" x="85.7643718644" y="201.328408841"></rect><rect class="toyplot-Datum" height="99.9154362986" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="21.3810608095" x="106.26825992" y="97.8493058337"></rect><rect class="toyplot-Datum" height="49.8740545523" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="11.1075226437" x="127.649320729" y="168.588261127"></rect><rect class="toyplot-Datum" height="3.90106431692" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="16.835885582" x="138.756843373" y="73.6411159985"></rect><rect class="toyplot-Datum" height="19.357601186" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="15.0924949592" x="155.592728955" y="75.7726280733"></rect><rect class="toyplot-Datum" height="35.2521794351" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="0.41305348772" x="170.685223914" y="165.084295142"></rect><rect class="toyplot-Datum" height="7.89390374622" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="23.1847986484" x="171.098277402" y="130.635954943"></rect><rect class="toyplot-Datum" height="98.9495084626" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="26.4792357191" x="194.28307605" y="116.491208862"></rect><rect class="toyplot-Datum" height="58.3491702053" style="opacity:1.0;stroke:white;stroke-width:1.0;fill:rgba(40%,76.1%,64.7%,1);" width="1 ...
#     (function()
#     {
#       // Workaround for browsers that don't support alignment-baseline
#       if(window.CSS !== undefined && window.CSS.supports !== undefined)
#       {
#         if(!window.CSS.supports("alignment-baseline", "middle"))
#         {
#           var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t2382206cd5014e55b323804b339a5181 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               if(match[1] == "middle")
#               {
#                 var style = getComputedStyle(text[i]);
#                 var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#                 var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#                 dy += 0.4 * font_size;
#                 text[i].setAttribute("dy", dy);
#               }
#             }
#           }
#         }
#         if(!window.CSS.supports("baseline-shift", "0"))
#         {
#           var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#t2382206cd5014e55b323804b339a5181 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               var style = getComputedStyle(t
