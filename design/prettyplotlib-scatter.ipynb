# %%
import numpy
import toyplot

# %%
canvas = toyplot.Canvas()
axes = canvas.axes()
for i in range(8):
    x = numpy.random.normal(loc=i, size=1000)
    y = numpy.random.normal(loc=i, size=1000)
    axes.scatterplot(x, y, size=40, mstyle={"opacity":0.4, "stroke":"none", "stroke-width":0.1})
# Out:
# <div align="center" class="toyplot" id="tbbd1ed43234f4441ae1811a95c40fc01"><svg height="600px" id="tc47c83a29b40424989fbe8451f62ebba" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-Axes2D" id="tb4b83a526729432dabbd43afa3d1d6c6"><toyplot:axes>{"x": [{"domain": {"max": 10.077478314330889, "min": -5.0}, "range": {"max": 540, "min": 60}, "scale": "linear"}], "y": [{"domain": {"max": 10.3504385754865, "min": -5.0}, "range": {"max": 540, "min": 60}, "scale": "linear"}]}</toyplot:axes><clipPath id="t99ca7caa07814370a91fd6b648f493db"><rect height="500" width="500" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t99ca7caa07814370a91fd6b648f493db)" style="cursor:crosshair"><rect height="500" style="pointer-events:all;visibility:
# ...
