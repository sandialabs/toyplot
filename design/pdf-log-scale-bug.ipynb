# %%
import numpy
import toyplot.pdf

x = numpy.linspace(0.001, 1000000)
canvas, axes, mark = toyplot.plot(x, x, xscale="log", yscale="log")
# Out:
# <div align="center" class="toyplot" id="td2733668087c460f8ac772532ff03d6f"><svg height="600px" id="tf279e051b18d4195951e9649a2135de3" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tf837404cb42d441583c4a61dc32498a1"><clipPath id="t97bf02029f114fbe8e7a2ea9b994a16f"><rect height="520.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t97bf02029f114fbe8e7a2ea9b994a16f)" style="cursor:crosshair"><rect height="520.0" style="pointer-events:all;visibility:hidden" width="520.0" x="40.0" y="40.0"></rect><g class="toyplot-mark-Plot" id="t82adfa1123d64b3989ed474caa367053" style="fill:none"><g class="toyplo
# ...

# %%
toyplot.pdf.render(canvas, "test.pdf")
