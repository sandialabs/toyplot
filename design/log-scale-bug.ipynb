# %%
import numpy
import toyplot

canvas, axes, mark = toyplot.bars(numpy.linspace(0, 2)**2, width=400)
axes.y.scale = "log"
# Out:
# <div align="center" class="toyplot" id="tabff4a4dba44476da3628a62a032d362"><svg class="toyplot-canvas-Canvas" height="400.0px" id="tf5e0ee13d13642b5b3b2a8e31413925e" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 400.0 400.0" width="400.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t7a8c4f69939e4ac78f075404cf843d03"><clipPath id="t30048d84eb604ce8b1a533733eaf2af5"><rect height="320.0" width="320.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t30048d84eb604ce8b1a533733eaf2af5)"><rect height="320.0" style="pointer-events:all;visibility:hidden" width="320.0" x="40.0" y="40.0"></rect><g class="toyplot-mark-BarMagnitudes" id="t7b21c4fcf4f844f6b5bfc73c8ea91d51" style="stroke:rgb(100%,100%,100%);stroke-opaci
# ...

# %%
import numpy
import toyplot

canvas, axes, mark = toyplot.bars(numpy.linspace(0, 2)**2, width=400)
axes.y.scale = "log"
axes.y.domain.min = 1
# Out:
# <div align="center" class="toyplot" id="t4c43493dbb654db5bb556e5b35748731"><svg class="toyplot-canvas-Canvas" height="400.0px" id="t511429d13d6e428fba97d578cd3197ba" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 400.0 400.0" width="400.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tcab85efd46e64023bfcb4696bd2fc328"><clipPath id="t3395a3ae608746deb34ade7ba2b64d76"><rect height="320.0" width="320.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t3395a3ae608746deb34ade7ba2b64d76)"><rect height="320.0" style="pointer-events:all;visibility:hidden" width="320.0" x="40.0" y="40.0"></rect><g class="toyplot-mark-BarMagnitudes" id="td1f1bc439ae94ee3905b22d00960ca1e" style="stroke:rgb(100%,100%,100%);stroke-opaci
# ...
