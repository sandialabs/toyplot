# %%
import toyplot.config
toyplot.config.width=800
toyplot.config.height=400

# %%
toyplot.plot(range(100));
# Out:
# <div class="toyplot" id="t2ee6467ba17140b294a4391451968c4f" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="400.0px" id="t0fb7577275cf459cafccbb641af1bc3e" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 800.0 400.0" width="800.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t6cd011984a934ef4a60e69514af4d7b3"><clipPath id="t455c6697beb8402b8dd2fc95596d7822"><rect height="320.0" width="720.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t455c6697beb8402b8dd2fc95596d7822)"><g class="toyplot-mark-Plot" id="t9947e3f7cc754032b5ddd385c9e2cc45" style="fill:none"><g class="toyplot-Series"><path d="M 50.0 350.0 L 57.0 347.0 L 64.0 344.0 L 71.0 
# ...

# %%
toyplot.plot(range(30));
# Out:
# <div class="toyplot" id="t2fa6671e07d54d8aa94cfa6f35db1a3d" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="400.0px" id="tb4290b0c26c5488291519e0e53da1072" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 800.0 400.0" width="800.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="td2a87290b2c3429bb8525ec5d7549061"><clipPath id="t909e5ce5f6ea4a61b3be2903d6489f55"><rect height="320.0" width="720.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t909e5ce5f6ea4a61b3be2903d6489f55)"><g class="toyplot-mark-Plot" id="tb30ee5ca6f3648f19e69eafcd6156b75" style="fill:none"><g class="toyplot-Series"><path d="M 50.0 350.0 L 73.33333333333334 340.0 L 96.66
# ...
