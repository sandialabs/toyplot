# %%
import toyplot.font
import toyplot.text

text = """The quick brown fox jumped over the lazy <span style="">dogs.</span>"""
text += """<br/>The quick brown fox jumped over the lazy dogs."""
text += """<br/><small>The quick brown fox jumped over the lazy dogs.</small>"""
style = {
    #"alignment-baseline": "alphabetic",
    "font-size": "20px",
    #"line-height": "200%",
    "text-anchor": "middle",
    "-toyplot-alignment-baseline": "top",
    "-toyplot-text-layout-visibility": "visible",
    "-toyplot-text-layout-line-visibility": "visible",
    "-toyplot-text-layout-box-visibility": "hidden",
}

fonts = toyplot.font.ReportlabLibrary()
layout = toyplot.text.layout(text, style, fonts)

canvas = toyplot.Canvas()
axes = canvas.cartesian()
axes.text(0, 0, text, style=style);
# Out:
# <div align="center" class="toyplot" id="t23fa21a2447f4e73bbc2e2929e8fc501"><svg class="toyplot-canvas-Canvas" height="600px" id="t3380393cfbd64bc4a73aacd40f7c7f62" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t701452b6d70b4fe4be4c87eea01a32c2"><clipPath id="te8f90dab9367464aaab7ed15efb9fc96"><rect height="520.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#te8f90dab9367464aaab7ed15efb9fc96)"><g class="toyplot-mark-Text" id="td2a78c0d09104abc9d9f0a4890f9d72c"><g class="toyplot-Series"><g class="toyplot-Datum" transform="translate(300.0,300.0)"><rect fill="none" height="69.6168" opacity="0.5" stroke="red" width="423.52" x="-211.76" y="0.0"></rect><circle fill="red" opacity="0.5" r="3" stroke="none" x="0" y="0"></circle><rect fill="none" height="24.0" opacity="0.5" stroke="green" width="423.52" x="-211.76" y="0.0"></rect><line fill="none" opacity="0.5" stroke="green" x1="-211.76" x2="211.76" y1="12.084" y2="12.084"></line><text style="-toyplot-alignment-baseline:top;-toyplot-text-layout-box-visibility:hidden;-toyplot-text-layout-line-visibility:visible;-toyplot-text-layout-visibility:visible;fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;font-family:helvetica;font-size:20.0;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="-211.76" y="17.11">The quick brown fox jumped over the lazy </text><text style="-toyplot-alignment-baseline:top;-toyplot-text-layout-box-visibility:hidden;-toyplot-text-layout-line-visibility:visible;-toyplot-text-layout-visibility:visible;fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;font-family:helvetica;font-size:20.0;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="162.84" y="17.11">dogs.</text><rect fill="none" height="24.0" opacity="0.5" stroke="green" width="423.52" x="-211.76" y="24.0"></rect><line fill="none" opacity="0.5" stroke="green" x1="-211.76" x2="211.76" y1="36.084" y2="36.084"></line><text style="-toyplot-alignment-baseline:top;-toyplot-text-layout-box-visibility:hidden;-toyplot-text-layout-line-visibility:visible;-toyplot-text-layout-visibility:visible;fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;font-family:helvetica;font-size:20.0;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="-211.76" y="41.11">The quick brown fox jumped over the lazy dogs.</text><rect fill="none" height="19.2" opacity="0.5" stroke="green" width="338.816" x="-169.408" y="50.4168"></rect><line fill="none" opacity="0.5" stroke="green" x1="-169.408" x2="169.408" y1="60.084" y2="60.084"></line><text style="-toyplot-alignment-baseline:top;-toyplot-text-layout-box-visibility:hidden;-toyplot-text-layout-line-visibility:visible;-toyplot-text-layout-visibility:visible;fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;font-family:helvetica;font-size:16.0;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="-169.408" y="64.1048">The quick brown fox jumped over the lazy dogs.</text></g></g></g></g><g class="toyplot-coordinates-Axis" id="tad81d18c6546448cbf9dd171791a5d98" transform="translate(50.0,550.0)translate(0,10.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><g transform="translate(0.0,6)"><text style="font-family:helvetica;font-size:10.0;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-8.615" y="7.18">-0.5</text></g><g transform="translate(250.0,6)"><text style="font-family:helvetica;font-size:10.0;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-6.95" y="7.18">0.0</text></g><g transform="translate(500.0,6)"><text style="f ...
#         (function()
#         {
#             function _sign(x)
#             {
#                 return x < 0 ? -1 : x > 0 ? 1 : 0;
#             }
#
#             function _mix(a, b, amount)
#             {
#                 return ((1.0 - amount) * a) + (amount * b);
#             }
#
#             function _log(x, base)
#             {
#                 return Math.log(Math.abs(x)) / Math.log(base);
#             }
#
#             function _in_range(a, x, b)
#             {
#                 var left = Math.min(a, b);
#                 var right = Math.max(a, b);
#                 return left <= x && x <= right;
#             }
#
#             function inside(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(_in_range(segment.range.min, range, segment.range.max))
#                         return true;
#                 }
#                 return false;
#             }
#
#             function to_domain(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#                     {
#                         if(segment.scale == "linear")
#                         {
#                             var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#                             return _mix(segment.domain.min, segment.domain.max, amount)
#                         }
#                         else if(segment.scale[0] == "log")
#                         {
#                             var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#                             var base = segment.scale[1];
#                             return _sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#                         }
#                     }
#                 }
#             }
#
#             function display_coordinates(e)
#             {
#                 var current = svg.createSVGPoint();
#                 current.x = e.clientX;
#                 current.y = e.clientY;

# %%
toyplot.text.dump(layout)
# Out:
# toyplot.text.Layout
#   bottom: 0.0
#   height: 120.0
#   left: -211.76
#   right: 211.76
#   style:
#     -toyplot-alignment-baseline: bottom
#     -toyplot-text-layout-box-visibility: hidden
#     -toyplot-text-layout-line-visibility: visible
#     -toyplot-text-layout-visibility: visible
#     font-family: helvetica
#     font-size: 20.0
#     vertical-align: baseline
#     white-space: pre
#   top: -120.0
#   width: 423.52
#
#   toyplot.text.LineBox
#     baseline: -94.89
#     bottom: -80.0
#     height: 40.0
#     left: -211.76
#     right: 211.76
#     style:
#       -toyplot-alignment-baseline: bottom
#       -toyplot-text-layout-box-visibility: hidden
#       -toyplot-text-layout-line-visibility: visible
#       -toyplot-text-layout-visibility: visible
#       font-family: helvetica
#       font-size: 20.0
#       vertical-align: baseline
#       white-space: pre
#     top: -120.0
#     width: 423.52
#
#     toyplot.text.TextBox
#       baseline: -94.89
#       bottom: -90.75
#       height: 18.5
#       left: -211.76
#       right: 162.84
#       style:
#         -toyplot-alignment-baseline: bottom
#         -toyplot-text-layout-box-visibility: hidden
#         -toyplot-text-layout-line-visibility: visible
#         -toyplot-text-layout-visibility: visible
#         font-family: helvetica
#         font-size: 20.0
#         vertical-align: baseline
#         white-space: pre
#       text: 'The quick brown fox jumped over the lazy '
#       top: -109.25
#       width: 374.6
#
#     toyplot.text.TextBox
#       baseline: -94.89
#       bottom: -90.75
#       height: 18.5
#       left: 162.84
#       right: 211.76
#       style:
#         -toyplot-alignment-baseline: bottom
#         -toyplot-text-layout-box-visibility: hidden
#         -toyplot-text-layout-line-visibility: visible
#         -toyplot-text-layout-visibility: visible
#         font-family: helvetica
#         font-size: 20.0
#         vertical-align: baseline
#         white-space: pre
#       text: 'dogs.'
#       top: -109.25
#       width: 48.92
#
#   toyplot.text.LineBox
#     baseline: -54.89
#     bottom: -40.0
#     height: 40.0
#     left: -211.76
#     right: 211.76
#     style:
#       -toyplot-alignment-baseline: bottom
#       -toyplot-text-layout-box-visibility: hidden
#       -toyplot-text-layout-line-visibility: visible
#       -toyplot-text-layout-visibility: visible
#       font-family: helvetica
#       font-size: 20.0
#       vertical-align: baseline
#       white-space: pre
#     top: -80.0
#     width: 423.52
#
#     toyplot.text.TextBox
#       baseline: -54.89
#       bottom: -50.75
#       height: 18.5
#       left: -211.76
#       right: 211.76
#       style:
#         -toyplot-alignment-baseline: bottom
#         -toyplot-text-layout-box-visibility: hidden
#         -toyplot-text-layout-line-visibility: visible
#         -toyplot-text-layout-visibility: visible
#         font-family: helvetica
#         font-size: 20.0
#         vertical-align: baseline
#         white-space: pre
#       text: 'The quick brown fox jumped over the lazy dogs.'
#       top: -69.25
#       width: 423.52
#
#   toyplot.text.LineBox
#     baseline: -14.89
#     bottom: 0.0
#     height: 40.0
#     left: -211.76
#     right: 211.76
#     style:
#       -toyplot-alignment-baseline: bottom
#       -toyplot-text-layout-box-visibility: hidden
#       -toyplot-text-layout-line-visibility: visible
#       -toyplot-text-layout-visibility: visible
#       font-family: helvetica
#       font-size: 20.0
#       vertical-align: baseline
#       white-space: pre
#     top: -40.0
#     width: 423.52
#
#     toyplot.text.TextBox
#       baseline: -14.89
#       bottom: -10.75
#       height: 18.5
#       left: -211.76
#       right: 211.76
#       style:
#         -toyplot-alignment-baseline: bottom
#         -toyplot-text-layout-box-visibility: hidden
#         -toyplot-text-layout-line-visibility: visible
#         -toyplot-text-layout-visibility: visible
#         font-family: helvetica
#         font-size: 20.0
#         vertical-align: baseline
#         white-space: pre
#       text: 'The quick brown fox jumped over the lazy dogs.'
#       top: -29.25
#       width: 423.52
