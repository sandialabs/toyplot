# %%
import numpy
import toyplot

# %%
canvas = toyplot.Canvas()
axes = canvas.axes()
axes.text(0, 0, "+++", style={"font-size":"32px", "-toyplot-anchor-shift":"0", "baseline-shift":"0%"}, angle=30)
axes.scatterplot([0], [0], color="black")
# Out:
# <div align="center" class="toyplot" id="tb0d4cb45f30e4df5b8d6aeb0d379deb0"><svg height="600px" id="tced5b16dbfb34ef8a06da5f78bbe48f3" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t531bb531da7d44ff9b6e5358e836df39"><clipPath id="t6f773f6af74a444992cb978d8d0f7fb2"><rect height="520.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t6f773f6af74a444992cb978d8d0f7fb2)" style="cursor:crosshair"><rect height="520.0" style="pointer-events:all;visibility:hidden" width="520.0" x="40.0" y="40.0"></rect><g class="toyplot-mark-Text" id="t3c8ce6a3f8cf42cdac47035396625ec4" style="-toyplot-anchor-shift:0;ali
# ...
