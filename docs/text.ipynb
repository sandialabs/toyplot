# %% [markdown]
# .. _text:
#
# # Text

# %% [markdown]
# ## Alignment
#
# By default, text in Toyplot is centered vertically and horizontally on its coordinates.  For example, in the following figure we rendered some text, then plotted its coordinates using a black dot:

# %%
import toyplot

canvas = toyplot.Canvas(width=500, height=150)
axes = canvas.axes(show=False)
axes.text(0, 0, "Text!", style={"font-size":"24px"})
axes.scatterplot(0, 0, color="black");
# Out:
# <div align="center" class="toyplot" id="t5d294211b94f418d97640538defd7290"><svg height="150.0px" id="t29cf9c9a0e294a12b3780ff39618ac13" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 500.0 150.0" width="500.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t267fd835459b4619a87e69ca204698df"><clipPath id="t9efc8a15089f4b769701287f8fb2159d"><rect height="70.0" width="420.0" x="40.0" y="40.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t9efc8a15089f4b769701287f8fb2159d)" style="cursor:crosshair"><rect height="70.0" style="pointer-events:all;visibility:hidden" width="420.0" x="40.0" y="40.0"></rect><g class="toyplot-mark-Text" id="tde1e55dcd81948a8aadc9fea6897946a" style="alignment-baseline:middle;font-size:24px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;font-size:24px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(250.0,75.0)"><tspan style="dominant-baseline:inherit">Text!</tspan></text></g></g><g class="toyplot-mark-Scatterplot" id="t68d7ee0db7734f63bac47765e4b8ad6a" style=""><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="250.0" cy="75.0" r="2.0"></circle></g></g></g></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="350.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="395.0" y="67.0"></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   var data_tables = [{"data": [[0.0], [0.0]], "title": "Scatterplot Data", "names": ["x", "y0"], "id": "t68d7ee0db7734f63bac47765e4b8ad6a", "filename": "toyplot"}];
#
#   function save_csv(data_table)
#   {
#     var uri = "data:text/csv;charset=utf-8,";
#     uri += data_table.names.join(",") + "\n";
#     for(var i = 0; i != data_table.data[0].length; ++i)
#     {
#       for(var j = 0; j != data_table.data.length; ++j)
#       {
#         if(j)
#           uri += ",";
#         uri += data_table.data[j][i];
#       }
#       uri += "\n";
#     }
#     uri = encodeURI(uri);
#
#     var link = document.createElement("a");
#     if(typeof link.download != "undefined")
#     {
#       link.href = uri;
#       link.style = "visibility:hidden";
#       link.download = data_table.filename + ".csv";
#
#       document.body.appendChild(link);
#       link.click();
#       document.body.removeChild(link);
#     }
#     else
#     {
#       window.open(uri);
#     }
#   }
#
#   function open_popup(data_table)
#   {
#     return function(e)
#     {
#       var popup = document.querySelector("#t5d294211b94f418d97640538defd7290 .toyplot-mark-popup");
#       popup.querySelector(".toyplot-mark-popup-title").innerHTML = data_table.title;
#       popup.querySelector(".toyplot-mark-popup-save-csv").onclick = function() { popup.style.visibility = "hidden"; save_csv(data_table); }
#       popup.style.left = (e.clientX - 50) + "px";
#       popup.style.top = (e.clientY - 20) + "px";
#       popup.style.visibility = "visible";
#       e.stopPropagation();
#       e.preventDefault();
#     }
#
#   }
#
#   for(var i = 0; i != data_tables.length; ++i)
#   {
#     var data_table = data_tables[i];
#     var event_target = document.querySelector("#" + data_table.id);
#     event_target.oncontextmenu = open_popup(data_table);
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"t267fd835459b4619a87e69ca204698df": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.5, "min": -0.5}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 450.0, "min": 50.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.5, "min": -0.5}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 50.0, "min": 100.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coordinates[i].style.visibility = "hidden";
#   }
#
#   for(var axes_id in axes)
#   {
#     var event_target = document.querySelector("#" + axes_id + " .toyplot-coordinate-events");
#     event_target.onmousemove = display_coordinates;
#     event_target.onmouseout = clear_coordinates;
#   }
# })();
# </script></div></div>

# %% [markdown]
# To control the horizontal alignment, use the `text-anchor` CSS attribute to change the text justification relative to its X coordinate:

# %%
canvas = toyplot.Canvas(width=500, height=300)
axes = canvas.axes(show=False)

axes.plot([0, 0], [-2, 2], color="gray", style={"stroke-width":1})

axes.text(0, 1, "Centered", style={"text-anchor":"middle", "font-size":"24px"})
axes.scatterplot(0, 1, color="black")

axes.text(0, 0, "Left Justified", style={"text-anchor":"start", "font-size":"24px"})
axes.scatterplot(0, 0, color="black")

axes.text(0, -1, "Right Justified", style={"text-anchor":"end", "font-size":"24px"})
axes.scatterplot(0, -1, color="black");
# Out:
# <div align="center" class="toyplot" id="t5bcd79f939ee4730b493f7103f27ba8e"><svg height="300.0px" id="t392eb92c7b8f4f2cb233c5d52e48c935" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 500.0 300.0" width="500.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t26531834002d462aaa70be3129afabd6"><clipPath id="t5c7724bc5b3548f9b7b9afedd61a18cf"><rect height="220.0" width="420.0" x="40.0" y="40.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t5c7724bc5b3548f9b7b9afedd61a18cf)" style="cursor:crosshair"><rect height="220.0" style="pointer-events:all;visibility:hidden" width="420.0" x="40.0" y="40.0"></rect><g class="toyplot-mark-Plot" id="tefc37f3e4f314784ac3607e586072443" style="fill:none;stroke-width:1"><g class="toyplot-Series"><path d="M 250.0 250.0 L 250.0 50.0" style="stroke:rgb(50.2%,50.2%,50.2%);stroke-opacity:1.0;stroke-width:1"></path></g></g><g class="toyplot-mark-Text" id="tebff358fa7ee44ddad66aed4eccd61bb" style="alignment-baseline:middle;font-size:24px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;font-size:24px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(250.0,100.0)"><tspan style="dominant-baseline:inherit">Centered</tspan></text></g></g><g class="toyplot-mark-Scatterplot" id="t0557c299804b416ab06f58b740a25626" style=""><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="250.0" cy="100.0" r="2.0"></circle></g></g></g><g class="toyplot-mark-Text" id="t366cd567d2a34f059a2afc42c9a56797" style="alignment-baseline:middle;font-size:24px;font-weight:normal;stroke:none;text-anchor:start"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(98.8%,55.3%,38.4%);fill-opacity:1.0;font-size:24px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:start" transform="translate(250.0,150.0)"><tspan style="dominant-baseline:inherit">Left Justified</tspan></text></g></g><g class="toyplot-mark-Scatterplot" id="t5afc3b917d424892a8ea2d92e0e846f1" style=""><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="250.0" cy="150.0" r="2.0"></circle></g></g></g><g class="toyplot-mark-Text" id="tedca0a3a140049df870c729f0de595c1" style="alignment-baseline:middle;font-size:24px;font-weight:normal;stroke:none;text-anchor:end"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(55.3%,62.7%,79.6%);fill-opacity:1.0;font-size:24px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:end" transform="translate(250.0,200.0)"><tspan style="dominant-baseline:inherit">Right Justified</tspan></text></g></g><g class="toyplot-mark-Scatterplot" id="tefe102b1d2944b0486d364184d8e9b09" style=""><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="250.0" cy="200.0" r="2.0"></circle></g></g></g></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="350.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="395.0" y="67.0"></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white ...
# (function()
# {
#   var data_tables = [{"data": [[0.0, 0.0], [-2.0, 2.0]], "title": "Plot Data", "names": ["x", "y0"], "id": "tefc37f3e4f314784ac3607e586072443", "filename": "toyplot"}, {"data": [[0.0], [1.0]], "title": "Scatterplot Data", "names": ["x", "y0"], "id": "t0557c299804b416ab06f58b740a25626", "filename": "toyplot"}, {"data": [[0.0], [0.0]], "title": "Scatterplot Data", "names": ["x", "y0"], "id": "t5afc3b917d424892a8ea2d92e0e846f1", "filename": "toyplot"}, {"data": [[0.0], [-1.0]], "title": "Scatterplot Data", "names": ["x", "y0"], "id": "tefe102b1d2944b0486d364184d8e9b09", "filename": "toyplot"}];
#
#   function save_csv(data_table)
#   {
#     var uri = "data:text/csv;charset=utf-8,";
#     uri += data_table.names.join(",") + "\n";
#     for(var i = 0; i != data_table.data[0].length; ++i)
#     {
#       for(var j = 0; j != data_table.data.length; ++j)
#       {
#         if(j)
#           uri += ",";
#         uri += data_table.data[j][i];
#       }
#       uri += "\n";
#     }
#     uri = encodeURI(uri);
#
#     var link = document.createElement("a");
#     if(typeof link.download != "undefined")
#     {
#       link.href = uri;
#       link.style = "visibility:hidden";
#       link.download = data_table.filename + ".csv";
#
#       document.body.appendChild(link);
#       link.click();
#       document.body.removeChild(link);
#     }
#     else
#     {
#       window.open(uri);
#     }
#   }
#
#   function open_popup(data_table)
#   {
#     return function(e)
#     {
#       var popup = document.querySelector("#t5bcd79f939ee4730b493f7103f27ba8e .toyplot-mark-popup");
#       popup.querySelector(".toyplot-mark-popup-title").innerHTML = data_table.title;
#       popup.querySelector(".toyplot-mark-popup-save-csv").onclick = function() { popup.style.visibility = "hidden"; save_csv(data_table); }
#       popup.style.left = (e.clientX - 50) + "px";
#       popup.style.top = (e.clientY - 20) + "px";
#       popup.style.visibility = "visible";
#       e.stopPropagation();
#       e.preventDefault();
#     }
#
#   }
#
#   for(var i = 0; i != data_tables.length; ++i)
#   {
#     var data_table = data_tables[i];
#     var event_target = document.querySelector("#" + data_table.id);
#     event_target.oncontextmenu = open_popup(data_table);
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"t26531834002d462aaa70be3129afabd6": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1.0, "min": -1.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 450.0, "min": 50.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 2.0, "min": -2.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 50.0, "min": 250.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scal

# %% [markdown]
# After the anchor has been established, the text can be shifted in arbitrary amounts, using the `-toyplot-anchor-shift` attribute.  Note that this is non-standard CSS, provided by Toyplot for symmetry with the standard `baseline-shift` attribute, below:

# %%
canvas = toyplot.Canvas(width=500, height=300)
axes = canvas.axes(show=False)

axes.plot([0, 0], [-3, 2], color="gray", style={"stroke-width":1})

axes.text(0, 1, "Shifted +0px", style={"-toyplot-anchor-shift":"0", "text-anchor":"start", "font-size":"24px"})
axes.scatterplot(0, 1, color="black")

axes.text(0, 0, "Shifted +20px", style={"-toyplot-anchor-shift":"20px", "text-anchor":"start", "font-size":"24px"})
axes.scatterplot(0, 0, color="black")

axes.text(0, -1, "Shifted +40px", style={"-toyplot-anchor-shift":"40px", "text-anchor":"start", "font-size":"24px"})
axes.scatterplot(0, -1, color="black");

axes.text(0, -2, "Shifted -20px", style={"-toyplot-anchor-shift":"-20px", "text-anchor":"start", "font-size":"24px"})
axes.scatterplot(0, -2, color="black");
# Out:
# <div align="center" class="toyplot" id="tc1ddae71c33b45d7998752ad5c7f4c55"><svg height="300.0px" id="t266b54ef9b85426db067488745806de7" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 500.0 300.0" width="500.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tb911daaf9c134c5da36baedd43819a2c"><clipPath id="te8587ca36db84d6aab1bdc33a394c080"><rect height="220.0" width="420.0" x="40.0" y="40.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#te8587ca36db84d6aab1bdc33a394c080)" style="cursor:crosshair"><rect height="220.0" style="pointer-events:all;visibility:hidden" width="420.0" x="40.0" y="40.0"></rect><g class="toyplot-mark-Plot" id="td8911734f7914748b89ec57b107e6617" style="fill:none;stroke-width:1"><g class="toyplot-Series"><path d="M 183.33333333333334 250.0 L 183.33333333333334 50.0" style="stroke:rgb(50.2%,50.2%,50.2%);stroke-opacity:1.0;stroke-width:1"></path></g></g><g class="toyplot-mark-Text" id="t6e7d1fda672d487ea1a41086051383c0" style="-toyplot-anchor-shift:0;alignment-baseline:middle;font-size:24px;font-weight:normal;stroke:none;text-anchor:start"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;font-size:24px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:start" transform="translate(183.33333333333334,89.999999999999986)"><tspan style="dominant-baseline:inherit">Shifted +0px</tspan></text></g></g><g class="toyplot-mark-Scatterplot" id="t89b62b12c68640b4aaa4dd10c8592ea9" style=""><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="183.33333333333334" cy="89.999999999999986" r="2.0"></circle></g></g></g><g class="toyplot-mark-Text" id="t9296110fd1604777b9d833b1dfbd70fa" style="-toyplot-anchor-shift:20px;alignment-baseline:middle;font-size:24px;font-weight:normal;stroke:none;text-anchor:start"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(98.8%,55.3%,38.4%);fill-opacity:1.0;font-size:24px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:start" transform="translate(183.33333333333334,130.0)translate(20.0,0)"><tspan style="dominant-baseline:inherit">Shifted +20px</tspan></text></g></g><g class="toyplot-mark-Scatterplot" id="t136dc4651b2448b3a189dc2e5f2306d8" style=""><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="183.33333333333334" cy="130.0" r="2.0"></circle></g></g></g><g class="toyplot-mark-Text" id="t4fb54b66c0ad4184abcbc3050b20fca6" style="-toyplot-anchor-shift:40px;alignment-baseline:middle;font-size:24px;font-weight:normal;stroke:none;text-anchor:start"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(55.3%,62.7%,79.6%);fill-opacity:1.0;font-size:24px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:start" transform="translate(183.33333333333334,170.0)translate(40.0,0)"><tspan style="dominant-baseline:inherit">Shifted +40px</tspan></text></g></g><g class="toyplot-mark-Scatterplot" id="t12149244dd55474b9733b3f0469d4a30" style=""><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="183.33333333333334" cy="170.0" r="2.0"></circle></g></g></g><g class="toyplot-mark-Text" id="t45e3cbfe795e43e9b32707afab511a92" style="-toyplot-anchor-shift:-20px;alignment-baseline:middle;font-size:24px;font-weight:normal;stroke:none;text-anchor:start"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middl ...
# (function()
# {
#   var data_tables = [{"data": [[0.0, 0.0], [-3.0, 2.0]], "title": "Plot Data", "names": ["x", "y0"], "id": "td8911734f7914748b89ec57b107e6617", "filename": "toyplot"}, {"data": [[0.0], [1.0]], "title": "Scatterplot Data", "names": ["x", "y0"], "id": "t89b62b12c68640b4aaa4dd10c8592ea9", "filename": "toyplot"}, {"data": [[0.0], [0.0]], "title": "Scatterplot Data", "names": ["x", "y0"], "id": "t136dc4651b2448b3a189dc2e5f2306d8", "filename": "toyplot"}, {"data": [[0.0], [-1.0]], "title": "Scatterplot Data", "names": ["x", "y0"], "id": "t12149244dd55474b9733b3f0469d4a30", "filename": "toyplot"}, {"data": [[0.0], [-2.0]], "title": "Scatterplot Data", "names": ["x", "y0"], "id": "t1fa2fdfc928b4da983e9d3403d24997a", "filename": "toyplot"}];
#
#   function save_csv(data_table)
#   {
#     var uri = "data:text/csv;charset=utf-8,";
#     uri += data_table.names.join(",") + "\n";
#     for(var i = 0; i != data_table.data[0].length; ++i)
#     {
#       for(var j = 0; j != data_table.data.length; ++j)
#       {
#         if(j)
#           uri += ",";
#         uri += data_table.data[j][i];
#       }
#       uri += "\n";
#     }
#     uri = encodeURI(uri);
#
#     var link = document.createElement("a");
#     if(typeof link.download != "undefined")
#     {
#       link.href = uri;
#       link.style = "visibility:hidden";
#       link.download = data_table.filename + ".csv";
#
#       document.body.appendChild(link);
#       link.click();
#       document.body.removeChild(link);
#     }
#     else
#     {
#       window.open(uri);
#     }
#   }
#
#   function open_popup(data_table)
#   {
#     return function(e)
#     {
#       var popup = document.querySelector("#tc1ddae71c33b45d7998752ad5c7f4c55 .toyplot-mark-popup");
#       popup.querySelector(".toyplot-mark-popup-title").innerHTML = data_table.title;
#       popup.querySelector(".toyplot-mark-popup-save-csv").onclick = function() { popup.style.visibility = "hidden"; save_csv(data_table); }
#       popup.style.left = (e.clientX - 50) + "px";
#       popup.style.top = (e.clientY - 20) + "px";
#       popup.style.visibility = "visible";
#       e.stopPropagation();
#       e.preventDefault();
#     }
#
#   }
#
#   for(var i = 0; i != data_tables.length; ++i)
#   {
#     var data_table = data_tables[i];
#     var event_target = document.querySelector("#" + data_table.id);
#     event_target.oncontextmenu = open_popup(data_table);
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"tb911daaf9c134c5da36baedd43819a2c": {"x": [{

# %% [markdown]
# To control vertical alignment, set the text baseline with `alignment-baseline`.  By default, the text baseline will line-up with the text Y coordinate.  CSS typography is a complex topic and there are many baseline types to accomodate different writing modes and fonts.  The following baselines are likely to be the most useful for Western scripts.  Note the subtle difference between the "central" and "middle" baselines - the former tends to center the upper-case letters in Western scripts while the latter tends to center lower-case letters, and is the Toyplot default:

# %%
canvas = toyplot.Canvas(width=600, height=300)
axes = canvas.axes(show=False)

axes.plot([-2, 3], [0, 0], color="gray", style={"stroke-width":1})

axes.text(-1, 0, "Hanging", style={"alignment-baseline":"hanging", "font-size":"24px"})
axes.scatterplot(-1, 0, color="black")

axes.text(0, 0, "Central", style={"alignment-baseline":"central", "font-size":"24px"})
axes.scatterplot(0, 0, color="black")

axes.text(1, 0, "Middle", style={"alignment-baseline":"middle", "font-size":"24px"})
axes.scatterplot(1, 0, color="black")

axes.text(2, 0, "Alpha", style={"alignment-baseline":"alphabetic", "font-size":"24px"})
axes.scatterplot(2, 0, color="black");
# Out:
# <div align="center" class="toyplot" id="t508d7c334310460abdff173208c541d3"><svg height="300.0px" id="t6b7da5f5196d4b6591065599abe90910" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 300.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tdd384cb743114709bbe11623d553777d"><clipPath id="t0e1b3dffce4445d692d4af178fb55d71"><rect height="220.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t0e1b3dffce4445d692d4af178fb55d71)" style="cursor:crosshair"><rect height="220.0" style="pointer-events:all;visibility:hidden" width="520.0" x="40.0" y="40.0"></rect><g class="toyplot-mark-Plot" id="ta685299bd456480b8a65948b97a7ab3b" style="fill:none;stroke-width:1"><g class="toyplot-Series"><path d="M 50.0 150.0 L 550.0 150.0" style="stroke:rgb(50.2%,50.2%,50.2%);stroke-opacity:1.0;stroke-width:1"></path></g></g><g class="toyplot-mark-Text" id="td5980f6630b64fcfa606e7579b613995" style="alignment-baseline:hanging;font-size:24px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:hanging;fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;font-size:24px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(150.0,150.0)"><tspan style="dominant-baseline:inherit">Hanging</tspan></text></g></g><g class="toyplot-mark-Scatterplot" id="t68bf5942b3f44d41bc1096d4eabd94bb" style=""><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="150.0" cy="150.0" r="2.0"></circle></g></g></g><g class="toyplot-mark-Text" id="tbe346e34f1ea4e339e295c3e5241dcdd" style="alignment-baseline:central;font-size:24px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:central;fill:rgb(98.8%,55.3%,38.4%);fill-opacity:1.0;font-size:24px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(250.0,150.0)"><tspan style="dominant-baseline:inherit">Central</tspan></text></g></g><g class="toyplot-mark-Scatterplot" id="t7e0865f4939741abb60b51384903ff53" style=""><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="250.0" cy="150.0" r="2.0"></circle></g></g></g><g class="toyplot-mark-Text" id="ta55c34df85da4f9cac66a98ca73bf4a8" style="alignment-baseline:middle;font-size:24px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(55.3%,62.7%,79.6%);fill-opacity:1.0;font-size:24px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(350.0,150.0)"><tspan style="dominant-baseline:inherit">Middle</tspan></text></g></g><g class="toyplot-mark-Scatterplot" id="t0137d66948374f6caca69de192079af7" style=""><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="350.0" cy="150.0" r="2.0"></circle></g></g></g><g class="toyplot-mark-Text" id="t16e82aa9d6a240a985c976896afcd90d" style="alignment-baseline:alphabetic;font-size:24px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:alphabetic;fill:rgb(90.6%,54.1%,76.5%);fill-opacity:1.0;font-size:24px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(450.0,150.0)"><tspan style="dominant-baseline:inherit">Alpha</tspan></text></g></g><g class="toyplot-mark-Scatterplot" id=" ...
# (function()
# {
#   var data_tables = [{"data": [[-2.0, 3.0], [0.0, 0.0]], "title": "Plot Data", "names": ["x", "y0"], "id": "ta685299bd456480b8a65948b97a7ab3b", "filename": "toyplot"}, {"data": [[-1.0], [0.0]], "title": "Scatterplot Data", "names": ["x", "y0"], "id": "t68bf5942b3f44d41bc1096d4eabd94bb", "filename": "toyplot"}, {"data": [[0.0], [0.0]], "title": "Scatterplot Data", "names": ["x", "y0"], "id": "t7e0865f4939741abb60b51384903ff53", "filename": "toyplot"}, {"data": [[1.0], [0.0]], "title": "Scatterplot Data", "names": ["x", "y0"], "id": "t0137d66948374f6caca69de192079af7", "filename": "toyplot"}, {"data": [[2.0], [0.0]], "title": "Scatterplot Data", "names": ["x", "y0"], "id": "t7621533a57ae46cf8ecec749766f73a4", "filename": "toyplot"}];
#
#   function save_csv(data_table)
#   {
#     var uri = "data:text/csv;charset=utf-8,";
#     uri += data_table.names.join(",") + "\n";
#     for(var i = 0; i != data_table.data[0].length; ++i)
#     {
#       for(var j = 0; j != data_table.data.length; ++j)
#       {
#         if(j)
#           uri += ",";
#         uri += data_table.data[j][i];
#       }
#       uri += "\n";
#     }
#     uri = encodeURI(uri);
#
#     var link = document.createElement("a");
#     if(typeof link.download != "undefined")
#     {
#       link.href = uri;
#       link.style = "visibility:hidden";
#       link.download = data_table.filename + ".csv";
#
#       document.body.appendChild(link);
#       link.click();
#       document.body.removeChild(link);
#     }
#     else
#     {
#       window.open(uri);
#     }
#   }
#
#   function open_popup(data_table)
#   {
#     return function(e)
#     {
#       var popup = document.querySelector("#t508d7c334310460abdff173208c541d3 .toyplot-mark-popup");
#       popup.querySelector(".toyplot-mark-popup-title").innerHTML = data_table.title;
#       popup.querySelector(".toyplot-mark-popup-save-csv").onclick = function() { popup.style.visibility = "hidden"; save_csv(data_table); }
#       popup.style.left = (e.clientX - 50) + "px";
#       popup.style.top = (e.clientY - 20) + "px";
#       popup.style.visibility = "visible";
#       e.stopPropagation();
#       e.preventDefault();
#     }
#
#   }
#
#   for(var i = 0; i != data_tables.length; ++i)
#   {
#     var data_table = data_tables[i];
#     var event_target = document.querySelector("#" + data_table.id);
#     event_target.oncontextmenu = open_popup(data_table);
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"tdd384cb743114709bbe11623d553777d": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 3.0, "min": -2.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 550.0, "min": 50.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.5, "min": -0.5}, "range": {"bounds": {"max": -Infinity, "

# %% [markdown]
# Of course, you can shift the text relative to its baseline by arbitrary amounts, using `baseline-shift`.  While you are free to use any CSS length units for the shift, percentages are especially useful, because they represent a distance relative to the font height:

# %%
canvas = toyplot.Canvas(width=700, height=300)
axes = canvas.axes(show=False)

axes.plot([-2, 3], [0, 0], color="gray", style={"stroke-width":1})

axes.text(-1, 0, "Shift -100%", style={"baseline-shift":"-100%", "font-size":"24px"})
axes.scatterplot(-1, 0, color="black")

axes.text(0, 0, "Shift 0%", style={"baseline-shift":"0", "font-size":"24px"})
axes.scatterplot(0, 0, color="black")

axes.text(1, 0, "Shift 66%", style={"baseline-shift":"66%", "font-size":"24px"})
axes.scatterplot(1, 0, color="black");

axes.text(2, 0, "Shift 100%", style={"baseline-shift":"100%", "font-size":"24px"})
axes.scatterplot(2, 0, color="black");
# Out:
# <div align="center" class="toyplot" id="tf36ecc0820964b7288ea6c2c5b8489e3"><svg height="300.0px" id="t3c821248f7fc4ead91d9db35b2622f90" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 700.0 300.0" width="700.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t861b79ade79a471a94813a8c3614b029"><clipPath id="tc790b32a30964737aec8f476ff82f800"><rect height="220.0" width="620.0" x="40.0" y="40.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tc790b32a30964737aec8f476ff82f800)" style="cursor:crosshair"><rect height="220.0" style="pointer-events:all;visibility:hidden" width="620.0" x="40.0" y="40.0"></rect><g class="toyplot-mark-Plot" id="t516abedf239643279e66fc2c1008113d" style="fill:none;stroke-width:1"><g class="toyplot-Series"><path d="M 61.764705882352949 150.0 L 650.0 150.0" style="stroke:rgb(50.2%,50.2%,50.2%);stroke-opacity:1.0;stroke-width:1"></path></g></g><g class="toyplot-mark-Text" id="tabd7b0ab95c2498eab484d2337b8e402" style="alignment-baseline:middle;baseline-shift:-100%;font-size:24px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;font-size:24px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(179.41176470588238,150.0)translate(0,24.0)"><tspan style="dominant-baseline:inherit">Shift -100%</tspan></text></g></g><g class="toyplot-mark-Scatterplot" id="t64eec665a1324a249a482882cd85c72b" style=""><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="179.41176470588238" cy="150.0" r="2.0"></circle></g></g></g><g class="toyplot-mark-Text" id="ta4390f44d7874dcdba013f9bfa306471" style="alignment-baseline:middle;baseline-shift:0;font-size:24px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(98.8%,55.3%,38.4%);fill-opacity:1.0;font-size:24px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(297.05882352941182,150.0)"><tspan style="dominant-baseline:inherit">Shift 0%</tspan></text></g></g><g class="toyplot-mark-Scatterplot" id="t764ab45e70fa4202834de44a713afb47" style=""><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="297.05882352941182" cy="150.0" r="2.0"></circle></g></g></g><g class="toyplot-mark-Text" id="tfca5dda0806e4a66bb5f30f9bea33312" style="alignment-baseline:middle;baseline-shift:66%;font-size:24px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(55.3%,62.7%,79.6%);fill-opacity:1.0;font-size:24px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(414.70588235294122,150.0)translate(0,-15.84)"><tspan style="dominant-baseline:inherit">Shift 66%</tspan></text></g></g><g class="toyplot-mark-Scatterplot" id="t60d08c39db2d47fb951076f7f97bc698" style=""><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="414.70588235294122" cy="150.0" r="2.0"></circle></g></g></g><g class="toyplot-mark-Text" id="tef2331fa8a224cba95354fb6f91a38c4" style="alignment-baseline:middle;baseline-shift:100%;font-size:24px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(90.6%,54.1%,76.5%);fill-opacity:1.0;font-size:24px;font-w ...
# (function()
# {
#   var data_tables = [{"data": [[-2.0, 3.0], [0.0, 0.0]], "title": "Plot Data", "names": ["x", "y0"], "id": "t516abedf239643279e66fc2c1008113d", "filename": "toyplot"}, {"data": [[-1.0], [0.0]], "title": "Scatterplot Data", "names": ["x", "y0"], "id": "t64eec665a1324a249a482882cd85c72b", "filename": "toyplot"}, {"data": [[0.0], [0.0]], "title": "Scatterplot Data", "names": ["x", "y0"], "id": "t764ab45e70fa4202834de44a713afb47", "filename": "toyplot"}, {"data": [[1.0], [0.0]], "title": "Scatterplot Data", "names": ["x", "y0"], "id": "t60d08c39db2d47fb951076f7f97bc698", "filename": "toyplot"}, {"data": [[2.0], [0.0]], "title": "Scatterplot Data", "names": ["x", "y0"], "id": "t96d4045ab78848c99b34b4999b3432bd", "filename": "toyplot"}];
#
#   function save_csv(data_table)
#   {
#     var uri = "data:text/csv;charset=utf-8,";
#     uri += data_table.names.join(",") + "\n";
#     for(var i = 0; i != data_table.data[0].length; ++i)
#     {
#       for(var j = 0; j != data_table.data.length; ++j)
#       {
#         if(j)
#           uri += ",";
#         uri += data_table.data[j][i];
#       }
#       uri += "\n";
#     }
#     uri = encodeURI(uri);
#
#     var link = document.createElement("a");
#     if(typeof link.download != "undefined")
#     {
#       link.href = uri;
#       link.style = "visibility:hidden";
#       link.download = data_table.filename + ".csv";
#
#       document.body.appendChild(link);
#       link.click();
#       document.body.removeChild(link);
#     }
#     else
#     {
#       window.open(uri);
#     }
#   }
#
#   function open_popup(data_table)
#   {
#     return function(e)
#     {
#       var popup = document.querySelector("#tf36ecc0820964b7288ea6c2c5b8489e3 .toyplot-mark-popup");
#       popup.querySelector(".toyplot-mark-popup-title").innerHTML = data_table.title;
#       popup.querySelector(".toyplot-mark-popup-save-csv").onclick = function() { popup.style.visibility = "hidden"; save_csv(data_table); }
#       popup.style.left = (e.clientX - 50) + "px";
#       popup.style.top = (e.clientY - 20) + "px";
#       popup.style.visibility = "visible";
#       e.stopPropagation();
#       e.preventDefault();
#     }
#
#   }
#
#   for(var i = 0; i != data_tables.length; ++i)
#   {
#     var data_table = data_tables[i];
#     var event_target = document.querySelector("#" + data_table.id);
#     event_target.oncontextmenu = open_popup(data_table);
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"t861b79ade79a471a94813a8c3614b029": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 3.0, "

# %% [markdown]
# Of course, you're free to combine all four styles in any way that you like.
#
# One final thing to keep in mind is that `-toyplot-anchor-shift` and `baseline-shift` move the text relative to its baseline, not the canvas.  This is important because it affects their behavior when text is rotated.  In the following example, look carefully and note that the text with `-toyplot-anchor-shift` is shifted *along its baseline*, not simply moved left or right on the canvas.  Similarly, the `baseline-shift` text is shifted *perpendicular to its baseline*, not merely up or down:

# %%
canvas = toyplot.Canvas(width=500, height=300)

axes = canvas.axes(grid=(1,3,0), xshow=False, yshow=False, label="default")
axes.vlines(0, color="lightgray")
axes.text(0, 0, "a + b", angle=45, style={"font-size":"24px"})
axes.scatterplot(0, 0, color="black")

axes = canvas.axes(grid=(1,3,1), xshow=False, yshow=False, label="-toyplot-anchor-shift")
axes.vlines(0, color="lightgray")
axes.text(0, 0, "a + b", angle=45, style={"-toyplot-anchor-shift":"20px", "font-size":"24px"})
axes.scatterplot(0, 0, color="black")

axes = canvas.axes(grid=(1,3,2), xshow=False, yshow=False, label="baseline-shift")
axes.vlines(0, color="lightgray")
axes.text(0, 0, "a + b", angle=45, style={"baseline-shift":"-20px", "font-size":"24px"})
axes.scatterplot(0, 0, color="black");
# Out:
# <div align="center" class="toyplot" id="t94e8ae433d9d4586aa7148e17c85b247"><svg height="300.0px" id="t0d6f11f852484bf78ed78797c52899fa" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 500.0 300.0" width="500.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t0311d86e15354c0dbb98e0961d42f2de"><clipPath id="t8ab1540634224888b6e5cc86eaf2564a"><rect height="220.0" width="86.66666666666666" x="40.0" y="40.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t8ab1540634224888b6e5cc86eaf2564a)" style="cursor:crosshair"><rect height="220.0" style="pointer-events:all;visibility:hidden" width="86.66666666666666" x="40.0" y="40.0"></rect><g class="toyplot-mark-AxisLines" id="tdbde10917c634b9b8771672648eedd0b" style=""><g class="toyplot-Series"><line class="toyplot-Datum" style="opacity:1.0;stroke:rgb(82.7%,82.7%,82.7%);stroke-opacity:1.0" x1="83.333333333333329" x2="83.333333333333329" y1="50.0" y2="250.0"></line></g></g><g class="toyplot-mark-Text" id="t6a853761bb3f4ceea11662c5fbe7d862" style="alignment-baseline:middle;font-size:24px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;font-size:24px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(83.333333333333329,150.0)rotate(-45.0)"><tspan style="dominant-baseline:inherit">a + b</tspan></text></g></g><g class="toyplot-mark-Scatterplot" id="te3a9927742dc4dd3a79d75965a3abd40" style=""><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="83.333333333333329" cy="150.0" r="2.0"></circle></g></g></g></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="16.666666666666657" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="61.66666666666666" y="67.0"></text></g><text style="dominant-baseline:middle;font-size:14px;font-weight:bold;stroke:none;text-anchor:middle" transform="translate(83.33333333333333,50.0)translate(0,-14.0)"><tspan style="dominant-baseline:inherit">default</tspan></text></g><g class="toyplot-axes-Cartesian" id="tcbcfcabfdaa141e6b377b87b1180f8cf"><clipPath id="tc1cc009f9bff44f682c9cd70baa5e206"><rect height="220.0" width="86.66666666666666" x="206.66666666666666" y="40.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tc1cc009f9bff44f682c9cd70baa5e206)" style="cursor:crosshair"><rect height="220.0" style="pointer-events:all;visibility:hidden" width="86.66666666666666" x="206.66666666666666" y="40.0"></rect><g class="toyplot-mark-AxisLines" id="tdf1f2f74b4ce461899c85c97f825040a" style=""><g class="toyplot-Series"><line class="toyplot-Datum" style="opacity:1.0;stroke:rgb(82.7%,82.7%,82.7%);stroke-opacity:1.0" x1="240.7407407407407" x2="240.7407407407407" y1="50.0" y2="250.0"></line></g></g><g class="toyplot-mark-Text" id="t3a63f33d47554a53a5b456b0399e8f40" style="-toyplot-anchor-shift:20px;alignment-baseline:middle;font-size:24px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;font-size:24px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(240.7407407407407,150.0)rotate(-45.0)translate(20.0,0)"><tspan style="dominant-baseline:inherit">a + b</tspan></text></g></g><g class="toyplot-mark-Scatterplot" id="ta179edb982044287844cc08638d9bcce" style=""><g cla ...
# (function()
# {
#   var data_tables = [{"data": [[0.0], [0.0]], "title": "Scatterplot Data", "names": ["x", "y0"], "id": "te3a9927742dc4dd3a79d75965a3abd40", "filename": "toyplot"}, {"data": [[0.0], [0.0]], "title": "Scatterplot Data", "names": ["x", "y0"], "id": "ta179edb982044287844cc08638d9bcce", "filename": "toyplot"}, {"data": [[0.0], [0.0]], "title":

# %% [markdown]
# ## Rich Text
#
# In addition to positioning text using styles, you can use (a limited subset of) HTML markup to format your text.  For example, you can create text with superscripts and subscripts:

# %%
canvas = toyplot.Canvas(width=600, height=150)
canvas.text(300, 100, "100<sup>-53</sup>", style={"font-size":"32px"});
# Out:
# <div align="center" class="toyplot" id="t70dfb961aa794c7ebf5965b2a60d8dcd"><svg height="150.0px" id="tb60563cc9686437da893e4b5b7c52a71" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 150.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-mark-Text" id="t9fe9b496d8894e218326481ccaf3e1cf" style="alignment-baseline:middle;font-size:32px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:32px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(300.0,100.0)"><tspan style="dominant-baseline:inherit">100</tspan><tspan dy="-9.6" style="dominant-baseline:inherit;font-size:22.4px">-53</tspan></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   var data_tables = [];
#
#   function save_csv(data_table)
#   {
#     var uri = "data:text/csv;charset=utf-8,";
#     uri += data_table.names.join(",") + "\n";
#     for(var i = 0; i != data_table.data[0].length; ++i)
#     {
#       for(var j = 0; j != data_table.data.length; ++j)
#       {
#         if(j)
#           uri += ",";
#         uri += data_table.data[j][i];
#       }
#       uri += "\n";
#     }
#     uri = encodeURI(uri);
#
#     var link = document.createElement("a");
#     if(typeof link.download != "undefined")
#     {
#       link.href = uri;
#       link.style = "visibility:hidden";
#       link.download = data_table.filename + ".csv";
#
#       document.body.appendChild(link);
#       link.click();
#       document.body.removeChild(link);
#     }
#     else
#     {
#       window.open(uri);
#     }
#   }
#
#   function open_popup(data_table)
#   {
#     return function(e)
#     {
#       var popup = document.querySelector("#t70dfb961aa794c7ebf5965b2a60d8dcd .toyplot-mark-popup");
#       popup.querySelector(".toyplot-mark-popup-title").innerHTML = data_table.title;
#       popup.querySelector(".toyplot-mark-popup-save-csv").onclick = function() { popup.style.visibility = "hidden"; save_csv(data_table); }
#       popup.style.left = (e.clientX - 50) + "px";
#       popup.style.top = (e.clientY - 20) + "px";
#       popup.style.visibility = "visible";
#       e.stopPropagation();
#       e.preventDefault();
#     }
#
#   }
#
#   for(var i = 0; i != data_tables.length; ++i)
#   {
#     var data_table = data_tables[i];
#     var event_target = document.querySelector("#" + data_table.id);
#     event_target.oncontextmenu = open_popup(data_table);
#   }
# })();
# </script></div></div>

# %% [markdown]
# Note that you can use rich text formatting anywhere that text is displayed, including tick labels ... for example, :class:`toyplot.locator.Log` uses superscripts to format tick labels for logarithmic scales.

# %%
canvas = toyplot.Canvas(width=600, height=150)
canvas.text(300, 100, "H<sub>2</sub>O", style={"font-size":"32px"});
# Out:
# <div align="center" class="toyplot" id="t51d8e5f537a74e86a7032445fecd6b6f"><svg height="150.0px" id="t17a9f7e3ff1b4c9d9d7299951ceb5b40" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 150.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-mark-Text" id="t5bf262f87ad941128d63c1c23d87fcfa" style="alignment-baseline:middle;font-size:32px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:32px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(300.0,100.0)"><tspan style="dominant-baseline:inherit">H</tspan><tspan dy="6.4" style="dominant-baseline:inherit;font-size:22.4px">2</tspan><tspan dy="-6.4" style="dominant-baseline:inherit">O</tspan></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   var data_tables = [];
#
#   function save_csv(data_table)
#   {
#     var uri = "data:text/csv;charset=utf-8,";
#     uri += data_table.names.join(",") + "\n";
#     for(var i = 0; i != data_table.data[0].length; ++i)
#     {
#       for(var j = 0; j != data_table.data.length; ++j)
#       {
#         if(j)
#           uri += ",";
#         uri += data_table.data[j][i];
#       }
#       uri += "\n";
#     }
#     uri = encodeURI(uri);
#
#     var link = document.createElement("a");
#     if(typeof link.download != "undefined")
#     {
#       link.href = uri;
#       link.style = "visibility:hidden";
#       link.download = data_table.filename + ".csv";
#
#       document.body.appendChild(link);
#       link.click();
#       document.body.removeChild(link);
#     }
#     else
#     {
#       window.open(uri);
#     }
#   }
#
#   function open_popup(data_table)
#   {
#     return function(e)
#     {
#       var popup = document.querySelector("#t51d8e5f537a74e86a7032445fecd6b6f .toyplot-mark-popup");
#       popup.querySelector(".toyplot-mark-popup-title").innerHTML = data_table.title;
#       popup.querySelector(".toyplot-mark-popup-save-csv").onclick = function() { popup.style.visibility = "hidden"; save_csv(data_table); }
#       popup.style.left = (e.clientX - 50) + "px";
#       popup.style.top = (e.clientY - 20) + "px";
#       popup.style.visibility = "visible";
#       e.stopPropagation();
#       e.preventDefault();
#     }
#
#   }
#
#   for(var i = 0; i != data_tables.length; ++i)
#   {
#     var data_table = data_tables[i];
#     var event_target = document.querySelector("#" + data_table.id);
#     event_target.oncontextmenu = open_popup(data_table);
#   }
# })();
# </script></div></div>

# %% [markdown]
# Note that you are free to nest superscripts and subscripts:

# %%
canvas = toyplot.Canvas(width=600, height=150)
canvas.text(300, 100, "W<sup>X<sub>Y</sub><sup>Z</sup></sup>", style={"font-size":"32px"});
# Out:
# <div align="center" class="toyplot" id="t146a0321722b4ec3a7f30b63ba7ee2dd"><svg height="150.0px" id="t3a64ff71a64245469d0463a679e662c4" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 150.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-mark-Text" id="t0abc7d81d5b24c78847d83a4350850c6" style="alignment-baseline:middle;font-size:32px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:32px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(300.0,100.0)"><tspan style="dominant-baseline:inherit">W</tspan><tspan dy="-9.6" style="dominant-baseline:inherit;font-size:22.4px">X</tspan><tspan dy="4.48" style="dominant-baseline:inherit;font-size:15.68px">Y</tspan><tspan dy="-11.2" style="dominant-baseline:inherit;font-size:15.68px">Z</tspan></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   var data_tables = [];
#
#   function save_csv(data_table)
#   {
#     var uri = "data:text/csv;charset=utf-8,";
#     uri += data_table.names.join(",") + "\n";
#     for(var i = 0; i != data_table.data[0].length; ++i)
#     {
#       for(var j = 0; j != data_table.data.length; ++j)
#       {
#         if(j)
#           uri += ",";
#         uri += data_table.data[j][i];
#       }
#       uri += "\n";
#     }
#     uri = encodeURI(uri);
#
#     var link = document.createElement("a");
#     if(typeof link.download != "undefined")
#     {
#       link.href = uri;
#       link.style = "visibility:hidden";
#       link.download = data_table.filename + ".csv";
#
#       document.body.appendChild(link);
#       link.click();
#       document.body.removeChild(link);
#     }
#     else
#     {
#       window.open(uri);
#     }
#   }
#
#   function open_popup(data_table)
#   {
#     return function(e)
#     {
#       var popup = document.querySelector("#t146a0321722b4ec3a7f30b63ba7ee2dd .toyplot-mark-popup");
#       popup.querySelector(".toyplot-mark-popup-title").innerHTML = data_table.title;
#       popup.querySelector(".toyplot-mark-popup-save-csv").onclick = function() { popup.style.visibility = "hidden"; save_csv(data_table); }
#       popup.style.left = (e.clientX - 50) + "px";
#       popup.style.top = (e.clientY - 20) + "px";
#       popup.style.visibility = "visible";
#       e.stopPropagation();
#       e.preventDefault();
#     }
#
#   }
#
#   for(var i = 0; i != data_tables.length; ++i)
#   {
#     var data_table = data_tables[i];
#     var event_target = document.querySelector("#" + data_table.id);
#     event_target.oncontextmenu = open_popup(data_table);
#   }
# })();
# </script></div></div>

# %% [markdown]
# There are a variety of tags to alter the inline appearance of text:

# %%
canvas = toyplot.Canvas(width=600, height=150)
canvas.text(
    300,
    100,
    "normal <b>bold</b> <i>italic</i> <strong>strong</strong> <em>emphasis</em> <small>small</small> <code>code</code>",
    style={"font-size":"24px"});
# Out:
# <div align="center" class="toyplot" id="t03708deedcbd471083882bd3bc66adae"><svg height="150.0px" id="taa48dd24aacc44a09e979e3894b53a51" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 150.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-mark-Text" id="t972b84eb00514cce8e875ba9ad18f967" style="alignment-baseline:middle;font-size:24px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:24px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(300.0,100.0)"><tspan style="dominant-baseline:inherit">normal </tspan><tspan style="dominant-baseline:inherit;font-weight:bold">bold</tspan><tspan style="dominant-baseline:inherit"> </tspan><tspan style="dominant-baseline:inherit;font-style:italic">italic</tspan><tspan style="dominant-baseline:inherit"> </tspan><tspan style="dominant-baseline:inherit;font-weight:bold">strong</tspan><tspan style="dominant-baseline:inherit"> </tspan><tspan style="dominant-baseline:inherit;font-style:italic">emphasis</tspan><tspan style="dominant-baseline:inherit"> </tspan><tspan style="dominant-baseline:inherit;font-size:19.2px">small</tspan><tspan style="dominant-baseline:inherit"> </tspan><tspan style="dominant-baseline:inherit;font-family:monospace">code</tspan></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   var data_tables = [];
#
#   function save_csv(data_table)
#   {
#     var uri = "data:text/csv;charset=utf-8,";
#     uri += data_table.names.join(",") + "\n";
#     for(var i = 0; i != data_table.data[0].length; ++i)
#     {
#       for(var j = 0; j != data_table.data.length; ++j)
#       {
#         if(j)
#           uri += ",";
#         uri += data_table.data[j][i];
#       }
#       uri += "\n";
#     }
#     uri = encodeURI(uri);
#
#     var link = document.createElement("a");
#     if(typeof link.download != "undefined")
#     {
#       link.href = uri;
#       link.style = "visibility:hidden";
#       link.download = data_table.filename + ".csv";
#
#       document.body.appendChild(link);
#       link.click();
#       document.body.removeChild(link);
#     }
#     else
#     {
#       window.open(uri);
#     }
#   }
#
#   function open_popup(data_table)
#   {
#     return function(e)
#     {
#       var popup = document.querySelector("#t03708deedcbd471083882bd3bc66adae .toyplot-mark-popup");
#       popup.querySelector(".toyplot-mark-popup-title").innerHTML = data_table.title;
#       popup.querySelector(".toyplot-mark-popup-save-csv").onclick = function() { popup.style.visibility = "hidden"; save_csv(data_table); }
#       popup.style.left = (e.clientX - 50) + "px";
#       popup.style.top = (e.clientY - 20) + "px";
#       popup.style.visibility = "visible";
#       e.stopPropagation();
#       e.preventDefault();
#     }
#
#   }
#
#   for(var i = 0; i != data_tables.length; ++i)
#   {
#     var data_table = data_tables[i];
#     var event_target = document.querySelector("#" + data_table.id);
#     event_target.oncontextmenu = open_popup(data_table);
#   }
# })();
# </script></div></div>

# %% [markdown]
# And these tags can be nested as well:

# %%
canvas = toyplot.Canvas(width=600, height=150)
canvas.text(300, 100, "foo <b>bar <i>baz <code>blah</code></i></b>", style={"font-size":"32px"});
# Out:
# <div align="center" class="toyplot" id="tbedc15ec28484412bc7232bc1a556e5d"><svg height="150.0px" id="tf418b66442ab494faba7da22a987f1d3" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 150.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-mark-Text" id="ted9f5c100dc14ed98db649292d99a5cf" style="alignment-baseline:middle;font-size:32px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:32px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(300.0,100.0)"><tspan style="dominant-baseline:inherit">foo </tspan><tspan style="dominant-baseline:inherit;font-weight:bold">bar </tspan><tspan style="dominant-baseline:inherit;font-style:italic;font-weight:bold">baz </tspan><tspan style="dominant-baseline:inherit;font-family:monospace;font-style:italic;font-weight:bold">blah</tspan></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   var data_tables = [];
#
#   function save_csv(data_table)
#   {
#     var uri = "data:text/csv;charset=utf-8,";
#     uri += data_table.names.join(",") + "\n";
#     for(var i = 0; i != data_table.data[0].length; ++i)
#     {
#       for(var j = 0; j != data_table.data.length; ++j)
#       {
#         if(j)
#           uri += ",";
#         uri += data_table.data[j][i];
#       }
#       uri += "\n";
#     }
#     uri = encodeURI(uri);
#
#     var link = document.createElement("a");
#     if(typeof link.download != "undefined")
#     {
#       link.href = uri;
#       link.style = "visibility:hidden";
#       link.download = data_table.filename + ".csv";
#
#       document.body.appendChild(link);
#       link.click();
#       document.body.removeChild(link);
#     }
#     else
#     {
#       window.open(uri);
#     }
#   }
#
#   function open_popup(data_table)
#   {
#     return function(e)
#     {
#       var popup = document.querySelector("#tbedc15ec28484412bc7232bc1a556e5d .toyplot-mark-popup");
#       popup.querySelector(".toyplot-mark-popup-title").innerHTML = data_table.title;
#       popup.querySelector(".toyplot-mark-popup-save-csv").onclick = function() { popup.style.visibility = "hidden"; save_csv(data_table); }
#       popup.style.left = (e.clientX - 50) + "px";
#       popup.style.top = (e.clientY - 20) + "px";
#       popup.style.visibility = "visible";
#       e.stopPropagation();
#       e.preventDefault();
#     }
#
#   }
#
#   for(var i = 0; i != data_tables.length; ++i)
#   {
#     var data_table = data_tables[i];
#     var event_target = document.querySelector("#" + data_table.id);
#     event_target.oncontextmenu = open_popup(data_table);
#   }
# })();
# </script></div></div>

# %% [markdown]
# Finally, you can insert line breaks into your text using the &lt;br&gt; tag:

# %%
canvas = toyplot.Canvas(width=600, height=200)
canvas.text(300, 100, "0.567832<br><small>(243, 128, 19)</small>", style={"font-size":"16px"});
# Out:
# <div align="center" class="toyplot" id="t8762874bb0ae4b4e9957e16338e054f9"><svg height="200.0px" id="tdcbccb50080c42c4a876e916fdc7970b" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 200.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-mark-Text" id="tce5c0329af724632b58c8a707365b42f" style="alignment-baseline:middle;font-size:16px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-Series"><text class="toyplot-Datum" style="dominant-baseline:middle;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-size:16px;font-weight:normal;opacity:1.0;stroke:none;text-anchor:middle" transform="translate(300.0,100.0)"><tspan style="dominant-baseline:inherit">0.567832</tspan><tspan dy="19.2" style="dominant-baseline:inherit;font-size:12.8px" x="0">(243, 128, 19)</tspan></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   var data_tables = [];
#
#   function save_csv(data_table)
#   {
#     var uri = "data:text/csv;charset=utf-8,";
#     uri += data_table.names.join(",") + "\n";
#     for(var i = 0; i != data_table.data[0].length; ++i)
#     {
#       for(var j = 0; j != data_table.data.length; ++j)
#       {
#         if(j)
#           uri += ",";
#         uri += data_table.data[j][i];
#       }
#       uri += "\n";
#     }
#     uri = encodeURI(uri);
#
#     var link = document.createElement("a");
#     if(typeof link.download != "undefined")
#     {
#       link.href = uri;
#       link.style = "visibility:hidden";
#       link.download = data_table.filename + ".csv";
#
#       document.body.appendChild(link);
#       link.click();
#       document.body.removeChild(link);
#     }
#     else
#     {
#       window.open(uri);
#     }
#   }
#
#   function open_popup(data_table)
#   {
#     return function(e)
#     {
#       var popup = document.querySelector("#t8762874bb0ae4b4e9957e16338e054f9 .toyplot-mark-popup");
#       popup.querySelector(".toyplot-mark-popup-title").innerHTML = data_table.title;
#       popup.querySelector(".toyplot-mark-popup-save-csv").onclick = function() { popup.style.visibility = "hidden"; save_csv(data_table); }
#       popup.style.left = (e.clientX - 50) + "px";
#       popup.style.top = (e.clientY - 20) + "px";
#       popup.style.visibility = "visible";
#       e.stopPropagation();
#       e.preventDefault();
#     }
#
#   }
#
#   for(var i = 0; i != data_tables.length; ++i)
#   {
#     var data_table = data_tables[i];
#     var event_target = document.querySelector("#" + data_table.id);
#     event_target.oncontextmenu = open_popup(data_table);
#   }
# })();
# </script></div></div>

# %% [markdown]
# Note that additional style attributes currently aren't allowed in rich-text, although this may change in the future.
