# %%
import numpy
x = numpy.linspace(0, 1)
bottom = x
top = x * 2

# %%
import toyplot
toyplot.plot(top, width=300)
toyplot.fill(top, width=300)
# Out:
# (<toyplot.canvas.Canvas at 0x10c52b0d0>,
# ...
#  <toyplot.mark.FillBoundaries at 0x10c532090>)
# ...

# %%
toyplot.plot(x, top, width=300)
toyplot.fill(x, top, width=300)
# Out:
# (<toyplot.canvas.Canvas at 0x10c52bbd0>,
# ...
#  <toyplot.mark.FillBoundaries at 0x10c555290>)
# ...

# %%
toyplot.fill(x, bottom, top, width=300)
# Out:
# (<toyplot.canvas.Canvas at 0x10c5d3990>,
# ...
#  <toyplot.mark.FillBoundaries at 0x10c4fe750>)
# ...
