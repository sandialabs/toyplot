# %% [markdown]
# Axes text use-cases:
#
# ```python
#
# # Plot one label
# axes.text(1.4, 3.2, "Label")
#
# # Plot multiple labels
# axes.text(numpy.linspace(0, 1), numpy.sin(linspace(0, 1)), numpy.arange(50))
#
# # Plot table
# axes.text(table, x="x", y=["y1", "y2"], text=["t1", "t2"])
#
# ```

# %%
import numpy
import toyplot.data

x = numpy.linspace(0, 2 * numpy.pi)
y = numpy.sin(x)

# %%
canvas = toyplot.Canvas(width=800, height=400)
axes = canvas.axes(grid=(1, 2, 0))
axes.text(1.4, 3.2, "Label 1", annotation=False)
axes.text(1.6, 3.0, "Label 2", annotation=False)
canvas.axes(grid=(1, 2, 1)).text(x, y, numpy.arange(50), annotation=False)
# Out:
# <div align="center" class="toyplot" id="td1e38b69f07242d5829441b5fb4bd805"><svg height="400.0px" id="t4c888b02a2b946ccbd6b19ab045cb697" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="800.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tc15beb8fec65419a9bc33bc30e492994"><clipPath id="tde61506af0844427bad6e6adb6119ac7"><rect height="300.0" width="300.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tde61506af0844427bad6e6adb6119ac7)" style="cursor:crosshair"><rect height="300.0" style="pointer-events:all;visibility:hidden" width="300.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Text" id="td398b734b5094052bba3258f73a75d36" style="alignment-baseline:middle;font-size:12px;font-weight:normal;stroke:none;text-anchor:middle"><g class="toyplot-S
# ...

# %%
table.rows(numpy.index_exp[0:10])
# Out:
# <table class="toyplot-data-Table" style="border-collapse:collapse; border:none; color: #292724"><tr style="border:none;border-bottom:1px solid #292724"><th style="text-align:left;border:none;padding-right:1em;">x</th><th style="text-align:left;border:none;padding-right:1em;">sin(x)</th><th style="text-align:left;border:none;padding-right:1em;">cos(x)</th><th style="text-align:left;border:none;padding-right:1em;">t1</th><th style="text-align:left;border:none;padding-right:1em;">t2</th></tr><tr style="border:none"><td style="border:none;padding-right:1em;">0.0</td><td style="border:none;padding-right:1em;">0.0</td><td style="border:none;padding-right:1em;">1.0</td><td style="border:none;padding-right:1em;">0</td><td style="border:none;padding-right:1em;">1</td></tr><tr style="border:none"><td style="border:none;padding-right:1em;">0.128228271575</td><td style="border:none;padding-right:1em;">0.127877161685</td><td style="border:none;padding-right:1em;">0.991790013823</td><td style="bor
# ...

# %%
canvas = toyplot.Canvas()
axes = canvas.axes()
#axes.text(table["x"], table["sin(x)"], table["t1"])
axes.text(table, x="x", y=["sin(x)", "sin(y)"], text=["t1", "t2"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-698e0d67d703> in <module>()
#       2 axes = canvas.axes()
#       3 #axes.text(table["x"], table["sin(x)"], table["t1"])
# ----> 4 axes.text(table, x="x", y=["sin(x)", "sin(y)"], text=["t1", "t2"])
#
# TypeError: text() got an unexpected keyword argument 'x'
# ...
