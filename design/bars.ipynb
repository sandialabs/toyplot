# %%
import numpy
import toyplot

# %%
numpy.random.seed(1234)
data = numpy.random.random(10)
x = numpy.linspace(0, 2, len(data))
x2 = numpy.linspace(0, 1, len(data)) ** 1.5
x3 = numpy.cumsum(numpy.random.random(len(data) + 1))
x4 = x3[:-1]
x5 = x3[1:]

toyplot.bars(data, width=300, height=300);
toyplot.bars(x, data, width=300, height=300);
toyplot.bars(x2, data, width=300, height=300);
toyplot.bars(x4, x5, data, width=300, height=300);
# Out:
# <div align="center" class="toyplot" id="t5479c3f3a37542bdb0ee4d54a00e51fd"><svg height="300px" id="t225b523f89634343882a3fb13fbeb265" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="300px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian2" id="t8f7c8460431748deadda5db098996160"><toyplot:axes>{"x": [{"domain": {"max": 10.0, "min": -0.5}, "range": {"max": 240, "min": 60}, "scale": "linear"}], "y": [{"domain": {"max": 1.0, "min": 0.0}, "range": {"max": 240, "min": 60}, "scale": "linear"}]}</toyplot:axes><clipPath id="t375f6433044741d0bd5784a2701fc3ff"><rect height="200" width="200" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t375f6433044741d0bd5784a2701fc3ff)" style="cursor:crosshair"><rect height="200" style="pointer-events:all;visibility:hidden" width="200"
# ...

# %%
observations = numpy.random.normal(size=(10000))
toyplot.bars(numpy.histogram(observations, 10), width=300, height=300);
# Out:
# <div align="center" class="toyplot" id="teb1c6b29e52243dc83a9aaa6fc81583a"><svg height="300px" id="t5a07271b07cb4414b555873a481edceb" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="300px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian2" id="t2ab9eaacb2c44f4eb48720a13717caa1"><toyplot:axes>{"x": [{"domain": {"max": 4.0, "min": -4.0}, "range": {"max": 240, "min": 60}, "scale": "linear"}], "y": [{"domain": {"max": 3000.0, "min": 0.0}, "range": {"max": 240, "min": 60}, "scale": "linear"}]}</toyplot:axes><clipPath id="t4d0f9dc775a54138b2fb852c5ac3d220"><rect height="200" width="200" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t4d0f9dc775a54138b2fb852c5ac3d220)" style="cursor:crosshair"><rect height="200" style="pointer-events:all;visibility:hidden" width="20
# ...

# %%
data = numpy.column_stack((numpy.random.random(10), numpy.random.random(10)))

toyplot.bars(data, width=300, height=300);
toyplot.bars(x, data, width=300, height=300);
toyplot.bars(x2, data, width=300, height=300);
toyplot.bars(x4, x5, data, width=300, height=300);
# Out:
# <div align="center" class="toyplot" id="t5571c076b1c94379a4e80e1ea74981ee"><svg height="300px" id="te4cc1be3674e41438bb8c7d8ed1254ac" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="300px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian2" id="tcbd7dc230fba4a628d8c9bd19b94757c"><toyplot:axes>{"x": [{"domain": {"max": 10.0, "min": -0.5}, "range": {"max": 240, "min": 60}, "scale": "linear"}], "y": [{"domain": {"max": 1.7255830023647287, "min": 0.0}, "range": {"max": 240, "min": 60}, "scale": "linear"}]}</toyplot:axes><clipPath id="t0a436de4a8254c2b930e6377c9baf184"><rect height="200" width="200" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t0a436de4a8254c2b930e6377c9baf184)" style="cursor:crosshair"><rect height="200" style="pointer-events:all;visibility:hidd
# ...

# %%
toyplot.bars(data, width=300, height=300, baseline=None);
toyplot.bars(x, data, width=300, height=300, baseline=None);
toyplot.bars(x2, data, width=300, height=300, baseline=None);
toyplot.bars(x4, x5, data, width=300, height=300, baseline=None);
# Out:
# <div align="center" class="toyplot" id="t50f1647af1294cc28621ac523a6d8f23"><svg height="300px" id="t6ad7436430ff430595d14cb6c9488606" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="300px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian2" id="t6de8504955964d59bd183dbe1e6452c7"><toyplot:axes>{"x": [{"domain": {"max": 10.0, "min": -0.5}, "range": {"max": 240, "min": 60}, "scale": "linear"}], "y": [{"domain": {"max": 0.9446142393124688, "min": 0.0}, "range": {"max": 240, "min": 60}, "scale": "linear"}]}</toyplot:axes><clipPath id="tacaa67d437eb41f1a7c6cf0913a85491"><rect height="200" width="200" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tacaa67d437eb41f1a7c6cf0913a85491)" style="cursor:crosshair"><rect height="200" style="pointer-events:all;visibility:hidd
# ...
