# %% [markdown]
# ## Overview
#
# To facilitate graph analysis, we need to support sharing layouts between graphs, something I haven't seen done very well elsewhere.  In particular, it should be possible to:
#
# * &#x2713; "Pin" a few key vertices while letting the layout handle the remaining vertices.
# * &#x2713; Render a graph using another graph's vertices, whether it is a superset or subset of the original.
# * &#x2713; An implicit requirement is the ability to perform a layout on some vertices while leaving others unchanged.
# * &#x2713; Another implicit requirement is the ability to supply disconnected vertex ids to be merged with the induced ids.

# %% [markdown]
# So the process to layout graph $G_1$, given an (optional) layout of graph $G_0$ is (I think):
#
# * Extract the edges for $G_1$.
#     * Either an $E \times 2$ matrix, or
#     * Two $|E|$ vectors.
# * Identify the vertex ids $V_1$ induced by those edges.
# * Merge optional user-supplied vertex ids with $V_1$ (to allow for disconnected vertices).
# * Create a set of completely masked vertex coordinates, $V_{C_1}$.
# * If the user supplied an "other" toyplot.layout.GraphLayout object from $G_0$, use the $V_0$ vertex ids to merge $V_{C_0}$ coordinates into $V_{C_1}$.
# * If the user supplied a set of external vertex coordinates $V_{C_{external}}$ with length $|V_1|$, merge them into $V_{C_1}$.
# * Apply a layout algorithm to any remaining masked values in $V_{C_1}$.

# %% [markdown]
# Allowed input formats:
#
# * toyplot.graph(edges, [vids], [olayout], [vcoordinates])
# * toyplot.graph(sources, targets, [vids], [olayout], [vcoordinates])

# %%
import numpy
import toyplot.color
import toyplot.generate

# %%
numpy.random.seed(1234)

# %%
colormap = toyplot.color.LinearMap(toyplot.color.Palette(["white", "yellow", "red"]))

# %%
G0 = toyplot.generate.prufer_tree(numpy.random.choice(4, 12))
G1 = G0[:-4]
G2 = G0[4:]

# %%
canvas = toyplot.Canvas(width=1000, height=500)

axes = canvas.axes(grid=(1, 2, 0), show=False)
axes.aspect = "fit-range"
mark = axes.graph(
    G0,
    vcolor=colormap,
    vstyle={"stroke":"black"},
    vsize=20,
    ecolor="black",
    eopacity=0.2,
);

vcoordinates = numpy.ma.masked_all((mark.vcount, 2))
vcoordinates[0] = (-1, 0)
vcoordinates[1] = (0, 0)
vcoordinates[2] = (1, 0)

axes = canvas.axes(grid=(1, 2, 1), show=False)
axes.aspect = "fit-range"
mark = axes.graph(
    G0,
    vcoordinates=vcoordinates,
    vcolor=colormap,
    vstyle={"stroke":"black"},
    vsize=20,
    ecolor="black",
    eopacity=0.2,
);

print "Pinned Vertices:"
# Out:
# INFO:toyplot:Graph layout time: 61.1660480499 ms
# INFO:toyplot:Graph layout time: 44.5070266724 ms
# Pinned Vertices:
# <div align="center" class="toyplot" id="t0a0b5f4720f94885b88b25d73e5b08a3"><svg height="500.0px" id="t94c2cc98ea4147b7b1422766e504d043" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 1000.0 500.0" width="1000.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tfd2bed0ce32349bd97d8e36c6a2272ac"><clipPath id="tb4be251e72b74af5abd9a5b55a13f6d3"><rect height="420.0" width="420.0" x="40.0" y="40.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tb4be251e72b74af5abd9a5b55a13f6d3)" style="cursor:crosshair"><rect height="420.0" style="pointer-events:all;visibility:hidden" width="420.0" x="40.0" y="40.0"></rect><g class="toyplot-mark-Graph" id="t1aebd6fcb5d34f798053c5430c5e7332"><g class="toyplot-Edges"><path d="M 212.989824851 122.095325547 L 242.175277852 50.0" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 212.989824851 122.095325547 L 147.327040719 90.1252303481" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 299.703905632 263.884406472 L 370.941013351 276.443631658" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 209.584889652 248.57881015 L 299.703905632 263.884406472" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 191.254021979 367.292268811 L 129.686439009 408.899221032" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 191.254021979 367.292268811 L 179.547501952 442.798262908" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 191.254021979 367.292268811 L 237.326088756 422.891476261" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 209.584889652 248.57881015 L 191.254021979 367.292268811" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 212.989824851 122.095325547 L 186.817405218 50.5312712524" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 209.584889652 248.57881015 L 153.411500782 278.251914861" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 212.989824851 122.095325547 L 279.00535555 93.2506777738" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 209.584889652 248.57881015 L 212.989824851 122.095325547" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 209.584889652 248.57881015 L 149.12644901 222.081467898" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="191.25402197937558" cy="367.29226881073197" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,84.6%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="209.58488965157997" cy="248.57881014969223" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,69.2%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="299.70390563237885" cy="263.88440647176407" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,53.8%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="212.98982485142017" cy="122.09532554692672" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,38.5%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="242.17527785163463" cy="50.0" r="10.0"></circ ...

# %%
canvas = toyplot.Canvas(width=1000, height=500)

axes = canvas.axes(grid=(1, 2, 0), show=False)
axes.aspect = "fit-range"
mark = axes.graph(
    G0,
    vcolor=colormap,
    vstyle={"stroke":"black"},
    vsize=20,
    ecolor="black",
    eopacity=0.2,
);

axes = canvas.axes(grid=(1, 2, 1), show=False)
axes.aspect = "fit-range"
mark = axes.graph(
    G1,
    olayout = mark,
    vcolor=colormap,
    vstyle={"stroke":"black"},
    vsize=20,
    ecolor="black",
    eopacity=0.2,
);

print "Shared Layout (Subset):"
# Out:
# INFO:toyplot:Graph layout time: 49.3140220642 ms
# INFO:toyplot:Graph layout time: 44.2850589752 ms
# Shared Layout (Subset):
# <div align="center" class="toyplot" id="t876bb7091537441d8adcccc4ac3d4487"><svg height="500.0px" id="t41c18b6779d946a78f6c3547ee6ede67" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 1000.0 500.0" width="1000.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t14d5220b8c364da9b67e1f9c663ae793"><clipPath id="td1be7455df8243808bf8b76a848fba97"><rect height="420.0" width="420.0" x="40.0" y="40.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#td1be7455df8243808bf8b76a848fba97)" style="cursor:crosshair"><rect height="420.0" style="pointer-events:all;visibility:hidden" width="420.0" x="40.0" y="40.0"></rect><g class="toyplot-mark-Graph" id="t5993abae5ff842e1aa1189d82472a650"><g class="toyplot-Edges"><path d="M 212.989824851 122.095325547 L 242.175277852 50.0" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 212.989824851 122.095325547 L 147.327040719 90.1252303481" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 299.703905632 263.884406472 L 370.941013351 276.443631658" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 209.584889652 248.57881015 L 299.703905632 263.884406472" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 191.254021979 367.292268811 L 129.686439009 408.899221032" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 191.254021979 367.292268811 L 179.547501952 442.798262908" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 191.254021979 367.292268811 L 237.326088756 422.891476261" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 209.584889652 248.57881015 L 191.254021979 367.292268811" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 212.989824851 122.095325547 L 186.817405218 50.5312712524" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 209.584889652 248.57881015 L 153.411500782 278.251914861" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 212.989824851 122.095325547 L 279.00535555 93.2506777738" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 209.584889652 248.57881015 L 212.989824851 122.095325547" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 209.584889652 248.57881015 L 149.12644901 222.081467898" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="191.25402197937558" cy="367.29226881073197" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,84.6%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="209.58488965157997" cy="248.57881014969223" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,69.2%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="299.70390563237885" cy="263.88440647176407" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,53.8%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="212.98982485142017" cy="122.09532554692672" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,38.5%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="242.17527785163463" cy="50.0" r="10.0"></circ ...

# %%
canvas = toyplot.Canvas(width=1000, height=500)

axes = canvas.axes(grid=(1, 2, 0), show=False)
axes.aspect = "fit-range"
mark = axes.graph(
    G2,
    vcolor=colormap,
    vstyle={"stroke":"black"},
    vsize=20,
    ecolor="black",
    eopacity=0.2,
);

axes = canvas.axes(grid=(1, 2, 1), show=False)
axes.aspect = "fit-range"
mark = axes.graph(
    G0,
    olayout = mark,
    vcolor=colormap,
    vstyle={"stroke":"black"},
    vsize=20,
    ecolor="black",
    eopacity=0.2,
);

print "Shared Layout (Superset):"
# Out:
# INFO:toyplot:Graph layout time: 45.7689762115 ms
# INFO:toyplot:Graph layout time: 44.2869663239 ms
# Shared Layout (Superset):
# <div align="center" class="toyplot" id="t84f6d0e9f8b446c1b2324ecb2dcd33d2"><svg height="500.0px" id="t4f486bb176044d8ba1da1e95db0e6403" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 1000.0 500.0" width="1000.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="teb6616631b3c4a8d840b225bc62d074d"><clipPath id="tb8d242b953b744dd85563447a2406d52"><rect height="420.0" width="420.0" x="40.0" y="40.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tb8d242b953b744dd85563447a2406d52)" style="cursor:crosshair"><rect height="420.0" style="pointer-events:all;visibility:hidden" width="420.0" x="40.0" y="40.0"></rect><g class="toyplot-mark-Graph" id="t7050704f55444483bce9dbfaef56af7f"><g class="toyplot-Edges"><path d="M 181.815535733 128.743572027 L 128.215623811 55.080174613" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 181.815535733 128.743572027 L 215.750776474 50.0" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 181.815535733 128.743572027 L 91.7040761966 130.4115928" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 258.543767486 235.429368662 L 181.815535733 128.743572027" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 333.037155284 334.96999942 L 416.658595811 367.166177452" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 258.543767486 235.429368662 L 196.721796766 289.527135423" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 333.037155284 334.96999942 L 338.817554586 420.001738567" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 258.543767486 235.429368662 L 333.037155284 334.96999942" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 258.543767486 235.429368662 L 332.658711429 199.781542558" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="181.81553573255164" cy="128.74357202731369" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,77.8%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="258.54376748587367" cy="235.42936866233632" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,55.6%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="333.03715528441018" cy="334.9699994195044" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,33.3%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="128.21562381143576" cy="55.080174612951673" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,11.1%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="215.75077647368002" cy="50.0" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,88.9%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="91.704076196606138" cy="130.411592799913" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,66.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="416.65859581140194" cy="367.1661774518405" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,44.4%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="196.72179676641397" cy="289.5271354229447" r="10.0"></circ ...

# %%
extra_vids = numpy.arange(50, 55)

canvas = toyplot.Canvas(width=1000, height=500)

axes = canvas.axes(grid=(1, 2, 0), show=False)
axes.aspect = "fit-range"
mark = axes.graph(
    G2,
    extra_vids,
    vcolor=colormap,
    vstyle={"stroke":"black"},
    vsize=20,
    ecolor="black",
    eopacity=0.2,
);

axes = canvas.axes(grid=(1, 2, 1), show=False)
axes.aspect = "fit-range"
mark = axes.graph(
    G0,
    extra_vids,
    olayout = mark,
    vcolor=colormap,
    vstyle={"stroke":"black"},
    vsize=20,
    ecolor="black",
    eopacity=0.2,
);

print "Shared Layout (Disconnected Vertices):"
# Out:
# INFO:toyplot:Graph layout time: 51.7859458923 ms
# INFO:toyplot:Graph layout time: 46.0848808289 ms
# Shared Layout (Disconnected Vertices):
# <div align="center" class="toyplot" id="t86e90aee5c94408a8b07c079d3187c1f"><svg height="500.0px" id="t608ad2375aba4e958349d6cbf29c82ee" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 1000.0 500.0" width="1000.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t2212a43a30d14b74addf4387a792f036"><clipPath id="t3dc193b5517b4f73ac5f48e4bf50fd78"><rect height="420.0" width="420.0" x="40.0" y="40.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t3dc193b5517b4f73ac5f48e4bf50fd78)" style="cursor:crosshair"><rect height="420.0" style="pointer-events:all;visibility:hidden" width="420.0" x="40.0" y="40.0"></rect><g class="toyplot-mark-Graph" id="t193994d160334249a5be5be636e98d61"><g class="toyplot-Edges"><path d="M 216.009629974 273.711478775 L 198.553263785 257.340472365" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 216.009629974 273.711478775 L 219.819067081 250.189082688" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 216.009629974 273.711478775 L 194.645146889 280.718961288" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 241.530345698 297.93461428 L 216.009629974 273.711478775" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 265.596354449 321.512380503 L 287.968916019 326.213293353" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 241.530345698 297.93461428 L 230.948038233 316.922303842" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 265.596354449 321.512380503 L 272.572367821 344.911034776" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 241.530345698 297.93461428 L 265.596354449 321.512380503" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 241.530345698 297.93461428 L 258.046150068 284.012074309" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="216.00962997355148" cy="273.7114787745349" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,85.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="241.53034569844999" cy="297.9346142804946" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,71.4%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="265.59635444919786" cy="321.51238050254068" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,57.1%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="198.55326378529452" cy="257.34047236507564" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,42.9%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="219.81906708053486" cy="250.18908268821284" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,28.6%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="194.64514688912112" cy="280.71896128804269" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,14.3%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="287.96891601906685" cy="326.21329335318279" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="230.94803823317113" cy="316. ...
