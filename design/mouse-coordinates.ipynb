# %%
import numpy
import toyplot

# %%
toyplot.plot(numpy.linspace(0, 1) ** 2);
# Out:
# <div align="center" class="toyplot" id="tfe09e90b95d544b8b64326e0a20f154a"><svg height="600px" id="tfebb72f4516b4a908352ec1b3d4ea702" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t308612f1bfb24da28ddb9b0b41d992e8"><clipPath id="tb48d69404a834f059af5e3e740f284d6"><rect height="520.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tb48d69404a834f059af5e3e740f284d6)" style="cursor:crosshair"><rect height="520.0" style="pointer-events:all;visibility:hidden" width="520.0" x="40.0" y="40.0"></rect><g class="toyplot-mark-Plot" id="tbdaf8e66086642ae8fe461e6cda3a3aa" style="fill:none"><g class="toyplo
# ...
