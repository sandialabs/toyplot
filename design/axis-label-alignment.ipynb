# %%
import toyplot.pdf

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, padding=20)
axes.x.ticks.show = True
axes.y.ticks.show = True
# Out:
# <div align="center" class="toyplot" id="te6ab06daf6294e8db8dc423a1784c448"><svg height="600px" id="t710e86b87b5f4a9eb49d40f5244bd604" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t1236d347169640a4ab7575edaf6da2a0"><clipPath id="t4d35eadac75e43f28b24f28a431984d1"><rect height="540.0" width="540.0" x="30.0" y="30.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t4d35eadac75e43f28b24f28a431984d1)" style="cursor:crosshair"><rect height="540.0" style="pointer-events:all;visibility:hidden" width="540.0" x="30.0" y="30.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="450.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="495.0" y="67.0"></text></g><g class="toyplot-axes-Axis" id="tf82f367dabfe47f98ce58867157cd1e0" transform="translate(50.0,570.0) rotate(0.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="125.0" x2="125.0" y1="-5" y2="0"></line><line style="" x1="250.0" x2="250.0" y1="-5" y2="0"></line><line style="" x1="375.0" x2="375.0" y1="-5" y2="0"></line><line style="" x1="500.0" x2="500.0" y1="-5" y2="0"></line></g><g><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,0) rotate(0)" x="0" y="0">-1000</text><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(125.0,0) rotate(0)" x="0" y="0">-500</text><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(250.0,0) rotate(0)" x="0" y="0">0</text><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(375.0,0) rotate(0)" x="0" y="0">500</text><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(500.0,0) rotate(0)" x="0" y="0">1000</text></g></g><g class="toyplot-axes-Axis" id="t30c5d24b8397455c912c78cfa8cd389e" transform="translate(30.0,550.0) rotate(-90.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="125.0" x2="125.0" y1="0" y2="5"></line><line style="" x1="250.0" x2="250.0" y1="0" y2="5"></line><line style="" x1="375.0" x2="375.0" y1="0" y2="5"></line><line style="" x1="500.0" x2="500.0" y1="0" y2="5"></line></g><g><text style="alignment-baseline:middle;baseline-shift:80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,0) rotate(0)" x="0" y="0">-1000</text><text style="alignment-baseline:middle;baseline-shift:80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(125.0,0) rotate(0)" x="0" y="0">-500</text><text style="alignment-baseline:middle;baseline-shift:80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(250.0,0) rotate(0)" x="0" y="0">0</text><text style="alignment-baseline:middle;baseline-shift:80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(375.0,0) rotate(0)" x="0" y="0">500</text><text style="alignment-baseline:middle;baseline-shift:80%;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate ...
# (function()
# {
#   if(window.CSS !== undefined && window.CSS.supports !== undefined)
#   {
#     if(!window.CSS.supports("alignment-baseline", "middle"))
#     {
#       var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#te6ab06daf6294e8db8dc423a1784c448 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           if(match[1] == "middle")
#           {
#             var style = getComputedStyle(text[i]);
#             var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#             var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#             dy += 0.4 * font_size;
#             text[i].setAttribute("dy", dy);
#           }
#         }
#       }
#     }
#     if(!window.CSS.supports("baseline-shift", "0"))
#     {
#       var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#te6ab06daf6294e8db8dc423a1784c448 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           var style = getComputedStyle(text[i]);
#           var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#           var percent = 0.01 * match[1].substr(0, match[1].length-1);
#           var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#           dy -= percent * font_size
#           text[i].setAttribute("dy", dy);
#         }
#       }
#     }
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"t1236d347169640a4ab7575edaf6da2a0": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 550.0, "min": 50.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 50.0, "min": 550.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object,

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, padding=20)
axes.x.ticks.show = True
axes.x.ticks.labels.style = {"font-size":"18px"}
axes.y.ticks.show = True
axes.y.ticks.labels.style = {"font-size":"18px"}
# Out:
# <div align="center" class="toyplot" id="t1b98d1181f604cfb85392a96963a990a"><svg height="600px" id="t3220191fc5114fd3aa15728b01aaba84" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tfd2dee6568884d0aba4cdb08c21078a6"><clipPath id="t1c35dcf6ddc84937b5be3df26475af93"><rect height="540.0" width="540.0" x="30.0" y="30.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t1c35dcf6ddc84937b5be3df26475af93)" style="cursor:crosshair"><rect height="540.0" style="pointer-events:all;visibility:hidden" width="540.0" x="30.0" y="30.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="450.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="495.0" y="67.0"></text></g><g class="toyplot-axes-Axis" id="t84eef72411ee4639a0ee6e35d48d330e" transform="translate(50.0,570.0) rotate(0.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="125.0" x2="125.0" y1="-5" y2="0"></line><line style="" x1="250.0" x2="250.0" y1="-5" y2="0"></line><line style="" x1="375.0" x2="375.0" y1="-5" y2="0"></line><line style="" x1="500.0" x2="500.0" y1="-5" y2="0"></line></g><g><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,0) rotate(0)" x="0" y="0">-1000</text><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(125.0,0) rotate(0)" x="0" y="0">-500</text><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(250.0,0) rotate(0)" x="0" y="0">0</text><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(375.0,0) rotate(0)" x="0" y="0">500</text><text style="alignment-baseline:middle;baseline-shift:-80%;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(500.0,0) rotate(0)" x="0" y="0">1000</text></g></g><g class="toyplot-axes-Axis" id="t82482a3445bd4f0fba3880230d7882f7" transform="translate(30.0,550.0) rotate(-90.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="125.0" x2="125.0" y1="0" y2="5"></line><line style="" x1="250.0" x2="250.0" y1="0" y2="5"></line><line style="" x1="375.0" x2="375.0" y1="0" y2="5"></line><line style="" x1="500.0" x2="500.0" y1="0" y2="5"></line></g><g><text style="alignment-baseline:middle;baseline-shift:80%;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,0) rotate(0)" x="0" y="0">-1000</text><text style="alignment-baseline:middle;baseline-shift:80%;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(125.0,0) rotate(0)" x="0" y="0">-500</text><text style="alignment-baseline:middle;baseline-shift:80%;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(250.0,0) rotate(0)" x="0" y="0">0</text><text style="alignment-baseline:middle;baseline-shift:80%;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(375.0,0) rotate(0)" x="0" y="0">500</text><text style="alignment-baseline:middle;baseline-shift:80%;font-size:18px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate ...
# (function()
# {
#   if(window.CSS !== undefined && window.CSS.supports !== undefined)
#   {
#     if(!window.CSS.supports("alignment-baseline", "middle"))
#     {
#       var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t1b98d1181f604cfb85392a96963a990a text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           if(match[1] == "middle")
#           {
#             var style = getComputedStyle(text[i]);
#             var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#             var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#             dy += 0.4 * font_size;
#             text[i].setAttribute("dy", dy);
#           }
#         }
#       }
#     }
#     if(!window.CSS.supports("baseline-shift", "0"))
#     {
#       var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t1b98d1181f604cfb85392a96963a990a text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           var style = getComputedStyle(text[i]);
#           var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#           var percent = 0.01 * match[1].substr(0, match[1].length-1);
#           var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#           dy -= percent * font_size
#           text[i].setAttribute("dy", dy);
#         }
#       }
#     }
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"tfd2dee6568884d0aba4cdb08c21078a6": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 550.0, "min": 50.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 50.0, "min": 550.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object,

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, gutter=100, padding=20)
axes.x.ticks.show = True
axes.x.ticks.labels.angle = 90
axes.x.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "-toyplot-anchor-shift":"-6px", "baseline-shift":0}
axes.y.ticks.show = True
axes.y.ticks.labels.angle = -90
axes.y.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "-toyplot-anchor-shift":"-6px", "baseline-shift":0}
# Out:
# <div align="center" class="toyplot" id="t73385cb37e6c418393ba56b197cde4b7"><svg height="600px" id="ta1130372c9474529aafdfd695743ef5b" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t6ace2e8117a642708fd560d3a017fc93"><clipPath id="tcb882ceab06f4785893ca426eec3b823"><rect height="440.0" width="440.0" x="80.0" y="80.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tcb882ceab06f4785893ca426eec3b823)" style="cursor:crosshair"><rect height="440.0" style="pointer-events:all;visibility:hidden" width="440.0" x="80.0" y="80.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="400.0" y="110.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="445.0" y="117.0"></text></g><g class="toyplot-axes-Axis" id="t15a3974c0f264db89d770b47f055fc3a" transform="translate(100.0,520.0) rotate(0.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="100.0" x2="100.0" y1="-5" y2="0"></line><line style="" x1="200.0" x2="200.0" y1="-5" y2="0"></line><line style="" x1="300.0" x2="300.0" y1="-5" y2="0"></line><line style="" x1="400.0" x2="400.0" y1="-5" y2="0"></line></g><g><text dx="-6px" style="-toyplot-anchor-shift:-6px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,0) rotate(-90)" x="0" y="0">-1000</text><text dx="-6px" style="-toyplot-anchor-shift:-6px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,0) rotate(-90)" x="0" y="0">-500</text><text dx="-6px" style="-toyplot-anchor-shift:-6px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,0) rotate(-90)" x="0" y="0">0</text><text dx="-6px" style="-toyplot-anchor-shift:-6px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,0) rotate(-90)" x="0" y="0">500</text><text dx="-6px" style="-toyplot-anchor-shift:-6px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(400.0,0) rotate(-90)" x="0" y="0">1000</text></g></g><g class="toyplot-axes-Axis" id="tae154f82abb04ff8971775a41f26afc3" transform="translate(80.0,500.0) rotate(-90.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="100.0" x2="100.0" y1="0" y2="5"></line><line style="" x1="200.0" x2="200.0" y1="0" y2="5"></line><line style="" x1="300.0" x2="300.0" y1="0" y2="5"></line><line style="" x1="400.0" x2="400.0" y1="0" y2="5"></line></g><g><text dx="-6px" style="-toyplot-anchor-shift:-6px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,0) rotate(90)" x="0" y="0">-1000</text><text dx="-6px" style="-toyplot-anchor-shift:-6px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,0) rotate(90)" x="0" y="0">-500</text><text dx="-6px" style="-toyplot-anchor-shift:-6px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,0) rotate(90)" x="0" y="0">0</text><text dx="-6px" style="-toyplot-anchor-shift:-6px;alignment-base ...
# (function()
# {
#   if(window.CSS !== undefined && window.CSS.supports !== undefined)
#   {
#     if(!window.CSS.supports("alignment-baseline", "middle"))
#     {
#       var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t73385cb37e6c418393ba56b197cde4b7 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           if(match[1] == "middle")
#           {
#             var style = getComputedStyle(text[i]);
#             var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#             var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#             dy += 0.4 * font_size;
#             text[i].setAttribute("dy", dy);
#           }
#         }
#       }
#     }
#     if(!window.CSS.supports("baseline-shift", "0"))
#     {
#       var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t73385cb37e6c418393ba56b197cde4b7 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           var style = getComputedStyle(text[i]);
#           var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#           var percent = 0.01 * match[1].substr(0, match[1].length-1);
#           var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#           dy -= percent * font_size
#           text[i].setAttribute("dy", dy);
#         }
#       }
#     }
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"t6ace2e8117a642708fd560d3a017fc93": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 500.0, "min": 100.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 100.0, "min": 500.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount =

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, gutter=100, padding=20)
axes.x.ticks.show = True
axes.x.ticks.labels.angle = 45
axes.x.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "-toyplot-anchor-shift":"-12px", "baseline-shift":0}
axes.y.ticks.show = True
axes.y.ticks.labels.angle = -45
axes.y.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "-toyplot-anchor-shift":"-12px", "baseline-shift":0}
# Out:
# <div align="center" class="toyplot" id="t0e136df8042b436cb9f650ef90d96d5c"><svg height="600px" id="t507ceb37653946459d4ae11b223ea71b" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t7ab277f9374848319a057f15c24fc711"><clipPath id="te7ccecc8fe76440cb023f445eba9ba3c"><rect height="440.0" width="440.0" x="80.0" y="80.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#te7ccecc8fe76440cb023f445eba9ba3c)" style="cursor:crosshair"><rect height="440.0" style="pointer-events:all;visibility:hidden" width="440.0" x="80.0" y="80.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="400.0" y="110.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="445.0" y="117.0"></text></g><g class="toyplot-axes-Axis" id="tacc2cdf8756a47509a139598df6dc3a3" transform="translate(100.0,520.0) rotate(0.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="100.0" x2="100.0" y1="-5" y2="0"></line><line style="" x1="200.0" x2="200.0" y1="-5" y2="0"></line><line style="" x1="300.0" x2="300.0" y1="-5" y2="0"></line><line style="" x1="400.0" x2="400.0" y1="-5" y2="0"></line></g><g><text dx="-12px" style="-toyplot-anchor-shift:-12px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,0) rotate(-45)" x="0" y="0">-1000</text><text dx="-12px" style="-toyplot-anchor-shift:-12px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,0) rotate(-45)" x="0" y="0">-500</text><text dx="-12px" style="-toyplot-anchor-shift:-12px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,0) rotate(-45)" x="0" y="0">0</text><text dx="-12px" style="-toyplot-anchor-shift:-12px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,0) rotate(-45)" x="0" y="0">500</text><text dx="-12px" style="-toyplot-anchor-shift:-12px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(400.0,0) rotate(-45)" x="0" y="0">1000</text></g></g><g class="toyplot-axes-Axis" id="t7bd9a991968c4cd58a992cfdef4ffcf0" transform="translate(80.0,500.0) rotate(-90.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="100.0" x2="100.0" y1="0" y2="5"></line><line style="" x1="200.0" x2="200.0" y1="0" y2="5"></line><line style="" x1="300.0" x2="300.0" y1="0" y2="5"></line><line style="" x1="400.0" x2="400.0" y1="0" y2="5"></line></g><g><text dx="-12px" style="-toyplot-anchor-shift:-12px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,0) rotate(45)" x="0" y="0">-1000</text><text dx="-12px" style="-toyplot-anchor-shift:-12px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,0) rotate(45)" x="0" y="0">-500</text><text dx="-12px" style="-toyplot-anchor-shift:-12px;alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,0) rotate(45)" x="0" y="0">0</text><text dx="-12px" style="-toyplot-anchor-shift:-1 ...
# (function()
# {
#   if(window.CSS !== undefined && window.CSS.supports !== undefined)
#   {
#     if(!window.CSS.supports("alignment-baseline", "middle"))
#     {
#       var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t0e136df8042b436cb9f650ef90d96d5c text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           if(match[1] == "middle")
#           {
#             var style = getComputedStyle(text[i]);
#             var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#             var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#             dy += 0.4 * font_size;
#             text[i].setAttribute("dy", dy);
#           }
#         }
#       }
#     }
#     if(!window.CSS.supports("baseline-shift", "0"))
#     {
#       var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t0e136df8042b436cb9f650ef90d96d5c text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           var style = getComputedStyle(text[i]);
#           var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#           var percent = 0.01 * match[1].substr(0, match[1].length-1);
#           var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#           dy -= percent * font_size
#           text[i].setAttribute("dy", dy);
#         }
#       }
#     }
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"t7ab277f9374848319a057f15c24fc711": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 500.0, "min": 100.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 100.0, "min": 500.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, gutter=100, padding=20)
axes.x.ticks.show = True
axes.x.ticks.labels.angle = 45
axes.x.ticks.labels.offset = "12px"
axes.x.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "baseline-shift":0}
axes.y.ticks.show = True
axes.y.ticks.labels.angle = -45
axes.y.ticks.labels.offset = "-12px"
axes.y.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "baseline-shift":0}
# Out:
# <div align="center" class="toyplot" id="t5495a058edec4f4eb4853639e6de166a"><svg height="600px" id="t0088e9eba3194e6480bb7fe4d0b22713" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="td90204206e834acebae43961fa7f94f7"><clipPath id="td7037668a96543a5b4cc9668ec7f5875"><rect height="440.0" width="440.0" x="80.0" y="80.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#td7037668a96543a5b4cc9668ec7f5875)" style="cursor:crosshair"><rect height="440.0" style="pointer-events:all;visibility:hidden" width="440.0" x="80.0" y="80.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="400.0" y="110.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="445.0" y="117.0"></text></g><g class="toyplot-axes-Axis" id="t21482ec2dd674b5597429c8e3d49b149" transform="translate(100.0,520.0) rotate(0.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="100.0" x2="100.0" y1="-5" y2="0"></line><line style="" x1="200.0" x2="200.0" y1="-5" y2="0"></line><line style="" x1="300.0" x2="300.0" y1="-5" y2="0"></line><line style="" x1="400.0" x2="400.0" y1="-5" y2="0"></line></g><g><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,12.0) rotate(-45)" x="0" y="0">-1000</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,12.0) rotate(-45)" x="0" y="0">-500</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,12.0) rotate(-45)" x="0" y="0">0</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,12.0) rotate(-45)" x="0" y="0">500</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(400.0,12.0) rotate(-45)" x="0" y="0">1000</text></g></g><g class="toyplot-axes-Axis" id="t0cf4574f3119419e81aff8eaa95aab03" transform="translate(80.0,500.0) rotate(-90.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="100.0" x2="100.0" y1="0" y2="5"></line><line style="" x1="200.0" x2="200.0" y1="0" y2="5"></line><line style="" x1="300.0" x2="300.0" y1="0" y2="5"></line><line style="" x1="400.0" x2="400.0" y1="0" y2="5"></line></g><g><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,-12.0) rotate(45)" x="0" y="0">-1000</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,-12.0) rotate(45)" x="0" y="0">-500</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,-12.0) rotate(45)" x="0" y="0">0</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,-12.0) rotate(45)" x="0" y="0">500</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(400.0, ...
# (function()
# {
#   if(window.CSS !== undefined && window.CSS.supports !== undefined)
#   {
#     if(!window.CSS.supports("alignment-baseline", "middle"))
#     {
#       var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t5495a058edec4f4eb4853639e6de166a text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           if(match[1] == "middle")
#           {
#             var style = getComputedStyle(text[i]);
#             var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#             var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#             dy += 0.4 * font_size;
#             text[i].setAttribute("dy", dy);
#           }
#         }
#       }
#     }
#     if(!window.CSS.supports("baseline-shift", "0"))
#     {
#       var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t5495a058edec4f4eb4853639e6de166a text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           var style = getComputedStyle(text[i]);
#           var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#           var percent = 0.01 * match[1].substr(0, match[1].length-1);
#           var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#           dy -= percent * font_size
#           text[i].setAttribute("dy", dy);
#         }
#       }
#     }
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"td90204206e834acebae43961fa7f94f7": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 500.0, "min": 100.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 100.0, "min": 500.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object,

# %%
canvas = toyplot.Canvas()
axes = canvas.axes(xmin=-1000, xmax=1000, ymin=-1000, ymax=1000, gutter=100, padding=20)
axes.x.ticks.show = True
axes.x.ticks.labels.angle = 90
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "baseline-shift":"-10%"}
axes.y.ticks.show = True
axes.y.ticks.labels.angle = -90
axes.y.ticks.labels.offset = -10
axes.y.ticks.labels.style = {"font-size":"18px", "text-anchor":"end", "baseline-shift":0}
# Out:
# <div align="center" class="toyplot" id="tebb3df8e99234379b1fb0d29b64f9cf3"><svg height="600px" id="tca9e26c2657b4bbca716bb809d419065" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tbed99255fa4149f08211f00c14b1b97f"><clipPath id="t98c396901c054f1bb7561b560179f24d"><rect height="440.0" width="440.0" x="80.0" y="80.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t98c396901c054f1bb7561b560179f24d)" style="cursor:crosshair"><rect height="440.0" style="pointer-events:all;visibility:hidden" width="440.0" x="80.0" y="80.0"></rect></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="400.0" y="110.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="445.0" y="117.0"></text></g><g class="toyplot-axes-Axis" id="tfef1b4da0dba4acc890f8a48ab8b3758" transform="translate(100.0,520.0) rotate(0.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="-5" y2="0"></line><line style="" x1="100.0" x2="100.0" y1="-5" y2="0"></line><line style="" x1="200.0" x2="200.0" y1="-5" y2="0"></line><line style="" x1="300.0" x2="300.0" y1="-5" y2="0"></line><line style="" x1="400.0" x2="400.0" y1="-5" y2="0"></line></g><g><text style="alignment-baseline:middle;baseline-shift:-10%;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,10.0) rotate(-90)" x="0" y="0">-1000</text><text style="alignment-baseline:middle;baseline-shift:-10%;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,10.0) rotate(-90)" x="0" y="0">-500</text><text style="alignment-baseline:middle;baseline-shift:-10%;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,10.0) rotate(-90)" x="0" y="0">0</text><text style="alignment-baseline:middle;baseline-shift:-10%;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,10.0) rotate(-90)" x="0" y="0">500</text><text style="alignment-baseline:middle;baseline-shift:-10%;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(400.0,10.0) rotate(-90)" x="0" y="0">1000</text></g></g><g class="toyplot-axes-Axis" id="t324068ffa74e4c5da7f56953a961864a" transform="translate(80.0,500.0) rotate(-90.0)"><line style="" x1="0" x2="400.0" y1="0" y2="0"></line><g><line style="" x1="0.0" x2="0.0" y1="0" y2="5"></line><line style="" x1="100.0" x2="100.0" y1="0" y2="5"></line><line style="" x1="200.0" x2="200.0" y1="0" y2="5"></line><line style="" x1="300.0" x2="300.0" y1="0" y2="5"></line><line style="" x1="400.0" x2="400.0" y1="0" y2="5"></line></g><g><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(0.0,-10.0) rotate(90)" x="0" y="0">-1000</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(100.0,-10.0) rotate(90)" x="0" y="0">-500</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(200.0,-10.0) rotate(90)" x="0" y="0">0</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="translate(300.0,-10.0) rotate(90)" x="0" y="0">500</text><text style="alignment-baseline:middle;baseline-shift:0;font-size:18px;font-weight:normal;stroke:none;text-anchor:end" transform="t ...
# (function()
# {
#   if(window.CSS !== undefined && window.CSS.supports !== undefined)
#   {
#     if(!window.CSS.supports("alignment-baseline", "middle"))
#     {
#       var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#tebb3df8e99234379b1fb0d29b64f9cf3 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           if(match[1] == "middle")
#           {
#             var style = getComputedStyle(text[i]);
#             var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#             var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#             dy += 0.4 * font_size;
#             text[i].setAttribute("dy", dy);
#           }
#         }
#       }
#     }
#     if(!window.CSS.supports("baseline-shift", "0"))
#     {
#       var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#tebb3df8e99234379b1fb0d29b64f9cf3 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           var style = getComputedStyle(text[i]);
#           var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#           var percent = 0.01 * match[1].substr(0, match[1].length-1);
#           var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#           dy -= percent * font_size
#           text[i].setAttribute("dy", dy);
#         }
#       }
#     }
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"tbed99255fa4149f08211f00c14b1b97f": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 500.0, "min": 100.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 1000.0, "min": -1000.0}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 100.0, "min": 500.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to

# %%
toyplot.pdf.render(canvas, "test.pdf")
