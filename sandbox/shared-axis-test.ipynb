# %%
import numpy

import toyplot

canvas = toyplot.Canvas(width=800, height=400)
axes = canvas.cartesian(grid=(1, 2, 0), ylabel="Axis 1")
axes = axes.share("x", ylabel="Axis 2")
axes = canvas.cartesian(grid=(1, 2, 1), ylabel="Axis 3")
# Out:
# <div class="toyplot" id="ta4be1e8333de42c49845285614676b5c" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="400.0px" id="tc6e2a341662a4804889da53d3c9913df" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 800.0 400.0" width="800.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t9b61641d1d2b4acfae1dd4bfbdc37488"><clipPath id="ta343d408cc22428a961f43b0652321e9"><rect height="320.0" width="320.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#ta343d408cc22428a961f43b0652321e9)"></g><g class="toyplot-coordinates-Axis" id="tfaaddec3ea7f45ffadd73170d8858503" transform="translate(50.0,350.0)translate(0,10.0)"><line style="" x1="0" x2="300.0" y1="
# ...
