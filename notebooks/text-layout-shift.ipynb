# %%
import toyplot.font
import toyplot.text

# %%
text = "Test <small>me!</small>"
style = {
    "font-size": "16px",
    "-toyplot-text-layout-visibility": "visible",
    "-toyplot-text-layout-line-visibility": "visible",
    "-toyplot-text-layout-box-visibility": "visible",
}
fonts = toyplot.font.ReportlabLibrary()

# %%
canvas = toyplot.Canvas(width=300, height=150)
axes = canvas.cartesian()
mark = axes.text(0, 0, text, style=style)

layout = toyplot.text.layout(text, style, fonts)
toyplot.text.dump(layout)

print("\nextents:", mark.extents(["x", "y"])[1])
# Out:
# toyplot.text.Layout
#   bottom: 9.6
#   height: 19.2
#   left: -28.452800000000003
#   right: 28.452800000000003
#   style:
#     -toyplot-text-layout-box-visibility: visible
#     -toyplot-text-layout-line-visibility: visible
#     -toyplot-text-layout-visibility: visible
#     fill: #292724
#     font-family: helvetica
#     font-size: 16.0px
#     font-weight: normal
#     stroke: none
#     vertical-align: baseline
#     white-space: pre
#   top: -9.6
#   width: 56.90560000000001
#
#   toyplot.text.LineBox
#     baseline: 4.087999999999999
#     bottom: 9.6
#     height: 19.2
#     left: -28.452800000000003
#     right: 28.452800000000003
#     style:
#       -toyplot-text-layout-box-visibility: visible
#       -toyplot-text-layout-line-visibility: visible
#       -toyplot-text-layout-visibility: visible
#       fill: #292724
#       font-family: helvetica
#       font-size: 16.0px
#       font-weight: normal
#       stroke: none
#       vertical-align: baseline
# ...

# %%
style = {
    "font-size": "16px",
    "-toyplot-anchor-shift": "10px",
    "-toyplot-text-layout-visibility": "visible",
    "-toyplot-text-layout-line-visibility": "visible",
    "-toyplot-text-layout-box-visibility": "visible",
}

# %%
canvas = toyplot.Canvas(width=300, height=150)
axes = canvas.cartesian()
mark = axes.text(0, 0, text, style=style)

layout = toyplot.text.layout(text, style, fonts)
toyplot.text.dump(layout)

print("\nextents:", mark.extents(["x", "y"])[1])
# Out:
# toyplot.text.Layout
#   bottom: 9.6
#   height: 19.2
#   left: -18.452800000000003
#   right: 38.4528
#   style:
#     -toyplot-text-layout-box-visibility: visible
#     -toyplot-text-layout-line-visibility: visible
#     -toyplot-text-layout-visibility: visible
#     fill: #292724
#     font-family: helvetica
#     font-size: 16.0px
#     font-weight: normal
#     stroke: none
#     vertical-align: baseline
#     white-space: pre
#   top: -9.6
#   width: 56.90560000000001
#
#   toyplot.text.LineBox
#     baseline: 4.087999999999999
#     bottom: 9.6
#     height: 19.2
#     left: -18.452800000000003
#     right: 38.4528
#     style:
#       -toyplot-text-layout-box-visibility: visible
#       -toyplot-text-layout-line-visibility: visible
#       -toyplot-text-layout-visibility: visible
#       fill: #292724
#       font-family: helvetica
#       font-size: 16.0px
#       font-weight: normal
#       stroke: none
#       vertical-align: baseline
#       white-space: pre
# ...
