# %%
import numpy
x = numpy.arange(10)
y1 = numpy.random.normal(size=len(x))
y2 = numpy.random.normal(size=len(x))
y3 = numpy.random.normal(size=len(x))

# %%
import toyplot
canvas = toyplot.Canvas()
axes = canvas.axes()
axes.plot(x, y1)
axes.text(x[-1], y1[-1], "Label 1", angle=0, style={"text-anchor":"begin", "-toyplot-anchor-shift":"5px"})
axes.plot(x, y2)
axes.text(x[-1], y2[-1], "Label 2", angle=0, style={"text-anchor":"begin", "-toyplot-anchor-shift":"5px"})
axes.plot(x, y3)
axes.text(x[-1], y3[-1], "Label 3", angle=0, style={"text-anchor":"begin", "-toyplot-anchor-shift":"5px"})
# Out:
# <div align="center" class="toyplot" id="t717ebb079a7648a68cff7824446e9129"><svg height="600px" id="t6475014816244e319c035ef99276fdd4" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t7dc9f40ac0974941b1c3a2f4633b641e"><toyplot:axes>{"x": [{"domain": {"max": 9.0, "min": 0.0}, "range": {"max": 540, "min": 60}, "scale": "linear"}], "y": [{"domain": {"max": 2.1841215942539711, "min": -3.0}, "range": {"max": 540, "min": 60}, "scale": "linear"}]}</toyplot:axes><clipPath id="tef5a2703b42b4b35bf836b95dff43149"><rect height="500" width="500" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tef5a2703b42b4b35bf836b95dff43149)" style="cursor:crosshair"><rect height="500" style="pointer-events:all;visibility:hidden
# ...
