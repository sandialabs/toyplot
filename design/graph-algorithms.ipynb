# %%
import numpy
import toyplot.layout

# %% [markdown]
# **Shortest Paths**

# %%
toyplot.layout._floyd_warshall_shortest_path(2, numpy.array([[0, 1]]))
# Out:
# array([[  0.,   1.],
#        [ inf,   0.]])

# %%
toyplot.layout._floyd_warshall_shortest_path(3, numpy.array([[0, 1], [1, 2]]))
# Out:
# array([[  0.,   1.,   2.],
#        [ inf,   0.,   1.],
#        [ inf,  inf,   0.]])

# %%
toyplot.layout._floyd_warshall_shortest_path(3, numpy.array([[0, 1], [1, 2], [2, 0]]))
# Out:
# array([[ 0.,  1.,  2.],
#        [ 2.,  0.,  1.],
#        [ 1.,  2.,  0.]])

# %% [markdown]
# **Adjacency Lists**

# %%
edges = numpy.array([[0, 1]])
toyplot.graph(edges, width=200);
print toyplot.layout._adjacency_list(2, edges)
# Out:
# INFO:toyplot:Graph layout time: 61.3961219788 ms
# [[1], []]
# <div align="center" class="toyplot" id="t4fefcee387ba4fcfb1c9547460be9433"><svg height="200.0px" id="t027b1b37566d4175b37dd7ab9ce90c57" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 200.0 200.0" width="200.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tf26e50b35e0b417390859fd683928df6"><clipPath id="tcea3c71805f84ab3af5f272d10b4994b"><rect height="100.0" width="100.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tcea3c71805f84ab3af5f272d10b4994b)" style="cursor:crosshair"><rect height="100.0" style="pointer-events:all;visibility:hidden" width="100.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Graph" id="t0b5e14e7e9154e4e81e6de0580b0bad1"><g class="toyplot-Edges"><path d="M 60.0 126.522228571 L 140.0 73.4777714295" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="60.0" cy="126.52222857053314" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="140.0" cy="73.477771429466841" r="2.2360679774997898"></circle></g></g></g></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="50.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="95.0" y="67.0"></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   if(window.CSS !== undefined && window.CSS.supports !== undefined)
#   {
#     if(!window.CSS.supports("alignment-baseline", "middle"))
#     {
#       var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t4fefcee387ba4fcfb1c9547460be9433 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           if(match[1] == "middle")
#           {
#             var style = getComputedStyle(text[i]);
#             var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#             var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#             dy += 0.4 * font_size;
#             text[i].setAttribute("dy", dy);
#           }
#         }
#       }
#     }
#     if(!window.CSS.supports("baseline-shift", "0"))
#     {
#       var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t4fefcee387ba4fcfb1c9547460be9433 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           var style = getComputedStyle(text[i]);
#           var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#           var percent = 0.01 * match[1].substr(0, match[1].length-1);
#           var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#           dy -= percent * font_size
#           text[i].setAttribute("dy", dy);
#         }
#       }
#     }
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"tf26e50b35e0b417390859fd683928df6": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": -0.077171654649813265, "min": -0.66433396657817279}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 140.0, "min": 60.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.70104851071778107, "min": 0.11388619878942155}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 60.0, "min": 140.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coordinates[i].style.visibility = "hidden";
#   }
#
#   for(var axes_id in axes)
#   {
#     var event_target = document.querySelector("#" + axes_id + " .toyplot-coordinate-events");
#     event_target.onmousemove = display_coordinates;
#     event_target.onmouseout = clear_coordinates;
#   }
# })();
# </script></div></div>

# %%
edges = numpy.array([[0, 1], [1, 2]])
toyplot.graph(edges, width=200);
print toyplot.layout._adjacency_list(3, edges)
# Out:
# INFO:toyplot:Graph layout time: 42.6831245422 ms
# [[1], [2], []]
# <div align="center" class="toyplot" id="t2abf44bf8a33419093a89e3a5fedbd14"><svg height="200.0px" id="t629a0dd48a9f40c08f030fd55ef07ede" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 200.0 200.0" width="200.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tf72ae3e5ad004b7ea28bdd2dc295e49b"><clipPath id="t75b01e533bb74bcca1f116f981b03df1"><rect height="100.0" width="100.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t75b01e533bb74bcca1f116f981b03df1)" style="cursor:crosshair"><rect height="100.0" style="pointer-events:all;visibility:hidden" width="100.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Graph" id="t70c2682a76924d459258b29bd4e83711"><g class="toyplot-Edges"><path d="M 60.0 74.1707870496 L 99.9819674137 99.9883558122" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path><path d="M 99.9819674137 99.9883558122 L 140.0 125.82921295" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="60.0" cy="74.170787049609189" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="99.981967413721421" cy="99.988355812164485" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="140.0" cy="125.82921295039083" r="2.2360679774997898"></circle></g></g></g></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="50.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="95.0" y="67.0"></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   if(window.CSS !== undefined && window.CSS.supports !== undefined)
#   {
#     if(!window.CSS.supports("alignment-baseline", "middle"))
#     {
#       var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t2abf44bf8a33419093a89e3a5fedbd14 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           if(match[1] == "middle")
#           {
#             var style = getComputedStyle(text[i]);
#             var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#             var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#             dy += 0.4 * font_size;
#             text[i].setAttribute("dy", dy);
#           }
#         }
#       }
#     }
#     if(!window.CSS.supports("baseline-shift", "0"))
#     {
#       var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t2abf44bf8a33419093a89e3a5fedbd14 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           var style = getComputedStyle(text[i]);
#           var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#           var percent = 0.01 * match[1].substr(0, match[1].length-1);
#           var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#           dy -= percent * font_size
#           text[i].setAttribute("dy", dy);
#         }
#       }
#     }
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"tf72ae3e5ad004b7ea28bdd2dc295e49b": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.50591063962397842, "min": -0.60271794822530878}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 140.0, "min": 60.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.77387572958244077, "min": -0.33475285826684653}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 60.0, "min": 140.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coordinates[i].style.visibility = "hidden";
#   }
#
#   for(var axes_id in axes)
#   {
#     var event_target = document.querySelector("#" + axes_id + " .toyplot-coordinate-events");
#     event_target.onmousemove = display_coordinates;
#     event_target.onmouseout = clear_coordinates;
#   }
# })();
# </script></div></div>

# %%
edges = numpy.array([[0, 1], [1, 2], [0, 2]])
toyplot.graph(edges, width=200);
print toyplot.layout._adjacency_list(3, edges)
# Out:
# INFO:toyplot:Graph layout time: 40.3959751129 ms
# [[1, 2], [2], []]
# <div align="center" class="toyplot" id="t632d603ad5fc4fc2836bf3949e140423"><svg height="200.0px" id="te891d443fd6c4458ae69caff3d727f2e" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 200.0 200.0" width="200.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tad99c7b5b27a4c58b7b310ed9994100f"><clipPath id="t4287631687024d1ca0fc8e130f037d94"><rect height="100.0" width="100.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t4287631687024d1ca0fc8e130f037d94)" style="cursor:crosshair"><rect height="100.0" style="pointer-events:all;visibility:hidden" width="100.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Graph" id="t85459a43123841e59a297d0fb110b956"><g class="toyplot-Edges"><path d="M 62.2433549596 110.792855067 L 125.294129484 60.0" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path><path d="M 125.294129484 60.0 L 137.75664504 140.0" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path><path d="M 62.2433549596 110.792855067 L 137.75664504 140.0" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="62.243354959633955" cy="110.79285506651492" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="125.29412948441203" cy="60.0" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="137.75664504036604" cy="140.0" r="2.2360679774997898"></circle></g></g></g></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="50.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="95.0" y="67.0"></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   if(window.CSS !== undefined && window.CSS.supports !== undefined)
#   {
#     if(!window.CSS.supports("alignment-baseline", "middle"))
#     {
#       var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t632d603ad5fc4fc2836bf3949e140423 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           if(match[1] == "middle")
#           {
#             var style = getComputedStyle(text[i]);
#             var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#             var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#             dy += 0.4 * font_size;
#             text[i].setAttribute("dy", dy);
#           }
#         }
#       }
#     }
#     if(!window.CSS.supports("baseline-shift", "0"))
#     {
#       var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t632d603ad5fc4fc2836bf3949e140423 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           var style = getComputedStyle(text[i]);
#           var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#           var percent = 0.01 * match[1].substr(0, match[1].length-1);
#           var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#           dy -= percent * font_size
#           text[i].setAttribute("dy", dy);
#         }
#       }
#     }
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"tad99c7b5b27a4c58b7b310ed9994100f": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.26424974786779987, "min": -0.30798009488887529}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 140.0, "min": 60.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.34822004130811507, "min": -0.22400980144856}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 60.0, "min": 140.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coordinates[i].style.visibility = "hidden";
#   }
#
#   for(var axes_id in axes)
#   {
#     var event_target = document.querySelector("#" + axes_id + " .toyplot-coordinate-events");
#     e

# %% [markdown]
# **Tree Detection**

# %%
edges = numpy.array([[0, 1]])
toyplot.graph(edges, width=200);
print toyplot.layout._require_tree_root(toyplot.layout._adjacency_list(2, edges))
# Out:
# INFO:toyplot:Graph layout time: 42.9000854492 ms
# 0
# <div align="center" class="toyplot" id="t3facb129b1144f0aa2bf431fbdcc3981"><svg height="200.0px" id="ta62e27ffd6fd46cb8e67906e7b43fd27" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 200.0 200.0" width="200.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tebd1d7aeeda4473c940446a605af4f3f"><clipPath id="tdcb7ef64b94d4f2687afe16c4eced080"><rect height="100.0" width="100.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tdcb7ef64b94d4f2687afe16c4eced080)" style="cursor:crosshair"><rect height="100.0" style="pointer-events:all;visibility:hidden" width="100.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Graph" id="t56b81c9661a4430ca8dc82d0aaeb4cd8"><g class="toyplot-Edges"><path d="M 60.0 126.522228571 L 140.0 73.4777714295" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="60.0" cy="126.52222857053314" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="140.0" cy="73.477771429466841" r="2.2360679774997898"></circle></g></g></g></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="50.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="95.0" y="67.0"></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   if(window.CSS !== undefined && window.CSS.supports !== undefined)
#   {
#     if(!window.CSS.supports("alignment-baseline", "middle"))
#     {
#       var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t3facb129b1144f0aa2bf431fbdcc3981 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           if(match[1] == "middle")
#           {
#             var style = getComputedStyle(text[i]);
#             var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#             var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#             dy += 0.4 * font_size;
#             text[i].setAttribute("dy", dy);
#           }
#         }
#       }
#     }
#     if(!window.CSS.supports("baseline-shift", "0"))
#     {
#       var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t3facb129b1144f0aa2bf431fbdcc3981 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           var style = getComputedStyle(text[i]);
#           var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#           var percent = 0.01 * match[1].substr(0, match[1].length-1);
#           var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#           dy -= percent * font_size
#           text[i].setAttribute("dy", dy);
#         }
#       }
#     }
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"tebd1d7aeeda4473c940446a605af4f3f": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": -0.077171654649813265, "min": -0.66433396657817279}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 140.0, "min": 60.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.70104851071778107, "min": 0.11388619878942155}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 60.0, "min": 140.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coordinates[i].style.visibility = "hidden";
#   }
#
#   for(var axes_id in axes)
#   {
#     var event_target = document.querySelector("#" + axes_id + " .toyplot-coordinate-events");
#     event_target.onmousemove = display_coordinates;
#     event_target.onmouseout = clear_coordinates;
#   }
# })();
# </script></div></div>

# %%
edges = numpy.array([[0, 1], [0, 2]])
toyplot.graph(edges, width=200);
print toyplot.layout._require_tree_root(toyplot.layout._adjacency_list(3, edges))
# Out:
# INFO:toyplot:Graph layout time: 39.8399829865 ms
# 0
# <div align="center" class="toyplot" id="t63d9117421a74592914213803b9a925d"><svg height="200.0px" id="ta3aa21589c7a43b6800931f7f3b1b202" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 200.0 200.0" width="200.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t1dfa261161054079974db053f5927599"><clipPath id="t6ed194b362704f0187306dad7641d51e"><rect height="100.0" width="100.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t6ed194b362704f0187306dad7641d51e)" style="cursor:crosshair"><rect height="100.0" style="pointer-events:all;visibility:hidden" width="100.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Graph" id="tdc9111a29ca4450684ac3d57b62c1fca"><g class="toyplot-Edges"><path d="M 100.04591717 100.070891739 L 74.0909405051 60.0" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path><path d="M 100.04591717 100.070891739 L 125.909059495 140.0" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="100.04591716988132" cy="100.07089173869471" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="74.090940505144403" cy="60.0" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="125.9090594948556" cy="140.0" r="2.2360679774997898"></circle></g></g></g></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="50.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="95.0" y="67.0"></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   if(window.CSS !== undefined && window.CSS.supports !== undefined)
#   {
#     if(!window.CSS.supports("alignment-baseline", "middle"))
#     {
#       var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t63d9117421a74592914213803b9a925d text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           if(match[1] == "middle")
#           {
#             var style = getComputedStyle(text[i]);
#             var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#             var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#             dy += 0.4 * font_size;
#             text[i].setAttribute("dy", dy);
#           }
#         }
#       }
#     }
#     if(!window.CSS.supports("baseline-shift", "0"))
#     {
#       var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t63d9117421a74592914213803b9a925d text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           var style = getComputedStyle(text[i]);
#           var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#           var percent = 0.01 * match[1].substr(0, match[1].length-1);
#           var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#           dy -= percent * font_size
#           text[i].setAttribute("dy", dy);
#         }
#       }
#     }
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"t1dfa261161054079974db053f5927599": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.36850752058426328, "min": -0.74162597686835185}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 140.0, "min": 60.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.7295277453913388, "min": -0.38060575206127645}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 60.0, "min": 140.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coordinates[i].style.visibility = "hidden";
#   }
#
#   for(var axes_id in axes)
#   {
#     var event_target = document.querySelector("#" + axes_id + " .toyplot-coordinate-events");
#     event_target.onmousemove = display_coordinates;
#     event_target.onmouseout = clear_coordinates;
#   }
# })();
# </script></div></div>

# %%
edges = numpy.array([[0, 1], [1, 2], [2, 1]])
toyplot.graph(edges, width=200, layout=toyplot.layout.FruchtermanReingold(toyplot.layout.CurvedEdges()));
print toyplot.layout._require_tree_root(toyplot.layout._adjacency_list(3, edges))
# Out:
# INFO:toyplot:Graph layout time: 38.8309955597 ms
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-b4178dd6eb83> in <module>()
#       1 edges = numpy.array([[0, 1], [1, 2], [2, 1]])
#       2 toyplot.graph(edges, width=200, layout=toyplot.layout.FruchtermanReingold(toyplot.layout.CurvedEdges()));
# ----> 3 print toyplot.layout._require_tree_root(toyplot.layout._adjacency_list(3, edges))
#
# /Users/tshead/src/toyplot/toyplot/layout.pyc in _require_tree_root(targets)
#     254         for target in targets[vertex]:
#     255             mark_visited(target)
# --> 256     mark_visited(root)
#     257
#     258     return root
#
# /Users/tshead/src/toyplot/toyplot/layout.pyc in mark_visited(vertex)
#     253         visited[vertex] = True
#     254         for target in targets[vertex]:
# --> 255             mark_visited(target)
#     256     mark_visited(root)
#     257
#
# /Users/tshead/src/toyplot/toyplot/layout.pyc in mark_visited(vertex)
#     253         visited[vertex] = True
#     254         for target in targets[vertex]:
# --> 255             mark_visited(target)
#     256     mark_visited(root)
#     257
#
# /Users/tshead/src/toyplot/toyplot/layout.pyc in mark_visited(vertex)
#     253         visited[vertex] = True
#     254         for target in targets[vertex]:
# --> 255             mark_visited(target)
#     256     mark_visited(root)
#     257
#
# /Users/tshead/src/toyplot/toyplot/layout.pyc in mark_visited(vertex)
#     250     def mark_visited(vertex):
#     251         if visited[vertex]:
# --> 252             raise ValueError("Not a tree.")
#     253         visited[vertex] = True
#     254         for target in targets[vertex]:
#
# ValueError: Not a tree.
# <div align="center" class="toyplot" id="t1bcf612d6e8146d99a9783adf2be0dc4"><svg height="200.0px" id="t57b74284884146f2ae4481c508122e90" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 200.0 200.0" width="200.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tad6a5f163f8c427887ee583e3f005bc1"><clipPath id="te286748177424191b19ea17b2b14c9bf"><rect height="100.0" width="100.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#te286748177424191b19ea17b2b14c9bf)" style="cursor:crosshair"><rect height="100.0" style="pointer-events:all;visibility:hidden" width="100.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Graph" id="t3b3378d89df34cd493f30f9a75d87d96"><g class="toyplot-Edges"><path d="M 60.0 68.8426251956 Q 87.8883650836 79.6693332538 105.211656268 104.059538192" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path><path d="M 105.211656268 104.059538192 Q 126.670503626 112.390204939 140.0 131.157374804" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path><path d="M 140.0 131.157374804 Q 118.541152642 122.826708058 105.211656268 104.059538192" style="fill:none;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.0"></path></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="60.0" cy="68.842625195594891" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="105.21165626819437" cy="104.05953819249666" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0"><circle cx="140.0" cy="131.15737480440509" r="2.2360679774997898"></circle></g></g></g></g><g class="toyplot-coordinates" style="visibility:hidden"><rect height="14.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:0.75;stroke:none" width="90.0" x="50.0" y="60.0"></rect><text style="alignment-baseline:middle;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="95.0" y="67.0"></text></g></g></svg><div class="toyplot-controls"><ul class="toyplot-mark-popup" onmouseleave="this.style.visibility='hidden'" style="background:rgba(0%,0%,0%,0.75);border:0;border-radius:6px;color:white;cursor:default;list-style:none;margin:0;padding:5px;position:fixed;visibility:hidden"><li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0;"></li><li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0;">Save as .csv</li></ul><script>
# (function()
# {
#   if(window.CSS !== undefined && window.CSS.supports !== undefined)
#   {
#     if(!window.CSS.supports("alignment-baseline", "middle"))
#     {
#       var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t1bcf612d6e8146d99a9783adf2be0dc4 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           if(match[1] == "middle")
#           {
#             var style = getComputedStyle(text[i]);
#             var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#             var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#             dy += 0.4 * font_size;
#             text[i].setAttribute("dy", dy);
#           }
#         }
#       }
#     }
#     if(!window.CSS.supports("baseline-shift", "0"))
#     {
#       var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#       var text = document.querySelectorAll("#t1bcf612d6e8146d99a9783adf2be0dc4 text");
#       for(var i = 0; i != text.length; ++i)
#       {
#         var match = re.exec(text[i].attributes.style.value);
#         if(match)
#         {
#           var style = getComputedStyle(text[i]);
#           var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#           var percent = 0.01 * match[1].substr(0, match[1].length-1);
#           var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#           dy -= percent * font_size
#           text[i].setAttribute("dy", dy);
#         }
#       }
#     }
#   }
# })();
# </script><script>
# (function()
# {
#   var axes = {"tad6a5f163f8c427887ee583e3f005bc1": {"x": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.3958464584840225, "min": -0.53759104995317897}, "range": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 140.0, "min": 60.0}, "scale": "linear"}], "y": [{"domain": {"bounds": {"max": Infinity, "min": -Infinity}, "max": 0.72562201868660203, "min": -0.20781548975059957}, "range": {"bounds": {"max": -Infinity, "min": Infinity}, "max": 60.0, "min": 140.0}, "scale": "linear"}]}};
#
#   function sign(x)
#   {
#     return x < 0 ? -1 : x > 0 ? 1 : 0;
#   }
#
#   function _mix(a, b, amount)
#   {
#     return ((1.0 - amount) * a) + (amount * b);
#   }
#
#   function _log(x, base)
#   {
#     return Math.log(Math.abs(x)) / Math.log(base);
#   }
#
#   function _in_range(a, x, b)
#   {
#     var left = Math.min(a, b);
#     var right = Math.max(a, b);
#     return left <= x && x <= right;
#   }
#
#   function to_domain(projection, range)
#   {
#     for(var i = 0; i != projection.length; ++i)
#     {
#       var segment = projection[i];
#       if(_in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#       {
#         if(segment.scale == "linear")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           return _mix(segment.domain.min, segment.domain.max, amount)
#         }
#         else if(segment.scale[0] == "log")
#         {
#           var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#           var base = segment.scale[1];
#           return sign(segment.domain.min) * Math.pow(base, _mix(_log(segment.domain.min, base), _log(segment.domain.max, base), amount));
#         }
#       }
#     }
#   }
#
#   // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#   function d3_mousePoint(container, e)
#   {
#     if (e.changedTouches) e = e.changedTouches[0];
#     var svg = container.ownerSVGElement || container;
#     if (svg.createSVGPoint) {
#       var point = svg.createSVGPoint();
#       point.x = e.clientX, point.y = e.clientY;
#       point = point.matrixTransform(container.getScreenCTM().inverse());
#       return [point.x, point.y];
#     }
#     var rect = container.getBoundingClientRect();
#     return [e.clientX - rect.left - container.clientLeft, e.clientY - rect.top - container.clientTop];
#   };
#
#   function display_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var data = axes[dom_axes.id];
#
#     point = d3_mousePoint(e.target, e);
#     var x = Number(to_domain(data["x"], point[0])).toFixed(2);
#     var y = Number(to_domain(data["y"], point[1])).toFixed(2);
#
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#     {
#       coordinates[i].style.visibility = "visible";
#       coordinates[i].querySelector("text").textContent = "x=" + x + " y=" + y;
#     }
#   }
#
#   function clear_coordinates(e)
#   {
#     var dom_axes = e.currentTarget.parentElement;
#     var coordinates = dom_axes.querySelectorAll(".toyplot-coordinates");
#     for(var i = 0; i != coordinates.length; ++i)
#       coordinates[i].style.visibility = "hidden";
#   }
#
#   for(var axes_id in axes)
#   {
