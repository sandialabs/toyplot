# %% [markdown]
# ## Overview
#
# To facilitate graph analysis, we need to support sharing layouts between graphs, something I haven't seen done very well elsewhere.  In particular, it should be possible to:
#
# * Use a consistent layout for multiple graphs:
#     * &#x2713; Capture the layout of a graph $G_0$ that has been rendered, or
#     * &#x2713; Create a layout without rendering $G_0$.
#     * &#x2713; Render graph $G_1$ that has the same vertices as $G_0$, in the same order.
#     * Render graph $G_1$ that has the same vertices as $G_0$, in a different order.
#     * Render graph $G_1$ that has a subset of the vertices in $G_0$, in arbitrary order.
#     * Render graph $G_1$ that has a superset of the vertices in $G_0$, in arbitrary order.
#         * In this case the new vertices should be laid-out using the chosen layout algorithm, without disturbing the existing vertices.
# * &#x2713; "Pin" a few key vertices while letting the layout handle the remaining vertices.
# * &#x2713; An implicit requirement is the ability to perform a layout on some vertices while leaving others unchanged.

# %%
import numpy
import toyplot.color
import toyplot.generate

# %%
numpy.random.seed(1234)

# %%
# Random graph
#vertices = ["a", "b", "c", "d", "e", "f", "g", "h", "i", "j"]
#graph = numpy.random.choice(vertices, (40, 2))

graph = toyplot.generate.prufer_tree(numpy.random.choice(4, 12))

# Reingold tree
#graph = numpy.array([[0,1],[0,2],[1,3],[2,4],[2,5],[3,6],[4,7],[5,8],[5,9],[6,10],[7,11],[9,12],[10,13],[12,14]])

# %%
# %%time

colormap = toyplot.color.LinearMap(toyplot.color.Palette(["white", "yellow", "red"]))

layout = toyplot.layout.graph(graph, layout=toyplot.layout.FruchtermanReingold())

layout.vcoordinates[4:] = numpy.ma.masked

canvas = toyplot.Canvas(width=1000, height=500)
axes = canvas.axes(show=False)
axes.aspect = "expand-domain"
mark = axes.graph(
    graph,
    layout.vcoordinates,
    layout=toyplot.layout.Random(),
    #layout=toyplot.layout.Eades(),
    #layout=toyplot.layout.FruchtermanReingold(M=100),
    #layout=toyplot.layout.Buchheim(),
    #layout=toyplot.layout.GraphViz(),
    vcolor=colormap,
    vmarker="o",
    vstyle={"stroke":"black"},
    vsize=20,
    ecolor="black",
    eopacity=0.2,
);

vcoordinates = mark.vcoordinates.copy()
axes.text(vcoordinates.T[0], vcoordinates.T[1], mark.vid, color="black")
# Out:
# INFO:toyplot:Graph layout time: 67.6598548889 ms
# INFO:toyplot:Graph layout time: 0.257015228271 ms
# CPU times: user 77.1 ms, sys: 3.97 ms, total: 81.1 ms
# Wall time: 78.3 ms
# <div align="center" class="toyplot" id="ta1f34a8757594032ba81c7e657a13003"><svg height="500.0px" id="tab42833179b048368eee28d495f3d5a0" preserveAspectRatio="xMidyMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 1000.0 500.0" width="1000.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t90d0b7b2e68c4363b9548758be9379a1"><clipPath id="t903641acfe744aac8f8833e0b55e396c"><rect height="400.0" width="900.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t903641acfe744aac8f8833e0b55e396c)" style="cursor:crosshair"><rect height="400.0" style="pointer-events:all;visibility:hidden" width="900.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Graph" id="t2486a127337b47b588a044934349adb7"><g class="toyplot-Edges"><path d="M 484.855562947 65.8163265306 L 675.731189873 102.930918429" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 484.855562947 65.8163265306 L 438.336829104 246.985943024" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 584.883988769 227.389289682 L 567.111776131 165.645873954" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 480.927823588 209.948097917 L 584.883988769 227.389289682" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 459.782378458 345.225688805 L 443.253588397 223.856047924" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 459.782378458 345.225688805 L 495.781499728 434.183673469" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 459.782378458 345.225688805 L 602.450198277 100.353419084" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 480.927823588 209.948097917 L 459.782378458 345.225688805" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 484.855562947 65.8163265306 L 441.132116623 203.031827777" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 480.927823588 209.948097917 L 326.648916536 297.767509032" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 484.855562947 65.8163265306 L 665.845361019 189.207169812" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 480.927823588 209.948097917 L 484.855562947 65.8163265306" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path><path d="M 480.927823588 209.948097917 L 453.911551765 136.435053898" style="fill:none;stroke:rgb(0%,0%,0%);stroke-opacity:0.2;stroke-width:1.0"></path></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="459.78237845770553" cy="345.22568880498949" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,84.6%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="480.92782358829186" cy="209.94809791683633" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,69.2%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="584.88398876938379" cy="227.38928968152348" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,53.8%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="484.85556294732925" cy="65.816326530612272" r="10.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(100%,100%,38.5%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="675.73118987315218" cy="102.9 ...
