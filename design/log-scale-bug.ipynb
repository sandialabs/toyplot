# %%
import numpy
import toyplot

canvas, axes, mark = toyplot.bars(numpy.linspace(0, 10)**2, width=400)
axes.y.scale = "log"
# Out:
# <div align="center" class="toyplot" id="ta29bf3ec242f4a7d939c6442f002849c"><svg class="toyplot-canvas-Canvas" height="400.0px" id="tf74d69db7194421b817d9a03f653da1a" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 400.0 400.0" width="400.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tf88fd85bb9774ce2ba593f3d8e51c6d6"><clipPath id="t89210aee49ae4c43ab40ab4554b5b413"><rect height="320.0" width="320.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t89210aee49ae4c43ab40ab4554b5b413)"><rect height="320.0" style="pointer-events:all;visibility:hidden" width="320.0" x="40.0" y="40.0"></rect><g class="toyplot-mark-BarMagnitudes" id="t6f6a4e058a384ab5a1b67b20ad581550" style="stroke:rgb(100%,100%,100%);stroke-opaci
# ...

# %%
import numpy
import toyplot

canvas, axes, mark = toyplot.bars(numpy.linspace(0, 10)**2, width=400)
axes.y.scale = "log"
axes.y.domain.min = 10
# Out:
# <div align="center" class="toyplot" id="tfcf03aa0141d481787878a3b9c0a18e5"><svg class="toyplot-canvas-Canvas" height="400.0px" id="tca4bb0f6d9f945e3a8c5e9d802a73d48" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 400.0 400.0" width="400.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t54a8907af432432ca92607e487a71c2a"><clipPath id="t5870bd4a6ecd41e3b181b89fe4a6785a"><rect height="320.0" width="320.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t5870bd4a6ecd41e3b181b89fe4a6785a)"><rect height="320.0" style="pointer-events:all;visibility:hidden" width="320.0" x="40.0" y="40.0"></rect><g class="toyplot-mark-BarMagnitudes" id="tc515d9bf28664ec491ddb4c5733378e2" style="stroke:rgb(100%,100%,100%);stroke-opaci
# ...

# %%
for segment in axes._y_projection._segments:
    print "scale:", segment.scale
    print "  domain:", segment.domain.bounds.min, segment.domain.min, segment.domain.max, segment.domain.bounds.max
    print "  range:", segment.range.bounds.min, segment.range.min, segment.range.max, segment.range.bounds.max
# Out:
# scale: linear
#   domain: -inf -80.0 10.0 10.0
#   range: -inf 650.0 350.0 350.0
# scale: ('log', 10)
#   domain: 10.0 10.0 100.0 inf
#   range: 350.0 350.0 50.0 inf
