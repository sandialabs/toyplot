# %%
import numpy
numpy.random.seed(1234)

import toyplot

# %%
mean = numpy.array([0, 0])
cov = numpy.array([[1, 0], [0, 1]])
samples = numpy.random.multivariate_normal(mean=mean, cov=cov, size=1000)

print(samples)

sigx = cov[0, 0]
sigy = cov[1, 1]

p = 0.95
s = -2 * numpy.log(1 - p)
print(s)

print(numpy.sqrt(numpy.square(samples[:,0]) + numpy.square(samples[:,1])))

canvas = toyplot.Canvas()
#axes = canvas.cartesian(xmin=-3, xmax=3, ymin=-3, ymax=3)
axes = canvas.cartesian()

axes.scatterplot(samples[:,0], samples[:,1]);
axes.ellipse(0, 0, sigx * numpy.sqrt(s), sigy * numpy.sqrt(s), 0, style={"stroke":"black", "fill":"none"})
#axes.ellipse(0, 0, cov[0, 0] * 2, cov[1, 1] * 2, 0, style={"stroke":"black", "fill":"none"})
#axes.ellipse(0, 0, cov[0, 0] * 3, cov[1, 1] * 3, 0, style={"stroke":"black", "fill":"none"})
# Out:
# [[ 1.17793856 -0.72564414]
#  [-1.12327154 -0.65861138]
#  [ 0.01074601 -0.37454705]
#  ...
#  [ 0.38330118  0.6488659 ]
#  [ 1.19142361 -1.02485607]
#  [ 0.13352304 -0.42341418]]
# 5.99146454710798
# [1.38350955 1.3021167  0.37470117 2.85028713 0.98652736 0.69637028
#  0.95454061 1.36691    1.8885509  0.99076557 0.78924062 1.60871152
#  1.30704589 1.22919959 1.43695275 0.47735267 1.72660692 1.35087403
#  1.08900051 2.48223925 0.72105074 0.1243563  2.27308157 0.45820871
#  0.11857349 0.86002723 1.72071683 2.59477097 1.23217834 1.06759861
#  0.42978351 1.74057    0.85238101 0.64867648 1.82811413 1.76358845
#  0.61328933 2.30458228 1.70826619 0.79705378 1.07535384 1.76582349
#  1.54548854 2.36628747 0.27451098 0.43290446 0.37587115 0.94764189
#  1.00497297 2.34722538 0.51534033 1.04977483 2.36886806 1.2305888
#  0.72275653 1.91828861 0.43599107 2.86943557 2.47352653 1.77424866
#  1.1923031  1.23556916 1.63431733 1.40093579 1.6846057  1.87898019
# ...
