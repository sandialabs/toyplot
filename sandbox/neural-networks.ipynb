# %% [markdown]
# **Mark / Label Use Cases**
#
# * <strike>Default mark alignment is zero.</strike>
# * <strike>Edge marks orient with edges by default.</strike>
# * <strike>Edge marks can optionally be oriented absolutely.</strike>
# * Edge marks can optionally be oriented relative to their edge-aligned orientation.
# * Mark labels can optionally be oriented absolutely.
# * Mark labels can optionally be oriented relative to their mark alignment.

# %%
import numpy
import toyplot.color
import toyplot.generate
import toyplot.mark

# %%
edges = numpy.array([
    ["x0", "a0"],
    ["x0", "a1"],
    ["x0", "a2"],
    ["x0", "a3"],
    ["x1", "a0"],
    ["x1", "a1"],
    ["x1", "a2"],
    ["x1", "a3"],
    ["x2", "a0"],
    ["x2", "a1"],
    ["x2", "a2"],
    ["x2", "a3"],
    ["a0", "y0"],
    ["a0", "y1"],
    ["a1", "y0"],
    ["a1", "y1"],
    ["a2", "y0"],
    ["a2", "y1"],
    ["a3", "y0"],
    ["a3", "y1"],
])

vcoordinates = numpy.ma.masked_all((9, 2))
vcoordinates[0] = (0, 1)
vcoordinates[1] = (1, 1)
vcoordinates[2] = (2, 1)
vcoordinates[3] = (3, 1)
vcoordinates[4] = (0, 2)
vcoordinates[5] = (1, 2)
vcoordinates[6] = (2, 2)
vcoordinates[7] = (0, 0)
vcoordinates[8] = (1, 0)

vcoordinates[7:9, 0] += 1.0
vcoordinates[4:7, 0] += 0.5

canvas = toyplot.Canvas(width=500, height=500)

axes = canvas.cartesian(show=False, padding=50)
#axes.aspect = "fit-range"
mark = axes.graph(
    edges,
    ecolor="black",
    eopacity=1,
    estyle={"stroke-width":1},
    hmarker=toyplot.marker.create("s", angle="r90", label="A", mstyle={"fill":"white"}, size=20),
    mmarker=toyplot.marker.create("s", angle="0", label="0.2", mstyle={"fill":"white"}, lstyle={"font-size":"12px"}, size=30),
    #mposition=numpy.random.choice([0.3, 0.4, 0.5, 0.6, 0.7], replace=True, size=20),
    tmarker=toyplot.marker.create(">", angle=None, mstyle={"stroke-width":1}, lstyle={"font-size":"10px"}, size=20),
    vcoordinates=vcoordinates,
    vcolor="white",
    vstyle={"stroke":toyplot.color.near_black},
    vlshow=False,
    vsize=50,
    vmarker=toyplot.marker.create("o", label="0.3", lstyle={"font-size":"18px"}),
)
#mark = axes.rects(-0.125, 0.8 + 0.125, 1 - 0.125, 1 + 0.125, color="rgba(0, 0, 0, 0.2)")
# Out:
# <div class="toyplot" id="t81731a162874414a92942c93184f8d99" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="500.0px" id="td3bbde0f5a7642acbb28780846f0a0ab" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 500.0 500.0" width="500.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="td18fd4355ee64787a43e42aaafcbc9f3"><clipPath id="t759d56b8a9c04ce1b61b20fac7afe259"><rect height="500.0" width="500.0" x="0.0" y="0.0"></rect></clipPath><g clip-path="url(#t759d56b8a9c04ce1b61b20fac7afe259)"><g class="toyplot-mark-Graph" id="t029d2fa25919410cb46088a5ac940c50"><g class="toyplot-Edges"><path d="M 108.760972516 73.7170824513 L 57.9056941504 226.282917549" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:1"></path><path d="M 124.572360817 73.7170824513 L 175.427639183 226.282917549" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:1"></path><path d="M 134.344336196 67.6776695297 L 298.988997137 232.32233047" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:1"></path><path d="M 138.103989809 62.8623938857 L 428.562676857 237.137606114" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:1"></path><path d="M 232.32233047 67.6776695297 L 67.6776695297 232.32233047" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:1"></path><path d="M 242.09430585 73.7170824513 L 191.239027484 226.282917549" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:1"></path><path d="M 257.90569415 73.7170824513 L 308.760972516 226.282917549" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:1"></path><path d="M 267.67766953 67.6776695297 L 432.32233047 232.32233047" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:1"></path><path d="M 361.896010191 62.8623938857 L 71.4373231428 237.137606114" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:1"></path><path d="M 365.655663804 67.6776695297 L 201.011002863 232.32233047" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:1"></path><path d="M 375.427639183 73.7170824513 L 324.572360817 226.282917549" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:1"></path><path d="M 391.239027484 73.7170824513 L 442.09430585 226.282917549" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:1"></path><path d="M 63.8675049056 270.801257358 L 169.465828428 429.198742642" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:1"></path><path d="M 70.0 265.0 L 296.666666667 435.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:1"></path><path d="M 183.333333333 275.0 L 183.333333333 425.0" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:1"></path><path d="M 197.200838239 270.801257358 L 302.799161761 429.198742642" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:1"></path><path d="M 302.799161761 270.801257358 L 197.200838239 429.198742642" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:1"></path><path d="M 316.666666667 275.0 L 3 ...

# %%
import toyplot.pdf
toyplot.pdf.render(canvas, "test.pdf")

# %%
edges = numpy.array([
    ["a", "b"],
    ["b", "c"],
])

vcoordinates = numpy.array([
    [0, 0],
    [0, -1],
    [0, -2],
])

canvas = toyplot.Canvas(width=500, height=300)
axes = canvas.cartesian(show=False, padding=50)
axes.aspect = "fit-range"
mark = axes.graph(
    edges,
    ecolor="black",
    tmarker=toyplot.marker.create(">", size=10),
    vcoordinates=vcoordinates,
    vlshow=False,
    vmarker=toyplot.marker.create("r2x1", label="Convolutional<br/>5&#215;5", angle=0, lstyle={"font-size":"12px"}, size=50),
    vstyle={"stroke":"black", "fill":"white"},
)

#axes.scatterplot(vcoordinates[:,0], vcoordinates[:,1], color="red")
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /Users/tshead/miniconda/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# /Users/tshead/src/toyplot/toyplot/canvas.pyc in _repr_html_(self)
#     145     def _repr_html_(self):
#     146         from . import html
# --> 147         return toyplot.html.tostring(self, style={"text-align":"center"})
#     148
#     149     def _repr_png_(self):
#
# /Users/tshead/src/toyplot/toyplot/html.py in tostring(canvas, style)
#     304     <body> etc. if the result is intended as a standalone HTML document.
#     305     """
# --> 306     return toyplot.compatibility.unicode_type(xml.tostring(render(canvas=canvas, style=style), encoding="utf-8", method="html"), encoding="utf-8")
#     307
#     308
#
# /Users/tshead/src/toyplot/toyplot/html.py in render(canvas, fobj, animation, style)
#     264
#     265     # Render the canvas.
# --> 266     _render(canvas, context.copy(parent=root_xml)) # pylint: disable=no-value-for-parameter
#     267
#     268     # Return / write the results.
#
# /Users/tshead/miniconda/lib/python2.7/site-packages/multipledispatch/dispatcher.pyc in __call__(self, *args, **kwargs)
#     162             self._cache[types] = func
#     163         try:
# --> 164             return func(*args, **kwargs)
#     165
#     166         except MDNotImplementedError:
#
# /Users/tshead/src/toyplot/toyplot/html.py in _render(canvas, context)
#     713     # Render everything on the canvas.
#     714     for child in canvas._children:
# --> 715         _render(canvas, child._finalize(), context.copy(parent=svg_xml))
#     716
#     717     # Create a container for any Javascript code.
#
# /Users/tshead/miniconda/lib/python2.7/site-packages/multipledispatch/dispatcher.pyc in __call__(self, *args, **kwargs)
#     162             self._cache[types] = func
#     163         try:
# --> 164             return func(*args, **kwargs)
#     165
#     166         except MDNotImplementedError:
#
# /Users/tshead/src/toyplot/toyplot/html.py in _render(canvas, axes, context)
#    1770
#    1771     for child in axes._children:
# -> 1772         _render(axes, child._finalize(), context.copy(parent=children_xml))
#    1773
#    1774     if axes._show:
#
# /Users/tshead/miniconda/lib/python2.7/site-packages/multipledispatch/dispatcher.pyc in __call__(self, *args, **kwargs)
#     162             self._cache[types] = func
#     163         try:
# --> 164             return func(*args, **kwargs)
#     165
#     166         except MDNotImplementedError:
#
# /Users/tshead/src/toyplot/toyplot/html.py in _render(axes, mark, context)
#    2565
#    2566             # Create the marker with defaults.
# -> 2567             marker = toyplot.marker.create(size=10, angle=angle, mstyle=estyle, lstyle={}) + toyplot.marker.convert(marker)
#    2568
#    2569             _draw_marker(
#
# UnboundLocalError: local variable 'angle' referenced before assignment

# %%
toyplot.pdf.render(canvas, "test.pdf")
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-5-b0d69e0f37bb> in <module>()
# ----> 1 toyplot.pdf.render(canvas, "test.pdf")
#
# /Users/tshead/src/toyplot/toyplot/pdf.pyc in render(canvas, fobj, width, height, scale)
#      56     """
#      57     canvas = toyplot.require.instance(canvas, toyplot.canvas.Canvas)
# ---> 58     return implementation.render(canvas, fobj, width, height, scale)
#
# /Users/tshead/src/toyplot/toyplot/reportlab/pdf.pyc in render(canvas, fobj, width, height, scale)
#      54     """
#      55     canvas = toyplot.require.instance(canvas, toyplot.canvas.Canvas)
# ---> 56     svg = toyplot.svg.render(canvas)
#      57     scale = canvas._point_scale(width=width, height=height, scale=scale)
#      58     if fobj is None:
#
# /Users/tshead/src/toyplot/toyplot/svg.pyc in render(canvas, fobj, animation)
#      48
#      49     canvas = toyplot.require.instance(canvas, toyplot.canvas.Canvas)
# ---> 50     html, html_animation = toyplot.html.render(canvas, animation=True)
#      51     svg = html.find("svg")
#      52
#
# /Users/tshead/src/toyplot/toyplot/html.py in render(canvas, fobj, animation, style)
#     264
#     265     # Render the canvas.
# --> 266     _render(canvas, context.copy(parent=root_xml)) # pylint: disable=no-value-for-parameter
#     267
#     268     # Return / write the results.
#
# /Users/tshead/miniconda/lib/python2.7/site-packages/multipledispatch/dispatcher.pyc in __call__(self, *args, **kwargs)
#     162             self._cache[types] = func
#     163         try:
# --> 164             return func(*args, **kwargs)
#     165
#     166         except MDNotImplementedError:
#
# /Users/tshead/src/toyplot/toyplot/html.py in _render(canvas, context)
#     713     # Render everything on the canvas.
#     714     for child in canvas._children:
# --> 715         _render(canvas, child._finalize(), context.copy(parent=svg_xml))
#     716
#     717     # Create a container for any Javascript code.
#
# /Users/tshead/miniconda/lib/python2.7/site-packages/multipledispatch/dispatcher.pyc in __call__(self, *args, **kwargs)
#     162             self._cache[types] = func
#     163         try:
# --> 164             return func(*args, **kwargs)
#     165
#     166         except MDNotImplementedError:
#
# /Users/tshead/src/toyplot/toyplot/html.py in _render(canvas, axes, context)
#    1770
#    1771     for child in axes._children:
# -> 1772         _render(axes, child._finalize(), context.copy(parent=children_xml))
#    1773
#    1774     if axes._show:
#
# /Users/tshead/miniconda/lib/python2.7/site-packages/multipledispatch/dispatcher.pyc in __call__(self, *args, **kwargs)
#     162             self._cache[types] = func
#     163         try:
# --> 164             return func(*args, **kwargs)
#     165
#     166         except MDNotImplementedError:
#
# /Users/tshead/src/toyplot/toyplot/html.py in _render(axes, mark, context)
#    2565
#    2566             # Create the marker with defaults.
# -> 2567             marker = toyplot.marker.create(size=10, angle=angle, mstyle=estyle, lstyle={}) + toyplot.marker.convert(marker)
#    2568
#    2569             _draw_marker(
#
# UnboundLocalError: local variable 'angle' referenced before assignment
