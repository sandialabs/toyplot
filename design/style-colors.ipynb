# %%
import numpy as np
import toyplot

import logging
logging.basicConfig()

## generate histogram data
dat = np.random.normal(0, 1, 1000)
m, x = np.histogram(dat, bins=20)

## set up plot
c = toyplot.Canvas(width=300, height=300)
a = c.axes()

# raises an error
color = toyplot.color.Palette()[1]
heights = np.column_stack([[140 for i in m], m])
a.bars(x[:-1], heights, 
       color=['white', color],
       baseline="stacked",
       style={"stroke": color},  ## <--- doesn't like color as matrix
      )
# Out:
# WARNING:toyplot:toyplot.canvas.Canvas.axes() is deprecated, use toyplot.canvas.Canvas.cartesian() instead.
# <div align="center" class="toyplot" id="t8731187cf34a4637810f7bc857799cc8"><svg class="toyplot-canvas-Canvas" height="300.0px" id="tdee1317f81c742a9b308eca12246ef46" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 300.0 300.0" width="300.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t6cd90bdd202e40dcb17f80a5a70b713e"><clipPath id="td49d4d313f924a5aaa9216fb88f6e624"><rect height="220.0" width="220.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#td49d4d313f924a5aaa9216fb88f6e624)"><g class="toyplot-mark-BarMagnitudes" id="t34e08a190b5a4928be7d310052d3769a" style="stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0;stroke-width:1.0"><g class="toyplot-Series"><rect class="toyplot-Datum" height="93.333333333333314" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0;stroke-width:1.0" width="9.1824934419089033" x="66.350131161821821" y="156.66666666666669"></rect><rect class="toyplot-Datum" height="93.333333333333314" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0;stroke-width:1.0" width="9.1824934419089033" x="75.532624603730724" y="156.66666666666669"></rect><rect class="toyplot-Datum" height="93.333333333333314" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0;stroke-width:1.0" width="9.1824934419089175" x="84.715118045639628" y="156.66666666666669"></rect><rect class="toyplot-Datum" height="93.333333333333314" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0;stroke-width:1.0" width="9.1824934419088891" x="93.897611487548545" y="156.66666666666669"></rect><rect class="toyplot-Datum" height="93.333333333333314" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0;stroke-width:1.0" width="9.1824934419089175" x="103.08010492945743" y="156.66666666666669"></rect><rect class="toyplot-Datum" height="93.333333333333314" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0;stroke-width:1.0" width="9.1824934419089175" x="112.26259837136635" y="156.66666666666669"></rect><rect class="toyplot-Datum" height="93.333333333333314" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0;stroke-width:1.0" width="9.1824934419089175" x="121.44509181327527" y="156.66666666666669"></rect><rect class="toyplot-Datum" height="93.333333333333314" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0;stroke-width:1.0" width="9.1824934419089175" x="130.62758525518419" y="156.66666666666669"></rect><rect class="toyplot-Datum" height="93.333333333333314" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0;stroke-width:1.0" width="9.1824934419088891" x="139.8100786970931" y="156.66666666666669"></rect><rect class="toyplot-Datum" height="93.333333333333314" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0;stroke-width:1.0" width="9.1824934419089175" x="148.99257213900199" y="156.66666666666669"></rect><rect class="toyplot-Datum" height="93.333333333333314" style="fill:rgb(100%,100%,100%);fill-opacity:1.0;opacity:1.0;stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0;stroke-width:1.0" width="9.1824934419088891" x="158.17506558091091" y="156.66666666666669"></rect><rect class="toyplot-Datum" height="93.333333333333314" style="fill:rgb(100%,100%,100%);fill-opacity ...
