# %% [markdown]
# # Overview
#
# We need to refine the way users specify colors, to simplify the public API and eliminate inconsistencies.  The challenge is to handle all of the ways in which a user might want to specify per-series / per-datum colors, while avoiding potential ambiguities.
#
# **Use-cases**
#
# * Specify one explicit color for everything.
#         toyplot.plot(x, y, color="red")
# * Specify an explicit color per series.
#         toyplot.plot(x, y, color=["red", "cinnamon", "cardinal"])
# * Specify a palette for the series.
#         toyplot.plot(x, y, color=toyplot.color.brewer("reds"))
# * Specify a colormap for the series.
#         toyplot.plot(x, y, color=toyplot.color.LinearMap(toyplot.color.Palette(["red", "green", "blue"])))
# * Specify per-datum scalar values and have them mapped.
#         toyplot.plot(x, y, color=temperature)
# * Specify per-datum scalar values and have them mapped, but override a few "special" values.
#         colors = toyplot.color.broadcast(temperature)
#         colors[numpy.argsort(temperature)[0]] = "blue"
#         colors[numpy.argsort(temperature)[-1]] = "red"
#         toyplot.plot(x, y, color=colors)
# * Specify explicit per-datum color values for everything (i.e. map them yourself).
#         toyplot.plot(x, y, color=mycolors)
#
# **API**
#
# * (values) - map the values with the default colormap.
# * (colormap) - Use the given colormap to map series $[0, N)$.
#     * What if there's only one series?  Users may expect it to map the datums.
# * (palette) - Use the palette with a linear colormap to map series $[0, N)$.
#     * What if there's only one series?  Users may expect it to map the datums.
# * (values, colormap) - map values with the given colormap.
# * (values, palette) - map values with a linear colormap and the given palette.
#
# toyplot.color.broadcast(...) always returns an $M \times N \times 4$ array, even if $M$ and $N$ are 1?
#
# **Values**
#
# * "value" - a single CSS color value.
# * (r, g, b) - a single RGB color value.
# * (r, g, b, a) - a single RGBA color value.
# * [value1, value2, ...] - 1D heterogeneous collection of CSS and tuple color values.
#     * We don't allow scalar values in this case, because their domain would be ambiguous.
#     * Have to be careful with the implementation here - we don't want a list of nothing-but-tuples to be misinterpreted as a 2D numpy array of scalars.
# * numpy numeric array with shape $M$ - 1D collection of scalar values for mapping.
# * numpy numeric array with shape $M \times N$ - 2D collection of scalar values for mapping.
# * numpy string array with shape $M$ - 1D collection of CSS color values.
# * numpy string array with shape $M \times N$ - 2D collection of CSS color values.
# * numpy object array with shape $M$ - 1D collection of heterogeneous CSS and tuple color values.
#     * We don't allow scalar values in this case, because their domain would be ambiguous.
# * numpy object array with shape $M \times N$ - 2D collection of heterogeneous CSS and tuple color values.
#     * We don't allow scalar values in this case, because their domain would be ambiguous.
# * numpy numeric array with shape $M \times N \times 3$ - 2D collection of RGB colors.
# * numpy numeric array with shape $M \times N \times 4$ - 2D collection of RGBA colors.

# %%
import numpy
x = numpy.linspace(0, 1)
y = numpy.column_stack((x ** 2, x ** 3))
temperature = numpy.random.uniform(size=y.shape)

# %%
import toyplot

# %%
toyplot.scatterplot(x, y, width=300);
# Out:
# <div align="center" class="toyplot" id="tbad8d2e1dbd44e0cbd66b3802b15502b"><svg height="300.0px" id="t7bbebaa625ca46a7a56d31f4f4b680b9" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="300.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t33f8ceca279e4def91185f8f6b967bd0"><clipPath id="t8b0124d0817d485a87e987e2d85f9590"><rect height="200.0" width="200.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#
r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(100%,0%,0%,1);opacity:1.0;stroke:rgba(100%,0%,0%,1)"><circle cx="100.40816326530611" cy="230.92877967513536" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(100%,0%,0%,1);opacity:1.0;stroke:rgba(100%,0%,0%,1)"><circle cx="104.08163265306122" cy="229.20449812578093" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(100%,0%,0%,1);opacity:1.0;stroke:rgba(100%,0%,0%,1)"><circle cx="107.75510204081633" cy="227.33027905039569" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(100%,0%,0%,1);opacity:1.0;stroke:rgba(100%,0%,0%,1)"><circle cx="111.42857142857143" cy="225.30612244897958" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(100%,0%,0%,1);opacity:1.0;stroke:rgba(100%,0%,0%,1)"><circle cx="115.10204081632654" cy="223.13202832153269" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(100%,0%,0%,1);opacity:1.0;stroke:rgba(100%,0%,0%,1)"><circle cx="11 ...

# %%
toyplot.scatterplot(x, y, fill=temperature, width=300);
# Out:
# <div align="center" class="toyplot" id="t1b09d121add847a2b55caf4b64b10424"><svg height="300.0px" id="tdfa99e7b7e634c749a4f58b108c16d41" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="300.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t12a22072d6fe47a58a7b4821854363c6"><clipPath id="tf1be6eb39d794fc8a5410e0eeca991c2"><rect height="200.0" width="200.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tf1be6eb39d794fc8a5410e0eeca991c2)" style="cursor:crosshair"><rect height="200.0" style="pointer-events:all;visibility:hidden" width="200.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Plot" id="ta7c9aef5499c47d18a423a19bb86e3b2" style="stroke:none"><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgba(80.1%,92.2%,77.3%,1);opacity:1.0;stroke:rgba(80.1%,92.2%,77.3%,1)"><circle cx="60.0" cy="240.0" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(65.9%,86.7%,71%,1);opacity:1.0;stroke:rgba(65.9%,86.7%,71%,1)"><circle cx="63.673469387755105" cy="239.92503123698458" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(10.9%,48.8%,71.5%,1);opacity:1.0;stroke:rgba(10.9%,48.8%,71.5%,1)"><circle cx="67.346938775510196" cy="239.70012494793838" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(7.35%,45.1%,69.6%,1);opacity:1.0;stroke:rgba(7.35%,45.1%,69.6%,1)"><circle cx="71.020408163265316" cy="239.32528113286131" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(84.8%,94.1%,82.6%,1);opacity:1.0;stroke:rgba(84.8%,94.1%,82.6%,1)"><circle cx="74.693877551020407" cy="238.80049979175345" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(39.3%,75.1%,79.8%,1);opacity:1.0;stroke:rgba(39.3%,75.1%,79.8%,1)"><circle cx="78.367346938775512" cy="238.12578092461476" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(71.1%,88.7%,73.3%,1);opacity:1.0;stroke:rgba(71.1%,88.7%,73.3%,1)"><circle cx="82.040816326530617" cy="237.30112453144525" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(9.64%,47.5%,70.8%,1);opacity:1.0;stroke:rgba(9.64%,47.5%,70.8%,1)"><circle cx="85.714285714285722" cy="236.32653061224491" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(69.2%,87.9%,72.4%,1);opacity:1.0;stroke:rgba(69.2%,87.9%,72.4%,1)"><circle cx="89.387755102040813" cy="235.20199916701375" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(29.2%,68.7%,81.9%,1);opacity:1.0;stroke:rgba(29.2%,68.7%,81.9%,1)"><circle cx="93.061224489795919" cy="233.92753019575176" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(67.2%,87.2%,71.6%,1);opacity:1.0;stroke:rgba(67.2%,87.2%,71.6%,1)"><circle cx="96.734693877551024" cy="232.50312369845898" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(12.6%,50.5%,72.3%,1);opacity:1.0;stroke:rgba(12.6%,50.5%,72.3%,1)"><circle cx="100.40816326530611" cy="230.92877967513536" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(47.1%,79.4%,77.3%,1);opacity:1.0;stroke:rgba(47.1%,79.4%,77.3%,1)"><circle cx="104.08163265306122" cy="229.20449812578093" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(23.3%,62.1%,78.4%,1);opacity:1.0;stroke:rgba(23.3%,62.1%,78.4%,1)"><circle cx="107.75510204081633" cy="227.33027905039569" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(17.7%,55.8%,75%,1);opacity:1.0;stroke:rgba(17.7%,55.8%,75%,1)"><circle cx="111.42857142857143" cy="225.30612244897958" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(94.7%,98%,92.1%,1);opacity:1.0;stroke:rgba(94.7%,98% ...

# %%
toyplot.scatterplot(x, y, fill=temperature, fill_palette=toyplot.color.brewer("BlueRed"), width=300);
# Out:
# <div align="center" class="toyplot" id="tfece55e544ca47479872a231be32a642"><svg height="300.0px" id="t2f228b1e1d7d447ea9ef747a5fe250bb" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="300.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t91a80dbace5441f2826956e267446b71"><clipPath id="t9b147ca1ddbf414fb466a9dcab84664a"><rect height="200.0" width="200.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t9b147ca1ddbf414fb466a9dcab84664a)" style="cursor:crosshair"><rect height="200.0" style="pointer-events:all;visibility:hidden" width="200.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Plot" id="tbd67b8e1a6b34ab68e46cbad138cf96d" style="stroke:none"><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgba(89.7%,50.8%,40.3%,1);opacity:1.0;stroke:rgba(89.7%,50.8%,40.3%,1)"><circle cx="60.0" cy="240.0" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(98.3%,80.5%,71.2%,1);opacity:1.0;stroke:rgba(98.3%,80.5%,71.2%,1)"><circle cx="63.673469387755105" cy="239.92503123698458" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(25.7%,56.9%,76.1%,1);opacity:1.0;stroke:rgba(25.7%,56.9%,76.1%,1)"><circle cx="67.346938775510196" cy="239.70012494793838" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(21.4%,51.2%,73.2%,1);opacity:1.0;stroke:rgba(21.4%,51.2%,73.2%,1)"><circle cx="71.020408163265316" cy="239.32528113286131" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(80.1%,30%,26.6%,1);opacity:1.0;stroke:rgba(80.1%,30%,26.6%,1)"><circle cx="74.693877551020407" cy="238.80049979175345" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(87.5%,92.4%,95.1%,1);opacity:1.0;stroke:rgba(87.5%,92.4%,95.1%,1)"><circle cx="78.367346938775512" cy="238.12578092461476" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(96.7%,70.7%,58.7%,1);opacity:1.0;stroke:rgba(96.7%,70.7%,58.7%,1)"><circle cx="82.040816326530617" cy="237.30112453144525" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(24.2%,54.9%,75%,1);opacity:1.0;stroke:rgba(24.2%,54.9%,75%,1)"><circle cx="85.714285714285722" cy="236.32653061224491" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(97.3%,74.4%,63.4%,1);opacity:1.0;stroke:rgba(97.3%,74.4%,63.4%,1)"><circle cx="89.387755102040813" cy="235.20199916701375" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(72.7%,85.1%,91.5%,1);opacity:1.0;stroke:rgba(72.7%,85.1%,91.5%,1)"><circle cx="93.061224489795919" cy="233.92753019575176" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(97.9%,78.1%,68.1%,1);opacity:1.0;stroke:rgba(97.9%,78.1%,68.1%,1)"><circle cx="96.734693877551024" cy="232.50312369845898" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(29.7%,59.8%,77.7%,1);opacity:1.0;stroke:rgba(29.7%,59.8%,77.7%,1)"><circle cx="100.40816326530611" cy="230.92877967513536" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(95.6%,96.3%,96.6%,1);opacity:1.0;stroke:rgba(95.6%,96.3%,96.6%,1)"><circle cx="104.08163265306122" cy="229.20449812578093" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(59.4%,78.3%,87.7%,1);opacity:1.0;stroke:rgba(59.4%,78.3%,87.7%,1)"><circle cx="107.75510204081633" cy="227.33027905039569" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(44.1%,68.9%,82.6%,1);opacity:1.0;stroke:rgba(44.1%,68.9%,82.6%,1)"><circle cx="111.42857142857143" cy="225.30612244897958" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(49.4%,2.87%,13.6%,1);opacity:1.0;stroke:rgba(49.4%,2 ...

# %%
colors = toyplot.color.broadcast(temperature, y.shape)
colors[20:30, 1] = toyplot.color.css("yellow")
colors.flat[numpy.argsort(temperature, None)[0]] = toyplot.color.css("blue")
colors.flat[numpy.argsort(temperature, None)[-1]] = toyplot.color.css("red")
toyplot.scatterplot(x, y, fill=colors, width=300);
# Out:
# <div align="center" class="toyplot" id="te45fcd998703455b841b57e510cf9f28"><svg height="300.0px" id="te598445deeec47469425131ea2e509cf" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="300.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t282eef372fbc48d680a66ee4e80d5d11"><clipPath id="t7fd22972863d444290a92f0341f0a68f"><rect height="200.0" width="200.0" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t7fd22972863d444290a92f0341f0a68f)" style="cursor:crosshair"><rect height="200.0" style="pointer-events:all;visibility:hidden" width="200.0" x="50.0" y="50.0"></rect><g class="toyplot-mark-Plot" id="t2057e5ccc0f6491094a67d03149ab1d5" style="stroke:none"><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgba(80.1%,92.2%,77.3%,1);opacity:1.0;stroke:rgba(80.1%,92.2%,77.3%,1)"><circle cx="60.0" cy="240.0" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(65.9%,86.7%,71%,1);opacity:1.0;stroke:rgba(65.9%,86.7%,71%,1)"><circle cx="63.673469387755105" cy="239.92503123698458" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(10.9%,48.8%,71.5%,1);opacity:1.0;stroke:rgba(10.9%,48.8%,71.5%,1)"><circle cx="67.346938775510196" cy="239.70012494793838" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(7.35%,45.1%,69.6%,1);opacity:1.0;stroke:rgba(7.35%,45.1%,69.6%,1)"><circle cx="71.020408163265316" cy="239.32528113286131" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(84.8%,94.1%,82.6%,1);opacity:1.0;stroke:rgba(84.8%,94.1%,82.6%,1)"><circle cx="74.693877551020407" cy="238.80049979175345" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(39.3%,75.1%,79.8%,1);opacity:1.0;stroke:rgba(39.3%,75.1%,79.8%,1)"><circle cx="78.367346938775512" cy="238.12578092461476" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(71.1%,88.7%,73.3%,1);opacity:1.0;stroke:rgba(71.1%,88.7%,73.3%,1)"><circle cx="82.040816326530617" cy="237.30112453144525" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(9.64%,47.5%,70.8%,1);opacity:1.0;stroke:rgba(9.64%,47.5%,70.8%,1)"><circle cx="85.714285714285722" cy="236.32653061224491" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(69.2%,87.9%,72.4%,1);opacity:1.0;stroke:rgba(69.2%,87.9%,72.4%,1)"><circle cx="89.387755102040813" cy="235.20199916701375" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(29.2%,68.7%,81.9%,1);opacity:1.0;stroke:rgba(29.2%,68.7%,81.9%,1)"><circle cx="93.061224489795919" cy="233.92753019575176" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(67.2%,87.2%,71.6%,1);opacity:1.0;stroke:rgba(67.2%,87.2%,71.6%,1)"><circle cx="96.734693877551024" cy="232.50312369845898" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(12.6%,50.5%,72.3%,1);opacity:1.0;stroke:rgba(12.6%,50.5%,72.3%,1)"><circle cx="100.40816326530611" cy="230.92877967513536" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(47.1%,79.4%,77.3%,1);opacity:1.0;stroke:rgba(47.1%,79.4%,77.3%,1)"><circle cx="104.08163265306122" cy="229.20449812578093" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(23.3%,62.1%,78.4%,1);opacity:1.0;stroke:rgba(23.3%,62.1%,78.4%,1)"><circle cx="107.75510204081633" cy="227.33027905039569" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(17.7%,55.8%,75%,1);opacity:1.0;stroke:rgba(17.7%,55.8%,75%,1)"><circle cx="111.42857142857143" cy="225.30612244897958" r="2.2360679774997898"></circle></g><g class="toyplot-Datum" style="fill:rgba(94.7%,98%,92.1%,1);opacity:1.0;stroke:rgba(94.7%,98% ...
